# %%
import pandas as pd
import sys

sys.path.append('../../')
from utils import dataframe_utils

# %%
annot_df_raw = pd.read_csv('../../input_data/interproscan_tsv_file/interproscan_compiled.tsv', sep='\t')
annot_df_raw
annot_df_raw['Protein accession'].values
# Out:
# array(['TTHERM_00046368', 'TTHERM_00046368', 'TTHERM_00046368', ...,
#        'TTHERM_00245160', 'TTHERM_00245160', 'TTHERM_00245160'],
#       dtype=object)

# %%
annot_df_raw
# Out:
#        Protein accession               Sequence MD5 digest  Sequence length  \
# 0        TTHERM_00046368  e7ee8c885c14dee785ed46b49f88b10c             1147
# 1        TTHERM_00046368  e7ee8c885c14dee785ed46b49f88b10c             1147
# 2        TTHERM_00046368  e7ee8c885c14dee785ed46b49f88b10c             1147
# 3        TTHERM_00046368  e7ee8c885c14dee785ed46b49f88b10c             1147
# 4        TTHERM_00046368  e7ee8c885c14dee785ed46b49f88b10c             1147
# ...                  ...                               ...              ...
# 233202   TTHERM_00927401  65eeb2a7e98e049b64af46123ef13b7d              581
# 233203   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233204   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233205   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233206   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
#
#           Analysis Signature accession          Signature description  \
# 0       MobiDBLite         mobidb-lite  consensus disorder prediction
# 1       MobiDBLite         mobidb-lite  consensus disorder prediction
# 2       MobiDBLite         mobidb-lite  consensus disorder prediction
# 3       MobiDBLite         mobidb-lite  consensus disorder prediction
# 4       MobiDBLite         mobidb-lite  consensus disorder prediction
# ...            ...                 ...                            ...
# 233202       Coils                Coil                           Coil
# 233203  MobiDBLite         mobidb-lite  consensus disorder prediction
# 233204  MobiDBLite         mobidb-lite  consensus disorder prediction
# 233205  MobiDBLite         mobidb-lite  consensus disorder prediction
# 233206  MobiDBLite         mobidb-lite  consensus disorder prediction
#
#         Start location  Stop location Score Status        Date  \
# 0                  404            475     -      T  02-07-2024
# 1                  660            687     -      T  02-07-2024
# 2                  212            233     -      T  02-07-2024
# 3                  367            391     -      T  02-07-2024
# 4                  613            630     -      T  02-07-2024
# ...                ...            ...   ...    ...         ...
# 233202             542            562     -      T  08-07-2024
# 233203             307            326     -      T  08-07-2024
# 233204             307            323     -      T  08-07-2024
# 233205             577            612     -      T  08-07-2024
# 233206              18             80     -      T  08-07-2024
#
#        InterPro annotations - accession InterPro annotations - description  \
# 0                                     -                                  -
# 1                                     -                                  -
# 2                                     -                                  -
# 3                                     -                                  -
# 4                                     -                                  -
# ...                                 ...                                ...
# 233202                                -                                  -
# 233203                                -                                  -
# 233204                                -                                  -
# 233205                                -                                  -
# 233206                                -                                  -
#
#        GO annotations with their source(s) Pathways annotations
# 0                                        -                    -
# 1                                        -                    -
# 2                                        -                    -
# 3                                        -                    -
# 4                                        -                    -
# ...                                    ...                  ...
# 233202                                   -                    -
# 233203                                   -                    -
# 233204                                   -                    -
# 233205                                   -                    -
# 233206                                   -                    -
#
# [233207 rows x 15 columns]

# %%
annot_df_raw.isna().any()
# Out:
# Protein accession                      False
# Sequence MD5 digest                    False
# Sequence length                        False
# Analysis                               False
# Signature accession                    False
# Signature description                  False
# Start location                         False
# Stop location                          False
# Score                                  False
# Status                                 False
# Date                                   False
# InterPro annotations - accession       False
# InterPro annotations - description     False
# GO annotations with their source(s)    False
# Pathways annotations                   False
# dtype: bool

# %%
interpro_desc_dict = {}

interpro_descs = annot_df_raw['InterPro annotations - description'].values

for idx, acc in enumerate(annot_df_raw['InterPro annotations - accession'].values):
    if acc in interpro_desc_dict and interpro_desc_dict[acc] != interpro_descs[idx]:
        raise(ValueError(f'InterPro annotation with accession={acc} has multiple descriptions:\n1. {interpro_desc_dict[acc]}\n2. {interpro_descs[idx]}\n...'))
    interpro_desc_dict[acc] = interpro_descs[idx]

# %%
interpro_desc_dict
# Out:
# {'-': '-',
#  'IPR001594': 'Palmitoyltransferase, DHHC domain',
#  'IPR001810': 'F-box domain',
#  'IPR006553': 'Leucine-rich repeat, cysteine-containing subtype',
#  'IPR036047': 'F-box-like domain superfamily',
#  'IPR032675': 'Leucine-rich repeat domain superfamily',
#  'IPR004344': 'Tubulin-tyrosine ligase/Tubulin polyglutamylase',
#  'IPR000719': 'Protein kinase domain',
#  'IPR027038': 'Ran GTPase-activating protein',
#  'IPR001611': 'Leucine-rich repeat',
#  'IPR011009': 'Protein kinase-like domain superfamily',
#  'IPR036259': 'MFS transporter superfamily',
#  'IPR051617': 'UNC-93-like transmembrane regulator',
#  'IPR011701': 'Major facilitator superfamily',
#  'IPR026906': 'BspA-type LRR region',
#  'IPR002259': 'Equilibrative nucleoside transporter',
#  'IPR025763': 'tRNA (guanine-N-7) methyltransferase catalytic subunit Trm8, eukaryote',
#  'IPR003358': 'tRNA (guanine-N-7) methyltransferase, Trmb type',
#  'IPR029063': 'S-adenosyl-L-methionine-dependent methyltransferase superfamily',
#  'IPR007722': 'mRNA decapping protein 2, Box A domain',
#  'IPR020084': 'NUDIX hydrolase, conserved site',
#  'IPR000086': 'NUDIX hydrolase domain',
#  'IPR015797': 'NUDIX hydrolase-like domain superfamily',
#  'IPR036189': 'mRNA decapping protein 2, Box A domain superfamily',
#  'IPR045357': 'Aminopeptidase N-like , N-terminal domain',
#  'IPR042097': 'Aminopeptidase N-like , N-terminal domain superfamliy',
#  'IPR005821': 'Ion transport domain',
#  'IPR027359': 'Voltage-dependent channel domain superfamily',
#  'IPR012340': 'Nucleic acid-binding, OB-fold',
#  'IPR013955': 'Replication factor A, C-terminal',
#  'IPR047192': 'Replication factor A, C-terminal, eukaryotes',
#  'IPR027417': 'P-loop containing nucleoside triphosphate hydrolase',
#  'IPR001806': 'Small GTPase',
#  'IPR026755': 'Protein FAM221A/B',
#  'IPR038765': 'Papain-like cysteine peptidase superfamily',
#  'IPR028889': 'Ubiquitin specific protease domain',
#  'IPR018200': 'Ubiquitin specific protease, conserved site',
#  'IPR051261': 'NOD-like receptor (NLR)',
#  'IPR013078': 'Histidine phosphatase superfamily, clade-1',
#  'IPR000571': 'Zinc finger, CCCH-type',
#  'IPR050275': 'Phosphoglycerate Mutase/Phosphatase',
#  'IPR036855': 'Zinc finger, CCCH-type superfamily',
#  'IPR029033': 'Histidine phosphatase superfamily',
#  'IPR036640': 'ABC transporter type 1, transmembrane domain superfamily',
#  'IPR011527': 'ABC transporter type 1, transmembrane domain',
#  'IPR017871': 'ABC transporter-like, conserved site',
#  'IPR003439': 'ABC transporter-like, ATP-binding domain',
#  'IPR044726': 'ABC transporter C family, six-transmembrane helical domain 2',
#  'IPR050173': 'ATP-binding cassette transporter C',
#  'IPR044746': 'ABC transporter C family, six-transmembrane helical domain 1',
#  'IPR003593': 'AAA+ ATPase domain',
#  'IPR003409': 'MORN repeat',
#  'IPR029058': 'Alpha/Beta hydrolase fold',
#  'IPR000073': 'Alpha/beta hydrolase fold-1',
#  'IPR018247': 'EF-Hand 1, calcium-binding site',
#  'IPR052994': 'Tiny macrocysts signaling regulators',
#  'IPR029149': 'Creatinase/Aminopeptidase P/Spt16, N-terminal',
#  'IPR032416': 'Peptidase M24, C-terminal domain',
#  'IPR000587': 'Creatinase, N-terminal',
#  'IPR050422': 'Xaa-Pro aminopeptidase P',
#  'IPR036005': 'Creatinase/aminopeptidase-like',
#  'IPR033740': 'Aminopeptidase P',
#  'IPR000994': 'Peptidase M24',
#  'IPR018490': 'Cyclic nucleotide-binding domain superfamily',
#  'IPR000595': 'Cyclic nucleotide-binding domain',
#  'IPR013099': 'Potassium channel domain',
#  'IPR051413': 'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel',
#  'IPR014710': 'RmlC-like jelly roll fold',
#  'IPR011990': 'Tetratricopeptide-like helical domain superfamily',
#  'IPR019734': 'Tetratricopeptide repeat',
#  'IPR006597': 'Sel1-like repeat',
#  'IPR013105': 'Tetratricopeptide repeat 2',
#  'IPR051012': 'Cellulose Synthase/LPS Assembly/PSI Assembly',
#  'IPR013087': 'Zinc finger C2H2-type',
#  'IPR036866': 'Ribonuclease Z/Hydroxyacylglutathione hydrolase-like',
#  'IPR050503': 'cAMP-dependent kinase regulatory chain',
#  'IPR012875': 'Succinate dehydrogenase assembly factor 4',
#  'IPR002048': 'EF-hand domain',
#  'IPR050205': 'Calcium-dependent Serine/Threonine Protein Kinases',
#  'IPR008271': 'Serine/threonine-protein kinase, active site',
#  'IPR011992': 'EF-hand domain pair',
#  'IPR017441': 'Protein kinase, ATP binding site',
#  'IPR006091': 'Acyl-CoA oxidase/dehydrogenase, middle domain',
#  'IPR046373': 'Acyl-CoA oxidase/dehydrogenase, middle domain superfamily',
#  'IPR002655': 'Acyl-CoA oxidase, C-terminal',
#  'IPR009100': 'Acyl-CoA dehydrogenase/oxidase, N-terminal and middle domain superfamily',
#  'IPR036250': 'Acyl-CoA dehydrogenase-like, C-terminal',
#  'IPR029320': 'Acyl-coenzyme A oxidase, N-terminal',
#  'IPR037069': 'Acyl-CoA dehydrogenase/oxidase, N-terminal domain superfamily',
#  'IPR012258': 'Acyl-CoA oxidase',
#  'IPR001650': 'Helicase, C-terminal domain-like',
#  'IPR011545': 'DEAD/DEAH box helicase domain',
#  'IPR014001': 'Helicase superfamily 1/2, ATP-binding domain',
#  'IPR014014': 'RNA helicase, DEAD-box type, Q motif',
#  'IPR009038': 'GOLD domain',
#  'IPR015720': 'Transmembrane emp24 domain-containing protein',
#  'IPR029775': 'Nephrocystin-4',
#  'IPR036322': 'WD40-repeat-containing domain superfamily',
#  'IPR015943': 'WD40/YVTN repeat-like-containing domain superfamily',
#  'IPR026183': 'Taxilin family',
#  'IPR002921': 'Fungal lipase-like domain',
#  'IPR051218': 'Secreted Mono/Diacylglycerol Lipase',
#  'IPR005399': 'Potassium channel, voltage-dependent, beta subunit, KCNAB-related',
#  'IPR036812': 'NADP-dependent oxidoreductase domain superfamily',
#  'IPR023210': 'NADP-dependent oxidoreductase domain',
#  'IPR017105': 'Adaptor protein complex AP-3, delta subunit',
#  'IPR002553': 'Clathrin/coatomer adaptor, adaptin-like, N-terminal',
#  'IPR011989': 'Armadillo-like helical',
#  'IPR016024': 'Armadillo-type fold',
#  'IPR039804': 'Listerin, zinc finger, RING-type',
#  'IPR001841': 'Zinc finger, RING-type',
#  'IPR011016': 'Zinc finger, RING-CH-type',
#  'IPR013083': 'Zinc finger, RING/FYVE/PHD-type',
#  'IPR039795': 'E3 ubiquitin-protein ligase listerin',
#  'IPR018902': 'Ciliary microtubule inner protein 2A-C-like domain',
#  'IPR052798': 'Giardia Variant Surface Antigen',
#  'IPR009030': 'Growth factor receptor cysteine-rich domain superfamily',
#  'IPR001199': 'Cytochrome b5-like heme/steroid binding domain',
#  'IPR018506': 'Cytochrome b5, heme-binding site',
#  'IPR050668': 'Cytochrome b5',
#  'IPR036400': 'Cytochrome b5-like heme/steroid binding domain superfamily',
#  'IPR023395': 'Mitochondrial carrier domain superfamily',
#  'IPR018108': 'Mitochondrial substrate/solute carrier',
#  'IPR045315': 'Mitochondrial carrier protein Mtm1-like',
#  'IPR047831': 'GPR180/TMEM145',
#  'IPR019336': 'GPR180/TMEM145, transmembrane domain',
#  'IPR014756': 'Immunoglobulin E-set',
#  'IPR005559': 'CG-1 DNA-binding domain',
#  'IPR036770': 'Ankyrin repeat-containing domain superfamily',
#  'IPR013783': 'Immunoglobulin-like fold',
#  'IPR044744': 'ZNRF4 /RNF13/RNF167, PA domain',
#  'IPR003137': 'PA domain',
#  'IPR021013': 'ATPase, vacuolar ER assembly factor, Vma12',
#  'IPR050117': 'Mitogen-activated protein kinase',
#  'IPR019786': 'Zinc finger, PHD-type, conserved site',
#  'IPR038716': 'Large ribosomal subunit protein P1/P2, N-terminal domain',
#  'IPR027534': 'Large ribosomal subunit protein P1/P2',
#  'IPR019399': 'Parkin co-regulated protein',
#  'IPR000742': 'EGF-like domain',
#  'IPR006212': 'Furin-like repeat',
#  'IPR003140': 'Phospholipase/carboxylesterase/thioesterase',
#  'IPR050565': 'AB hydrolase superfamily domain-containing protein',
#  'IPR020097': 'Pseudouridine synthase I, TruA, alpha/beta domain',
#  'IPR020103': 'Pseudouridine synthase, catalytic domain superfamily',
#  'IPR020094': 'Pseudouridine synthase TruA/RsuA/RluB/E/F, N-terminal',
#  'IPR001406': 'Pseudouridine synthase I, TruA',
#  'IPR020095': 'Pseudouridine synthase I, TruA, C-terminal',
#  'IPR037221': 'H-type lectin domain superfamily',
#  'IPR019019': 'H-type lectin domain',
#  'IPR050474': 'Helicase Hel308/SKI2',
#  'IPR035892': 'C2 domain superfamily',
#  'IPR036390': 'Winged helix DNA-binding domain superfamily',
#  'IPR036388': 'Winged helix-like DNA-binding domain superfamily',
#  'IPR004179': 'Sec63 domain',
#  'IPR002110': 'Ankyrin repeat',
#  'IPR047139': 'tRNA endonuclease ANKZF1/VMS1',
#  'IPR000860': 'Porphobilinogen deaminase',
#  'IPR036803': 'Porphobilinogen deaminase, C-terminal domain superfamily',
#  'IPR022418': 'Porphobilinogen deaminase, C-terminal',
#  'IPR022417': 'Porphobilinogen deaminase, N-terminal',
#  'IPR011044': 'Quinoprotein amine dehydrogenase, beta chain-like',
#  'IPR029164': 'Phosphatidylinositol N-acetylglucosaminyltransferase subunit Y',
#  'IPR050235': 'Casein Kinase 1 Ser/Thr Protein Kinase',
#  'IPR005804': 'Fatty acid desaturase domain',
#  'IPR013866': 'Sphingolipid delta4-desaturase, N-terminal',
#  'IPR011146': 'HIT-like domain',
#  'IPR036265': 'HIT-like superfamily',
#  'IPR051884': "Bis(5'-adenosyl)-triphosphatase activity regulators",
#  'IPR000996': 'Clathrin light chain',
#  'IPR050818': 'Voltage-gated potassium channel family H',
#  'IPR006939': 'SNF5/SMARCB1/INI1',
#  'IPR050630': 'WD repeat Echinoderm Microtubule-associated Protein-like',
#  'IPR001680': 'WD40 repeat',
#  'IPR036465': 'von Willebrand factor A-like domain superfamily',
#  'IPR007724': 'Poly(ADP-ribose) glycohydrolase',
#  'IPR048362': 'Poly (ADP-ribose) glycohydrolase, helical domain',
#  'IPR046372': 'Poly (ADP-ribose) glycohydrolase (PARG), catalytic domain',
#  'IPR000253': 'Forkhead-associated (FHA) domain',
#  'IPR008984': 'SMAD/FHA domain superfamily',
#  'IPR036397': 'Ribonuclease H superfamily',
#  'IPR003100': 'PAZ domain',
#  'IPR003165': 'Piwi domain',
#  'IPR036085': 'PAZ domain superfamily',
#  'IPR012337': 'Ribonuclease H-like superfamily',
#  'IPR001881': 'EGF-like calcium-binding domain',
#  'IPR000203': 'GPS motif',
#  'IPR050339': 'Cell Cycle and Stress Response Kinase',
#  'IPR028008': 'Protein of unknown function DUF4441',
#  'IPR001163': 'Sm domain, eukaryotic/archaea-type',
#  'IPR044642': 'U6 snRNA-associated Sm-like protein Lsm1/8',
#  'IPR034103': 'Sm-like protein Lsm8',
#  'IPR047575': 'Sm domain',
#  'IPR010920': 'LSM domain superfamily',
#  'IPR001394': 'Peptidase C19, ubiquitin carboxyl-terminal hydrolase',
#  'IPR050164': 'Ubiquitin carboxyl-terminal hydrolases',
#  'IPR007304': 'TAP46-like protein',
#  'IPR038511': 'TAP42/TAP46-like superfamily',
#  'IPR016339': 'Truncated hemoglobin, group 1',
#  'IPR019795': 'Globin, bacterial-like, conserved site',
#  'IPR001486': 'Truncated hemoglobin',
#  'IPR009050': 'Globin-like superfamily',
#  'IPR012292': 'Globin/Protoglobin',
#  'IPR018488': 'Cyclic nucleotide-binding, conserved site',
#  'IPR043533': 'Cyclic nucleotide-binding domain-containing protein 1/2',
#  'IPR023299': 'P-type ATPase, cytoplasmic domain N',
#  'IPR004014': 'Cation-transporting P-type ATPase, N-terminal',
#  'IPR023214': 'HAD superfamily',
#  'IPR023298': 'P-type ATPase, transmembrane domain superfamily',
#  'IPR036412': 'HAD-like superfamily',
#  'IPR006068': 'Cation-transporting P-type ATPase, C-terminal',
#  'IPR001757': 'P-type ATPase',
#  'IPR018303': 'P-type ATPase, phosphorylation site',
#  'IPR008250': 'P-type ATPase, A domain superfamily',
#  'IPR044492': 'P-type ATPase, haloacid dehalogenase domain',
#  'IPR050510': 'Cation transport ATPase (P-type)',
#  'IPR044677': 'Mitochondrial phosphate carrier protein SLC25A3/Pic2/Mir1-like',
#  'IPR023393': 'START-like domain superfamily',
#  'IPR002913': 'START domain',
#  'IPR036890': 'Histidine kinase/HSP90-like ATPase superfamily',
#  'IPR014729': 'Rossmann-like alpha/beta/alpha sandwich fold',
#  'IPR001245': 'Serine-threonine/tyrosine-protein kinase, catalytic domain',
#  'IPR051681': 'Serine/Threonine Kinases and Pseudokinases',
#  'IPR011604': 'PD-(D/E)XK endonuclease-like domain superfamily',
#  'IPR019080': 'YqaJ viral recombinase',
#  'IPR011335': 'Restriction endonuclease type II-like',
#  'IPR051703': 'NF-kappa-B Signaling Regulator',
#  'IPR013260': 'mRNA splicing factor SYF2',
#  'IPR002130': 'Cyclophilin-type peptidyl-prolyl cis-trans isomerase domain',
#  'IPR029000': 'Cyclophilin-like domain superfamily',
#  'IPR005225': 'Small GTP-binding protein domain',
#  'IPR013525': 'ABC-2 type transporter, transmembrane domain',
#  'IPR043926': 'ABC transporter family G domain',
#  'IPR050352': 'ATP-binding cassette subfamily G transporters',
#  'IPR027640': 'Kinesin-like protein',
#  'IPR019821': 'Kinesin motor domain, conserved site',
#  'IPR001752': 'Kinesin motor domain',
#  'IPR036961': 'Kinesin motor domain superfamily',
#  'IPR033885': 'Alkane/xylene monooxygenase',
#  'IPR020471': 'Aldo-keto reductase',
#  'IPR018170': 'Aldo/keto reductase, conserved site',
#  'IPR000014': 'PAS domain',
#  'IPR051131': 'NEK Ser/Thr protein kinase family, NIMA subfamily',
#  'IPR000408': 'Regulator of chromosome condensation, RCC1',
#  'IPR009091': 'Regulator of chromosome condensation 1/beta-lactamase-inhibitor protein II',
#  'IPR051553': 'Ran GTPase-activating',
#  'IPR033646': 'CLU central domain',
#  'IPR045111': 'Vacuolar protein sorting-associated protein Vps41/Vps8',
#  'IPR000547': 'Clathrin, heavy chain/VPS, 7-fold repeat',
#  'IPR025941': 'Vacuolar protein sorting-associated protein 8, central domain',
#  'IPR051052': 'Diverse substrate methyltransferase',
#  'IPR025714': 'Methyltransferase domain',
#  'IPR036052': 'Tryptophan synthase beta chain-like, PALP domain superfamily',
#  'IPR001926': 'Tryptophan synthase beta chain-like, PALP domain',
#  'IPR050214': 'Cysteine Synthase/Cystathionine Beta-Synthase',
#  'IPR032157': 'Proteasome assembly chaperone 4',
#  'IPR001047': 'Small ribosomal subunit protein eS8',
#  'IPR022309': 'Ribosomal protein eS8/ribosomal biogenesis NSA2',
#  'IPR039175': 'Mitochondrial import inner membrane translocase subunit TIM22',
#  'IPR049452': 'Anoctamin, transmembrane domain',
#  'IPR007632': 'Anoctamin',
#  'IPR000315': 'B-box-type zinc finger',
#  'IPR001789': 'Signal transduction response regulator, receiver domain',
#  'IPR003594': 'Histidine kinase/HSP90-like ATPase',
#  'IPR005467': 'Histidine kinase domain',
#  'IPR003661': 'Signal transduction histidine kinase, dimerisation/phosphoacceptor domain',
#  'IPR004358': 'Signal transduction histidine kinase-related protein, C-terminal',
#  'IPR011006': 'CheY-like superfamily',
#  'IPR036097': 'Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily',
#  'IPR009011': 'Mannose-6-phosphate receptor binding domain superfamily',
#  'IPR044865': 'MRH domain',
#  'IPR040236': 'Transmembrane protein 198',
#  'IPR025256': 'Domain of unknown function DUF4203',
#  'IPR018939': 'Autophagy-related protein 27',
#  'IPR013000': 'Large ribosomal subunit protein uL4, eukaryotic/archaeal, conserved site',
#  'IPR025755': 'Large ribosomal subunit protein uL4, C-terminal domain',
#  'IPR002136': 'Large ribosomal subunit protein uL4',
#  'IPR023574': 'Large ribosomal subunit protein uL4 domain superfamily',
#  'IPR045240': 'Large ribosomal subunit protein uL4, eukaryotic and archaeal type',
#  'IPR000849': 'Sugar phosphate transporter',
#  'IPR020846': 'Major facilitator superfamily domain',
#  'IPR007230': 'Nuclear pore complex protein Nup98-Nup96-like, autopeptidase S59 domain',
#  'IPR036903': 'Nuclear pore complex protein Nup98-Nup96-like, autopeptidase S59 domain superfamily',
#  'IPR037665': 'Nucleoporin peptidase S59-like',
#  'IPR045203': 'RAN GTPase-activating protein 1/2',
#  'IPR036273': 'CRAL/TRIO, N-terminal domain superfamily',
#  'IPR051026': 'Phosphatidylinositol/phosphatidylcholine transfer',
#  'IPR001251': 'CRAL-TRIO lipid binding domain',
#  'IPR036865': 'CRAL-TRIO lipid binding domain superfamily',
#  'IPR050227': 'Ras-related protein Rab',
#  'IPR017998': 'Chaperone tailless complex polypeptide 1 (TCP-1)',
#  'IPR002194': 'Chaperonin TCP-1, conserved site',
#  'IPR027413': 'GroEL-like equatorial domain superfamily',
#  'IPR012718': 'T-complex protein 1, epsilon subunit',
#  'IPR027409': 'GroEL-like apical domain superfamily',
#  'IPR002423': 'Chaperonin Cpn60/GroEL/TCP-1 family',
#  'IPR053374': 'TCP-1 chaperonin-containing T-complex',
#  'IPR027410': 'TCP-1-like chaperonin intermediate domain superfamily',
#  'IPR050599': 'Voltage-dependent calcium channel alpha-1 subunit',
#  'IPR023796': 'Serpin domain',
#  'IPR036186': 'Serpin superfamily',
#  'IPR042178': 'Serpin superfamily, domain 1',
#  'IPR000215': 'Serpin family',
#  'IPR042185': 'Serpin superfamily, domain 2',
#  'IPR002035': 'von Willebrand factor, type A',
#  'IPR051266': 'Calcium-activated chloride channel regulator',
#  'IPR030383': 'Very large inducible GTPASE (VLIG)-type guanine nucleotide-binding (G) domain',
#  'IPR052969': 'Threonine-specific kinase-like protein',
#  'IPR015915': 'Kelch-type beta propeller',
#  'IPR003388': 'Reticulon',
#  'IPR029488': 'Hemingway/CFA97',
#  'IPR000873': 'AMP-dependent synthetase/ligase domain',
#  'IPR042099': 'ANL, N-terminal domain',
#  'IPR020845': 'AMP-binding, conserved site',
#  'IPR011050': 'Pectin lyase fold/virulence factor',
#  'IPR052201': 'Leucine-rich repeat-containing regulator of pluripotency',
#  'IPR015505': 'Coronin',
#  'IPR015048': 'Domain of unknown function DUF1899',
#  'IPR019775': 'WD40 repeat, conserved site',
#  'IPR036774': 'ERV/ALR sulfhydryl oxidase domain superfamily',
#  'IPR017905': 'ERV/ALR sulfhydryl oxidase domain',
#  'IPR039799': 'Sulfhydryl oxidase ALR/ERV',
#  'IPR006977': 'Yip1 domain',
#  'IPR039765': 'Protein Yip5/YIPF1/YIPF2',
#  'IPR050852': 'Queuine tRNA-ribosyltransferase',
#  'IPR036511': 'Queuine tRNA-ribosyltransferase-like',
#  'IPR002616': 'tRNA-guanine(15) transglycosylase-like',
#  'IPR050588': 'With No Lysine (K) Ser/Thr Protein Kinase',
#  'IPR036365': 'PGBD-like superfamily',
#  'IPR008266': 'Tyrosine-protein kinase, active site',
#  'IPR001577': 'Peptidase M8, leishmanolysin',
#  'IPR020818': 'GroES chaperonin family',
#  'IPR011032': 'GroES-like superfamily',
#  'IPR037124': 'GroES chaperonin superfamily',
#  'IPR011012': 'Longin-like domain superfamily',
#  'IPR006722': 'Trafficking protein particle complex subunit 2',
#  'IPR011697': 'Peptidase C26',
#  'IPR015527': 'Peptidase C26, gamma-glutamyl hydrolase',
#  'IPR029062': 'Class I glutamine amidotransferase-like',
#  'IPR036249': 'Thioredoxin-like superfamily',
#  'IPR051063': 'Protein Disulfide Isomerase',
#  'IPR013766': 'Thioredoxin domain',
#  'IPR017937': 'Thioredoxin, conserved site',
#  'IPR001878': 'Zinc finger, CCHC-type',
#  'IPR050305': 'Small GTPase superfamily, Rab',
#  'IPR005828': 'Major facilitator, sugar transporter-like',
#  'IPR005829': 'Sugar transporter, conserved site',
#  'IPR003689': 'Zinc/iron permease',
#  'IPR040323': 'EARP and GARP complex-interacting protein 1',
#  'IPR036013': 'Band 7/SPFH domain superfamily',
#  'IPR001107': 'Band 7 domain',
#  'IPR043202': 'Band-7 stomatin-like',
#  'IPR002859': 'PKD/REJ-like domain',
#  'IPR010926': 'Class I myosin tail homology domain',
#  'IPR045122': 'Calcium permeable stress-gated cation channel 1-like',
#  'IPR018499': 'Tetraspanin/Peripherin',
#  'IPR016169': 'FAD-binding, type PCMH, subdomain 2',
#  'IPR036318': 'FAD-binding, type PCMH-like superfamily',
#  'IPR016166': 'FAD-binding domain, PCMH-type',
#  'IPR051264': 'FAD-binding Oxidoreductase/Transferase Type 4',
#  'IPR004113': 'FAD-binding oxidoreductase/transferase, type 4, C-terminal',
#  'IPR006094': 'FAD linked oxidase, N-terminal',
#  'IPR016167': 'FAD-binding, type PCMH, subdomain 1',
#  'IPR016164': 'FAD-linked oxidase-like, C-terminal',
#  'IPR016171': 'Vanillyl-alcohol oxidase, C-terminal subdomain 2',
#  'IPR035979': 'RNA-binding domain superfamily',
#  'IPR012677': 'Nucleotide-binding alpha-beta plait domain superfamily',
#  'IPR000504': 'RNA recognition motif domain',
#  'IPR051210': 'Ubiquitin ligases and GEF domain-containing protein',
#  'IPR036670': 'SecA, preprotein cross-linking domain superfamily',
#  'IPR044722': 'SecA, C-terminal helicase domain',
#  'IPR000185': 'Protein translocase subunit SecA',
#  'IPR014018': 'SecA motor DEAD',
#  'IPR011115': 'SecA DEAD-like, N-terminal',
#  'IPR053271': 'DDT domain-containing protein',
#  'IPR028941': 'WHIM2 domain',
#  'IPR019787': 'Zinc finger, PHD-finger',
#  'IPR011011': 'Zinc finger, FYVE/PHD-type',
#  'IPR018501': 'DDT domain',
#  'IPR001965': 'Zinc finger, PHD-type',
#  'IPR001563': 'Peptidase S10, serine carboxypeptidase',
#  'IPR033124': 'Serine carboxypeptidases, histidine active site',
#  'IPR018202': 'Serine carboxypeptidase, serine active site',
#  'IPR019165': 'Peptidase M76, ATP23',
#  'IPR003877': 'SPRY domain',
#  'IPR001870': 'B30.2/SPRY domain',
#  'IPR050672': 'F-box/SPRY and SOCS box protein families',
#  'IPR017907': 'Zinc finger, RING-type, conserved site',
#  'IPR018957': 'Zinc finger, C3HC4 RING-type',
#  'IPR013320': 'Concanavalin A-like lectin/glucanase domain superfamily',
#  'IPR043136': 'B30.2/SPRY domain superfamily',
#  'IPR001461': 'Aspartic peptidase A1 family',
#  'IPR021109': 'Aspartic peptidase domain superfamily',
#  'IPR033121': 'Peptidase family A1 domain',
#  'IPR034164': 'Pepsin-like domain',
#  'IPR001969': 'Aspartic peptidase, active site',
#  'IPR036428': 'Pterin 4 alpha carbinolamine dehydratase superfamily',
#  'IPR001533': 'Pterin 4 alpha carbinolamine dehydratase',
#  'IPR002052': 'DNA methylase, N-6 adenine-specific, conserved site',
#  'IPR004556': 'Methyltransferase HemK-like',
#  'IPR007848': 'Methyltransferase small domain',
#  'IPR050320': 'Protein N5-glutamine methyltransferase',
#  'IPR050209': 'Rab GTPases family involved in membrane trafficking',
#  'IPR022742': 'Serine aminopeptidase, S33',
#  'IPR044245': 'SprT-like domain-containing protein Spartan',
#  'IPR006640': 'SprT-like',
#  'IPR011263': 'DNA-directed RNA polymerase, RpoA/D/Rpb3-type',
#  'IPR036603': 'RNA polymerase, RBP11-like subunit',
#  'IPR050518': 'Archaeal Rpo3/Eukaryotic RPB3 RNA Polymerase Subunit',
#  'IPR001514': 'DNA-directed RNA polymerase, 30-40kDa subunit, conserved site',
#  'IPR036643': 'DNA-directed RNA polymerase, insert domain superfamily',
#  'IPR022842': 'DNA-directed RNA polymerase subunit Rpo3/Rpb3/RPAC1',
#  'IPR011262': 'DNA-directed RNA polymerase, insert domain',
#  'IPR003848': 'Domain of unknown function DUF218',
#  'IPR051599': 'Cell Envelope Integrity and Synthesis Associated Protein',
#  'IPR028172': 'Intraflagellar transport protein 20',
#  'IPR051177': 'Catalytically Inactive Kinase-Related Protein',
#  'IPR019559': 'Cullin protein, neddylation domain',
#  'IPR036317': 'Cullin homology domain superfamily',
#  'IPR016158': 'Cullin homology domain',
#  'IPR001373': 'Cullin, N-terminal',
#  'IPR045093': 'Cullin',
#  'IPR016159': 'Cullin repeat-like-containing domain superfamily',
#  'IPR006286': 'Deglycase PfpI-like',
#  'IPR002818': 'DJ-1/PfpI',
#  'IPR035965': 'PAS domain superfamily',
#  'IPR052287': 'Non-homologous end-joining factor',
#  'IPR038051': 'XRCC4-like, N-terminal domain superfamily',
#  'IPR015381': 'XLF-like, N-terminal',
#  'IPR017920': 'COMM domain',
#  'IPR037360': 'COMM domain-containing protein 9',
#  'IPR045269': 'Serine/threonine-protein kinase Atg1-like',
#  'IPR010987': 'Glutathione S-transferase, C-terminal-like',
#  'IPR040079': 'Glutathione transferase family',
#  'IPR004046': 'Glutathione S-transferase, C-terminal',
#  'IPR050213': 'Glutathione S-transferase superfamily',
#  'IPR036282': 'Glutathione S-transferase, C-terminal domain superfamily',
#  'IPR004045': 'Glutathione S-transferase, N-terminal',
#  'IPR013025': 'Large ribosomal subunit protein uL23-like',
#  'IPR005633': 'Large ribosomal subunit protein uL23, N-terminal',
#  'IPR012678': 'Ribosomal protein uL23/eL15/eS24 core domain superfamily',
#  'IPR001014': 'Large ribosomal subunit protein uL23, conserved site',
#  'IPR040091': 'Leucine-rich repeat-containing protein 56',
#  'IPR009643': 'Heat shock factor binding 1',
#  'IPR001656': 'Pseudouridine synthase, TruD',
#  'IPR011760': 'Pseudouridine synthase, TruD, insertion domain',
#  'IPR042214': 'Pseudouridine synthase, TruD, catalytic domain',
#  'IPR050660': 'NEK Serine/Threonine Protein Kinase',
#  'IPR011629': 'Zinc chaperone CobW-like, C-terminal',
#  'IPR051927': 'Zinc Chaperone and cDPG Synthetase',
#  'IPR006644': 'Dystroglycan-type cadherin-like',
#  'IPR015919': 'Cadherin-like superfamily',
#  'IPR000668': 'Peptidase C1A, papain C-terminal',
#  'IPR013128': 'Peptidase C1A',
#  'IPR013201': 'Cathepsin propeptide inhibitor domain (I29)',
#  'IPR039417': 'Papain-like cysteine endopeptidase',
#  'IPR025660': 'Cysteine peptidase, histidine active site',
#  'IPR025875': 'Leucine rich repeat 4',
#  'IPR003591': 'Leucine-rich repeat, typical subtype',
#  'IPR050836': 'SDS22/Internalin LRR-containing',
#  'IPR001623': 'DnaJ domain',
#  'IPR051100': 'DnaJ subfamily B/C chaperone co-factors',
#  'IPR036869': 'Chaperone J-domain superfamily',
#  'IPR045877': 'RNA-binding protein ZFP36-like',
#  'IPR045242': 'Syntaxin',
#  'IPR000727': 'Target SNARE coiled-coil homology domain',
#  'IPR010989': 'SNARE',
#  'IPR007527': 'Zinc finger, SWIM-type',
#  'IPR020892': 'Cyclophilin-type peptidyl-prolyl cis-trans isomerase, conserved site',
#  'IPR024936': 'Cyclophilin-type peptidyl-prolyl cis-trans isomerase',
#  'IPR044666': 'Cyclophilin-type peptidyl-prolyl cis-trans isomerase, cyclophilin A-like',
#  'IPR027752': 'Protein polyglycylase TTLL10',
#  'IPR029041': 'FAD-linked oxidoreductase-like',
#  'IPR015659': 'Proline oxidase family',
#  'IPR006626': 'Parallel beta-helix repeat',
#  'IPR013057': 'Amino acid transporter, transmembrane domain',
#  'IPR050121': 'Cytochrome P450 monooxygenase',
#  'IPR017972': 'Cytochrome P450, conserved site',
#  'IPR036396': 'Cytochrome P450 superfamily',
#  'IPR001128': 'Cytochrome P450',
#  'IPR002403': 'Cytochrome P450, E-class, group IV',
#  'IPR001194': 'cDENN domain',
#  'IPR037516': 'Tripartite DENN domain',
#  'IPR051942': 'DENN domain-containing protein 2',
#  'IPR043153': 'DENN domain, C-terminal lobe',
#  'IPR013694': 'VIT domain',
#  'IPR030445': 'Histone H3-K79 methyltransferase',
#  'IPR025789': 'Histone-lysine N-methyltransferase DOT1 domain',
#  'IPR050196': 'Cytochrome P450 Monooxygenases',
#  'IPR003368': 'Polymorphic outer membrane protein repeat',
#  'IPR007421': 'Schlafen, AlbA_2 domain',
#  'IPR029684': 'Schlafen family',
#  'IPR052187': 'Major facilitator superfamily domain-containing protein 1',
#  'IPR018494': 'Oxysterol-binding protein, conserved site',
#  'IPR037239': 'Oxysterol-binding protein superfamily',
#  'IPR000648': 'Oxysterol-binding protein',
#  'IPR008775': 'Phytanoyl-CoA dioxygenase-like',
#  'IPR038286': 'Inositol polyphosphate kinase superfamily',
#  'IPR005522': 'Inositol polyphosphate kinase',
#  'IPR050284': 'Histone deacetylase and polyamine deacetylase',
#  'IPR000286': 'Histone deacetylase family',
#  'IPR023696': 'Ureohydrolase domain superfamily',
#  'IPR037138': 'Histone deacetylase domain superfamily',
#  'IPR023801': 'Histone deacetylase domain',
#  'IPR002350': 'Kazal domain',
#  'IPR020472': 'G-protein beta WD-40 repeat',
#  'IPR000811': 'Glycosyl transferase, family 35',
#  'IPR011833': 'Glycogen/starch/alpha-glucan phosphorylase',
#  'IPR035090': 'Phosphorylase pyridoxal-phosphate attachment site',
#  'IPR011993': 'PH-like domain superfamily',
#  'IPR005334': 'Dynein light chain Tctex-1 like',
#  'IPR038586': 'Tctex-1-like superfamily',
#  'IPR002452': 'Alpha tubulin',
#  'IPR037103': 'Tubulin/FtsZ-like, C-terminal domain',
#  'IPR000217': 'Tubulin',
#  'IPR018316': 'Tubulin/FtsZ, 2-layer sandwich domain',
#  'IPR003008': 'Tubulin/FtsZ, GTPase domain',
#  'IPR023123': 'Tubulin, C-terminal',
#  'IPR036525': 'Tubulin/FtsZ, GTPase domain superfamily',
#  'IPR008280': 'Tubulin/FtsZ, C-terminal',
#  'IPR023366': 'ATP synthase subunit alpha, N-terminal domain-like superfamily',
#  'IPR000194': 'ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain',
#  'IPR036121': 'ATPase, F1/V1/A1 complex, alpha/beta subunit, N-terminal domain superfamily',
#  'IPR005294': 'ATP synthase, F1 complex, alpha subunit',
#  'IPR008145': 'Guanylate kinase/L-type calcium channel beta subunit',
#  'IPR008144': 'Guanylate kinase-like domain',
#  'IPR047501': 'Ciliogenesis-associated TTC17-interacting protein, dimerization/docking domain',
#  'IPR017665': 'Guanylate kinase',
#  'IPR012724': 'Chaperone DnaJ',
#  'IPR001305': 'Heat shock protein DnaJ, cysteine-rich domain',
#  'IPR018253': 'DnaJ domain, conserved site',
#  'IPR002939': 'Chaperone DnaJ, C-terminal',
#  'IPR036410': 'Heat shock protein DnaJ, cysteine-rich domain superfamily',
#  'IPR008971': 'HSP40/DnaJ peptide-binding',
#  'IPR016689': 'ESCRT-2 complex, Snf8',
#  'IPR040608': 'Snf8/Vps36 family',
#  'IPR001179': 'FKBP-type peptidyl-prolyl cis-trans isomerase domain',
#  'IPR046357': 'Peptidyl-prolyl cis-trans isomerase domain superfamily',
#  'IPR048278': 'Profilin',
#  'IPR036140': 'Profilin superfamily',
#  'IPR036188': 'FAD/NAD(P)-binding domain superfamily',
#  'IPR002937': 'Amine oxidase',
#  'IPR052387': 'Fibrocystin-related protein',
#  'IPR002909': 'IPT domain',
#  'IPR050391': 'Mitochondrial Metabolite Transporter',
#  'IPR024862': 'Transient receptor potential cation channel subfamily V',
#  'IPR037607': 'Diacylglycerol kinase',
#  'IPR017438': 'Inorganic polyphosphate/ATP-NAD kinase, N-terminal',
#  'IPR000756': 'Diacylglycerol kinase, accessory domain',
#  'IPR016064': 'NAD kinase/diacylglycerol kinase-like domain superfamily',
#  'IPR001206': 'Diacylglycerol kinase, catalytic domain',
#  'IPR001684': 'Large ribosomal subunit protein bL27',
#  'IPR029016': 'GAF-like domain superfamily',
#  'IPR010736': 'Sperm-tail PG-rich repeat',
#  'IPR021183': 'N-terminal acetyltransferase A, auxiliary subunit',
#  'IPR049560': 'SAM-dependent methyltransferase RsmB-F/NOP2-type, catalytic core',
#  'IPR001678': 'SAM-dependent methyltransferase RsmB-F/NOP2-type domain',
#  'IPR023267': 'RNA (C5-cytosine) methyltransferase',
#  'IPR001578': 'Peptidase C12, ubiquitin carboxyl-terminal hydrolase',
#  'IPR036959': 'Peptidase C12, ubiquitin carboxyl-terminal hydrolase superfamily',
#  'IPR000608': 'Ubiquitin-conjugating enzyme E2',
#  'IPR016135': 'Ubiquitin-conjugating enzyme/RWD-like',
#  'IPR050113': 'Ubiquitin-conjugating enzyme',
#  'IPR016039': 'Thiolase-like',
#  'IPR020617': 'Thiolase, C-terminal',
#  'IPR002155': 'Thiolase',
#  'IPR020613': 'Thiolase, conserved site',
#  'IPR020610': 'Thiolase, active site',
#  'IPR020616': 'Thiolase, N-terminal',
#  'IPR028796': 'Tetratricopeptide repeat protein 8',
#  'IPR000308': '14-3-3 protein',
#  'IPR036815': '14-3-3 domain superfamily',
#  'IPR023410': '14-3-3 domain',
#  'IPR029151': 'Periplasmic sensor-like domain superfamily',
#  'IPR029023': 'Tensin-type phosphatase domain',
#  'IPR029021': 'Protein-tyrosine phosphatase-like',
#  'IPR003595': 'Protein-tyrosine phosphatase, catalytic',
#  'IPR020422': 'Dual specificity protein phosphatase domain',
#  'IPR000387': 'Tyrosine-specific protein phosphatases domain',
#  'IPR014020': 'Tensin phosphatase, C2 domain',
#  'IPR051281': 'Dual-specificity lipid and protein phosphatase',
#  'IPR000340': 'Dual specificity phosphatase, catalytic domain',
#  'IPR016130': 'Protein-tyrosine phosphatase, active site',
#  'IPR036852': 'Peptidase S8/S53 domain superfamily',
#  'IPR000209': 'Peptidase S8/S53 domain',
#  'IPR014044': 'CAP domain',
#  'IPR001283': 'Cysteine-rich secretory protein-related',
#  'IPR002413': 'Venom allergen 5-like',
#  'IPR035940': 'CAP superfamily',
#  'IPR026082': 'ABC transporter A',
#  'IPR005248': 'Nicotinate/nicotinamide nucleotide adenylyltransferase',
#  'IPR004821': 'Cytidyltransferase-like domain',
#  'IPR052394': 'Leucine-rich repeat-containing protein',
#  'IPR001884': 'Translation elongation factor IF5A-like',
#  'IPR020189': 'Translation elongation factor, IF5A C-terminal',
#  'IPR014722': 'Large ribosomal subunit protein uL2, domain 2',
#  'IPR008991': 'Translation protein SH3-like domain superfamily',
#  'IPR048670': 'Translation initiation factor 5A-like, N-terminal',
#  'IPR013238': 'RNA polymerase III, subunit Rpc25',
#  'IPR045113': 'RNA polymerase subunit Rpb7-like',
#  'IPR036898': 'RNA polymerase Rpb7-like, N-terminal domain superfamily',
#  'IPR011047': 'Quinoprotein alcohol dehydrogenase-like superfamily',
#  'IPR052066': 'Glycosphingolipid Hydrolyzing Enzymes',
#  'IPR041036': 'Glycoside hydrolase family 5, C-terminal domain',
#  'IPR017853': 'Glycoside hydrolase superfamily',
#  'IPR013780': 'Glycosyl hydrolase, all-beta',
#  'IPR001547': 'Glycoside hydrolase, family 5',
#  'IPR007397': 'F-box associated (FBA) domain',
#  'IPR001229': 'Jacalin-like lectin domain',
#  'IPR036404': 'Jacalin-like lectin domain superfamily',
#  'IPR012716': 'T-complex protein 1, beta subunit',
#  'IPR037519': 'LITAF domain containing protein',
#  'IPR006629': 'LPS-induced tumour necrosis factor alpha factor',
#  'IPR036938': 'Phosphatidic acid phosphatase type 2/haloperoxidase superfamily',
#  'IPR000326': 'Phosphatidic acid phosphatase type 2/haloperoxidase',
#  'IPR004254': 'AdipoR/Haemolysin-III-related',
#  'IPR019448': 'NT-type C2 domain',
#  'IPR003938': 'Potassium channel, voltage-dependent, EAG/ELK/ERG',
#  'IPR034752': 'Mis18 domain',
#  'IPR004910': 'Yippee/Mis18/Cereblon',
#  'IPR007248': 'Mpv17/PMP22',
#  'IPR051433': 'Calcium and Integrin-Binding',
#  'IPR050632': 'Nematode Cuticular Collagen',
#  'IPR006073': 'GTP binding domain',
#  'IPR052993': 'Cilia- and flagella-associated protein 57',
#  'IPR044635': 'Ubiquitin carboxyl-terminal hydrolase 14-like',
#  'IPR036875': 'Zinc finger, CCHC-type superfamily',
#  'IPR045550': 'Acylamino-acid-releasing enzyme, N-terminal domain',
#  'IPR001375': 'Peptidase S9, prolyl oligopeptidase, catalytic domain',
#  'IPR036910': 'High mobility group box domain superfamily',
#  'IPR009071': 'High mobility group box domain',
#  'IPR000225': 'Armadillo',
#  'IPR038905': 'Armadillo repeat-containing protein 2',
#  'IPR045133': 'Serine/threonine-protein kinase/endoribonuclease IRE1/2-like',
#  'IPR002498': 'Phosphatidylinositol-4-phosphate 4/5-kinase, core',
#  'IPR027484': 'Phosphatidylinositol-4-phosphate 5-kinase, N-terminal',
#  'IPR027483': 'Phosphatidylinositol-4-phosphate 4/5-kinase, C-terminal domain superfamily',
#  'IPR023610': 'Phosphatidylinositol-4/5-phosphate 5/4-kinase',
#  'IPR001727': 'GDT1-like',
#  'IPR024571': 'ERAP1-like C-terminal domain',
#  'IPR001930': 'Peptidase M1, alanine aminopeptidase/leukotriene A4 hydrolase',
#  'IPR050344': 'Peptidase M1 family aminopeptidases',
#  'IPR027268': 'Peptidase M4/M1, CTD superfamily',
#  'IPR014782': 'Peptidase M1, membrane alanine aminopeptidase',
#  'IPR024977': 'Anaphase-promoting complex subunit 4-like, WD40 domain',
#  'IPR002053': 'Glycoside hydrolase, family 25',
#  'IPR051595': 'Glycosyl Hydrolase 25 Enzymes',
#  'IPR008152': 'Clathrin adaptor, alpha/beta/gamma-adaptin, appendage, Ig-like subdomain',
#  'IPR013041': 'Clathrin adaptor, appendage, Ig-like subdomain superfamily',
#  'IPR052267': 'Nexin-Dynein Regulatory Complex Component',
#  'IPR003959': 'ATPase, AAA-type, core',
#  'IPR024135': 'Ragulator complex protein LAMTOR5',
#  'IPR002867': 'IBR domain',
#  'IPR044066': 'TRIAD supradomain',
#  'IPR031127': 'E3 ubiquitin ligase RBR family',
#  'IPR000560': 'Histidine phosphatase superfamily, clade-2',
#  'IPR050645': 'Histidine Acid Phosphatase',
#  'IPR033379': 'Histidine acid phosphatase active site',
#  'IPR000889': 'Glutathione peroxidase',
#  'IPR011331': 'Large ribosomal subunit protein eL37/eL43',
#  'IPR048395': 'Glycosyl hydrolase family 31, C-terminal domain',
#  'IPR011013': 'Galactose mutarotase-like domain superfamily',
#  'IPR030458': 'Glycosyl hydrolases family 31, active site',
#  'IPR000322': 'Glycoside hydrolase family 31, TIM barrel domain',
#  'IPR000195': 'Rab-GAP-TBC domain',
#  'IPR050302': 'Rab GTPase-activating TBC domain-containing protein',
#  'IPR035969': 'Rab-GAP-TBC domain superfamily',
#  'IPR053238': 'RING-H2 finger domain-containing protein',
#  'IPR040626': 'Cytosolic carboxypeptidase, N-terminal',
#  'IPR000834': 'Peptidase M14, carboxypeptidase A',
#  'IPR050821': 'Cytosolic carboxypeptidase',
#  'IPR023270': 'tRNA (C5-cytosine) methyltransferase, NCL1',
#  'IPR001345': 'Phosphoglycerate/bisphosphoglycerate mutase, active site',
#  'IPR052765': 'Phosphoglycerate Mutase-Related',
#  'IPR039058': 'Yippee family',
#  'IPR034751': 'Yippee domain',
#  'IPR006984': 'rRNA-processing protein Fcf1/Utp23',
#  'IPR029060': 'PIN-like domain superfamily',
#  'IPR008195': 'Large ribosomal subunit protein eL34',
#  'IPR018065': 'Large ribosomal subunit protein eL34, conserved site',
#  'IPR038508': 'ArfGAP domain superfamily',
#  'IPR001164': 'Arf GTPase activating protein',
#  'IPR037278': 'ARFGAP/RecO-like zinc finger',
#  'IPR009072': 'Histone-fold',
#  'IPR003958': 'Transcription factor CBF/NF-Y/archaeal histone domain',
#  'IPR042225': 'Negative cofactor 2 complex subunit beta',
#  'IPR045270': 'Serine/Threonine Kinase AGC, catalytic domain',
#  'IPR004316': 'Sugar transporter SWEET repeat',
#  'IPR047664': 'Sugar transporter SWEET',
#  'IPR005172': 'CRC domain',
#  'IPR044522': 'CRC domain-containing protein TSO1-like',
#  'IPR033467': 'Tesmin/TSO1-like CXC domain',
#  'IPR001876': 'Zinc finger, RanBP2-type',
#  'IPR036443': 'Zinc finger, RanBP2-type superfamily',
#  'IPR043130': 'CDP-alcohol phosphatidyltransferase, transmembrane domain',
#  'IPR014472': 'Choline/ethanolamine phosphotransferase',
#  'IPR000462': 'CDP-alcohol phosphatidyltransferase',
#  'IPR048254': 'CDP-alcohol phosphatidyltransferase, conserved site',
#  'IPR006032': 'Small ribosomal subunit protein uS12',
#  'IPR005680': 'Small ribosomal subunit protein uS12, eukaryotic/archaeal',
#  'IPR001972': 'Stomatin/HflK family',
#  'IPR052920': 'Potential DNA-binding regulatory protein',
#  'IPR000169': 'Cysteine peptidase, cysteine active site',
#  'IPR053710': 'Arylamine N-acetyltransferase domain-containing protein',
#  'IPR001447': 'Arylamine N-acetyltransferase',
#  'IPR005024': 'Snf7 family',
#  'IPR002490': 'V-type ATPase, V0 complex, 116kDa subunit family',
#  'IPR026028': 'ATPase, V0 complex, subunit 116kDa, eukaryotic',
#  'IPR052983': 'Major Facilitator Superfamily Riboflavin Transporter',
#  'IPR038792': 'CFAP97 domain-containing protein 1/2',
#  'IPR051787': 'Effector and Ciliary Development-Associated Protein',
#  'IPR014721': 'Small ribosomal subunit protein uS5 domain 2-type fold, subgroup',
#  'IPR020568': 'Ribosomal protein uS5 domain 2-type superfamily',
#  'IPR027065': 'Lon protease',
#  'IPR008269': 'Peptidase S16, Lon proteolytic domain',
#  'IPR008268': 'Peptidase S16, active site',
#  'IPR032847': 'Pre-mRNA-processing factor 17',
#  'IPR049549': '26S proteasome regulatory subunit RPN7/PSMD6, C-terminal helix',
#  'IPR000717': 'Proteasome component (PCI) domain',
#  'IPR045135': '26S proteasome regulatory subunit Rpn7, N-terminal',
#  'IPR019585': '26S proteasome regulatory subunit Rpn7/COP9 signalosome complex subunit 1',
#  'IPR007705': 'Vesicle transport v-SNARE, N-terminal',
#  'IPR038407': 'Vesicle transport v-SNARE, N-terminal domain superfamily',
#  'IPR036028': 'SH3-like domain superfamily',
#  'IPR001452': 'SH3 domain',
#  'IPR027159': 'Nuclear cap-binding protein subunit 1',
#  'IPR015174': 'MIF4G-like, type 2',
#  'IPR051581': 'Calcium-Binding Signaling',
#  'IPR002014': 'VHS domain',
#  'IPR003000': 'Sirtuin family',
#  'IPR026590': 'Sirtuin family, catalytic core domain',
#  'IPR050134': 'NAD-dependent sirtuin protein deacylases',
#  'IPR029035': 'DHS-like NAD/FAD-binding domain superfamily',
#  'IPR019359': 'CCDC85 family',
#  'IPR004033': 'UbiE/COQ5 methyltransferase',
#  'IPR023576': 'UbiE/COQ5 methyltransferase, conserved site',
#  'IPR036641': 'HPT domain superfamily',
#  'IPR036291': 'NAD(P)-binding domain superfamily',
#  'IPR037191': 'VPS9 domain superfamily',
#  'IPR003123': 'VPS9 domain',
#  'IPR045046': 'Vacuolar protein sorting-associated protein 9-like',
#  'IPR001900': 'Ribonuclease II/R',
#  'IPR022966': 'Ribonuclease II/R, conserved site',
#  'IPR050180': 'RNR Ribonuclease',
#  'IPR041505': 'Dis3-like cold-shock domain 2',
#  'IPR001660': 'Sterile alpha motif domain',
#  'IPR013761': 'Sterile alpha motif/pointed domain superfamily',
#  'IPR002562': "3'-5' exonuclease domain",
#  'IPR012588': 'Exosome-associated factor Rrp6, N-terminal',
#  'IPR045092': 'Exosome complex exonuclease Rrp6-like',
#  'IPR002121': 'HRDC domain',
#  'IPR044876': 'HRDC domain superfamily',
#  'IPR049559': "Rrp6-like, 3'-5' exonuclease domain",
#  'IPR010997': 'HRDC-like superfamily',
#  'IPR040134': '26S Proteasome non-ATPase regulatory subunit 12/COP9 signalosome complex subunit 4',
#  'IPR002016': 'Haem peroxidase',
#  'IPR010255': 'Haem peroxidase superfamily',
#  'IPR019794': 'Peroxidase, active site',
#  'IPR002207': 'Class I peroxidase',
#  'IPR044831': 'Heme-binding peroxidase Ccp1-like',
#  'IPR051728': 'RING-FYVE domain-containing E3 ubiquitin-protein ligase',
#  'IPR027443': 'Isopenicillin N synthase-like superfamily',
#  'IPR031712': 'Domain of unknown function DUF5077',
#  'IPR021862': 'Protein of unknown function DUF3472',
#  'IPR013216': 'Methyltransferase type 11',
#  'IPR006012': 'Syntaxin/epimorphin, conserved site',
#  'IPR006011': 'Syntaxin, N-terminal domain',
#  'IPR001708': 'Membrane insertase YidC/ALB3/OXA1/COX18',
#  'IPR028055': 'Membrane insertase YidC/Oxa/ALB, C-terminal',
#  'IPR044712': 'NAD/FAD transporter SLC25A32-like',
#  'IPR051876': 'Outer dynein arm-docking/Coiled-coil domain-containing protein',
#  'IPR049258': 'ODAD1, central coiled coil region',
#  'IPR001252': 'Malate dehydrogenase, active site',
#  'IPR010945': 'Malate dehydrogenase, type 2',
#  'IPR001557': 'L-lactate/malate dehydrogenase',
#  'IPR015955': 'Lactate dehydrogenase/glycoside hydrolase, family 4, C-terminal',
#  'IPR001236': 'Lactate/malate dehydrogenase, N-terminal',
#  'IPR022383': 'Lactate/malate dehydrogenase, C-terminal',
#  'IPR009053': 'Prefoldin',
#  'IPR052255': 'RNA polymerase II subunit 5-mediating protein',
#  'IPR004127': 'Prefoldin alpha-like',
#  'IPR046341': 'SET domain superfamily',
#  'IPR041355': 'Pre-SET CXC domain',
#  'IPR026489': 'CXC domain',
#  'IPR001214': 'SET domain',
#  'IPR045318': 'Histone-lysine N-methyltransferase EZH1/2-like',
#  'IPR002589': 'Macro domain',
#  'IPR043472': 'Macro domain-like',
#  'IPR050285': 'STE20 Serine/Threonine-Protein Kinase',
#  'IPR001365': 'Adenosine deaminase domain',
#  'IPR006330': 'Adenosine/adenine deaminase',
#  'IPR032466': 'Metal-dependent hydrolase',
#  'IPR001293': 'Zinc finger, TRAF-type',
#  'IPR052056': 'Mono-ADP-ribosyltransferase ARTD/PARP',
#  'IPR010729': 'Large ribosomal subunit protein uL29m, mitochondrial',
#  'IPR038340': 'MRP-L47 superfamily, mitochondrial',
#  'IPR036049': 'Large ribosomal subunit protein uL29 superfamily',
#  'IPR051330': 'Phosphatase regulators and Met sulfoxide reductases',
#  'IPR003018': 'GAF domain',
#  'IPR000943': 'RNA polymerase sigma-70',
#  'IPR023352': 'Membrane associated eicosanoid/glutathione metabolism-like domain superfamily',
#  'IPR001129': 'Membrane-associated, eicosanoid/glutathione metabolism (MAPEG) protein',
#  'IPR005651': 'Trm112-like',
#  'IPR039127': 'Multifunctional methyltransferase subunit Trm112',
#  'IPR050956': 'Two-component system histidine kinase',
#  'IPR000740': 'GrpE nucleotide exchange factor',
#  'IPR013805': 'GrpE nucleotide exchange factor, coiled-coil',
#  'IPR009012': 'GrpE nucleotide exchange factor, head',
#  'IPR002113': 'ADP/ATP carrier protein, eukaryotic type',
#  'IPR002067': 'Mitochondrial carrier protein',
#  'IPR007149': 'Leo1-like protein',
#  'IPR002893': 'Zinc finger, MYND-type',
#  'IPR012580': 'NUC153',
#  'IPR040382': 'Nucleolar protein 10/Enp2',
#  'IPR039241': 'Ribosomal RNA-processing protein Rrp9-like',
#  'IPR009360': 'Pre-mRNA-splicing factor Isy1',
#  'IPR037200': 'Pre-mRNA-splicing factor Isy1 superfamily',
#  'IPR029012': 'Helix hairpin bin domain superfamily',
#  'IPR053708': 'Eukaryotic Ribosomal Large Subunit eL42',
#  'IPR011332': 'Zinc-binding ribosomal protein',
#  'IPR000552': 'Large ribosomal subunit protein eL42',
#  'IPR051752': 'Mitochondrial 2-oxodicarboxylate carrier',
#  'IPR011249': 'Metalloenzyme, LuxS/M16 peptidase-like',
#  'IPR050361': 'Mitochondrial Processing Peptidase/Ubiquinol-cytochrome c Reductase Complex',
#  'IPR007863': 'Peptidase M16, C-terminal',
#  'IPR045149': 'Protein OS-9-like',
#  'IPR000210': 'BTB/POZ domain',
#  'IPR011333': 'SKP1/BTB/POZ domain superfamily',
#  'IPR052803': 'Primary Cilium-Associated Jouberin',
#  'IPR013520': 'Exonuclease, RNase T/DNA polymerase III',
#  'IPR051274': "3'-5' Exoribonuclease",
#  'IPR047201': "ERI-1-like, DEDDh 3'-5' exonuclease domain",
#  'IPR043601': 'R-spondin, Fu-CRD domain',
#  'IPR011761': 'ATP-grasp fold',
#  'IPR002933': 'Peptidase M20',
#  'IPR051458': 'Cytosolic and Metallo Dipeptidase',
#  'IPR047002': 'T-complex protein 10, C-terminal domain superfamily',
#  'IPR009852': 'Centromere protein J, C-terminal domain',
#  'IPR026581': 'T-complex protein 10 family',
#  'IPR018767': 'Brl1/Brr6 domain',
#  'IPR038358': 'VPS28, N-terminal domain superfamily',
#  'IPR007143': 'Vacuolar protein sorting-associated Vps28',
#  'IPR037202': 'ESCRT assembly domain',
#  'IPR043313': 'Leucine-rich melanocyte differentiation-associated protein',
#  'IPR036430': 'Ribonuclease T2-like superfamily',
#  'IPR001568': 'Ribonuclease T2-like',
#  'IPR006539': 'P-type ATPase, subfamily IV',
#  'IPR032630': 'P-type ATPase, C-terminal',
#  'IPR032631': 'P-type ATPase, N-terminal',
#  'IPR044570': 'Histone-lysine N-methyltransferase Set1-like',
#  'IPR006544': 'P-type ATPase, subfamily V',
#  'IPR032714': 'Cilium assembly protein DZIP1, N-terminal',
#  'IPR051241': 'DZIP and RILPL',
#  'IPR001279': 'Metallo-beta-lactamase',
#  'IPR012317': 'Poly(ADP-ribose) polymerase, catalytic domain',
#  'IPR041466': 'Dynein heavy chain, AAA 5 extension domain',
#  'IPR026983': 'Dynein heavy chain',
#  'IPR035699': 'Dynein heavy chain, hydrolytic ATP-binding dynein motor region',
#  'IPR049899': 'Zinc finger, C2HC/C3H-type',
#  'IPR026319': 'Zinc finger C2HC domain-containing protein 1A/B-like',
#  'IPR024156': 'Small GTPase superfamily, ARF type',
#  'IPR006689': 'Small GTPase superfamily, ARF/SAR type',
#  'IPR051195': 'Fungal stress response NST1',
#  'IPR003653': 'Ulp1 protease family, C-terminal catalytic domain',
#  'IPR044613': 'NEDD8-specific protease 1/2-like',
#  'IPR000407': 'Nucleoside phosphatase GDA1/CD39',
#  'IPR045081': 'Acidic leucine-rich nuclear phosphoprotein 32',
#  'IPR013112': 'FAD-binding 8',
#  'IPR013130': 'Ferric reductase transmembrane component-like domain',
#  'IPR039261': 'Ferredoxin-NADP reductase (FNR), nucleotide-binding domain',
#  'IPR017927': 'FAD-binding domain, ferredoxin reductase-type',
#  'IPR050369': 'Respiratory burst oxidase/Ferric reductase',
#  'IPR017938': 'Riboflavin synthase-like beta-barrel',
#  'IPR013121': 'Ferric reductase, NAD binding domain',
#  'IPR045267': 'Cyclin-dependent kinase 11/PITSLRE, catalytic domain',
#  'IPR050108': 'Cyclin-dependent kinase',
#  'IPR009670': 'Cell surface immobilisation antigen SerH',
#  'IPR003838': 'ABC3 transporter permease protein domain',
#  'IPR052818': 'NEDD1 Spindle Assembly Protein',
#  'IPR050600': 'SETD3/SETD6 methyltransferase',
#  'IPR030616': 'Aurora kinase-like',
#  'IPR006758': 'Poxvirus A32',
#  'IPR035014': 'cGMP-dependent protein kinase, catalytic domain',
#  'IPR000961': 'AGC-kinase, C-terminal',
#  'IPR051685': 'Ycf3/AcsC/BcsC/TPR Multifunctional',
#  'IPR052259': 'Nucleoredoxin-like',
#  'IPR012336': 'Thioredoxin-like fold',
#  'IPR001607': 'Zinc finger, UBP-type',
#  'IPR033809': 'USP39',
#  'IPR050185': 'Ubiquitin carboxyl-terminal hydrolase',
#  'IPR011048': 'Cytochrome cd1-nitrite reductase-like, haem d1 domain superfamily',
#  'IPR007130': 'Diacylglycerol acyltransferase',
#  'IPR043519': 'Nucleotidyltransferase superfamily',
#  'IPR002401': 'Cytochrome P450, E-class, group I',
#  'IPR013180': 'Beta-catenin-like protein 1, N-terminal',
#  'IPR039678': 'Beta-catenin-like protein 1',
#  'IPR014352': 'FERM/acyl-CoA-binding protein superfamily',
#  'IPR000582': 'Acyl-CoA-binding protein, ACBP',
#  'IPR035984': 'Acyl-CoA binding protein superfamily',
#  'IPR033471': 'DIRP domain',
#  'IPR010561': 'Protein LIN-9/Protein ALWAYS EARLY',
#  'IPR015946': 'K homology domain-like, alpha/beta',
#  'IPR036102': 'OsmC/Ohr superfamily',
#  'IPR003718': 'OsmC/Ohr family',
#  'IPR052924': 'OsmC/Ohr hydroperoxide reductase',
#  'IPR001932': 'PPM-type phosphatase-like domain',
#  'IPR047113': 'Proliferation-associated protein 2G4/ARX1',
#  'IPR036457': 'PPM-type phosphatase-like domain superfamily',
#  'IPR000222': 'PPM-type phosphatase, divalent cation binding',
#  'IPR008380': "HAD-superfamily hydrolase, subfamily IG, 5'-nucleotidase",
#  'IPR020904': 'Short-chain dehydrogenase/reductase, conserved site',
#  'IPR002347': 'Short-chain dehydrogenase/reductase SDR',
#  'IPR039192': 'Glycogen synthase kinase 3, catalytic domain',
#  'IPR050591': 'Glycogen Synthase Kinase-3',
#  'IPR030379': 'Septin-type guanine nucleotide-binding (G) domain',
#  'IPR015341': 'Glycoside hydrolase family 38, central domain',
#  'IPR000602': 'Glycoside hydrolase family 38, N-terminal domain',
#  'IPR050843': 'Glycosyl Hydrolase Family 38',
#  'IPR028995': 'Glycoside hydrolase families 57/38, central domain superfamily',
#  'IPR011682': 'Glycosyl hydrolase family 38, C-terminal',
#  'IPR037094': 'Glycoside hydrolase family 38, central domain superfamily',
#  'IPR011330': 'Glycoside hydrolase/deacetylase, beta/alpha-barrel',
#  'IPR027291': 'Glycoside hydrolase 38, N-terminal domain superfamily',
#  'IPR000620': 'EamA domain',
#  'IPR001368': 'TNFR/NGFR cysteine-rich region',
#  'IPR011641': 'Tyrosine-protein kinase ephrin type A/B receptor-like',
#  'IPR027815': 'CSC1/OSCA1-like, cytosolic domain',
#  'IPR044770': 'Protein spinster-like',
#  'IPR017452': 'GPCR, rhodopsin-like, 7TM',
#  'IPR017981': 'GPCR, family 2-like, 7TM',
#  'IPR022343': 'GCR1-cAMP receptor',
#  'IPR022340': 'G protein-coupled receptor GCR1 putative',
#  'IPR022127': 'Store-operated calcium entry regulator STIMATE/YPL162C',
#  'IPR037696': 'Coiled-coil domain-containing protein 77',
#  'IPR053209': 'Gramillin-biosynthesis-related methyltransferase',
#  'IPR004324': 'Folate-biopterin transporter',
#  'IPR039309': 'Biopterin transporter family',
#  'IPR051696': 'DENN Domain-Containing GEFs',
#  'IPR006876': 'LMBR1-like membrane protein',
#  'IPR051584': 'GPCR-associated LMBR1 domain-containing protein',
#  'IPR015324': 'Ribosomal protein Rsm22-like',
#  'IPR052571': 'Mitochondrial RNA Methyltransferase',
#  'IPR003609': 'PAN/Apple domain',
#  'IPR006353': 'HAD-superfamily hydrolase, subfamily IIA, CECR5',
#  'IPR006357': 'HAD-superfamily hydrolase, subfamily IIA',
#  'IPR050324': 'CDP-alcohol phosphatidyltransferase class-I',
#  'IPR005033': 'YEATS',
#  'IPR038704': 'YEATS superfamily',
#  'IPR016487': 'Sm-like protein Lsm6/SmF',
#  'IPR052769': 'Tetratricopeptide repeat domain-containing protein',
#  'IPR023753': 'FAD/NAD(P)-binding domain',
#  'IPR053275': 'Agnestin biosynthesis monooxygenase',
#  'IPR045028': 'Helicase superfamily 1/2, DinG/Rad3-like',
#  'IPR013020': 'ATP-dependent helicase Rad3/Chl1-like',
#  'IPR010614': 'RAD3-like helicase, DEAD',
#  'IPR014013': 'Helicase superfamily 1/2, ATP-binding domain, DinG/Rad3-type',
#  'IPR006554': 'Helicase-like, DEXD box c2 type',
#  'IPR006555': 'ATP-dependent helicase, C-terminal',
#  'IPR007111': 'NACHT nucleoside triphosphatase',
#  'IPR002159': 'CD36 family',
#  'IPR012945': 'Tubulin binding cofactor C-like domain',
#  'IPR031925': 'Tubulin-specific chaperone C, N-terminal',
#  'IPR016098': 'Cyclase-associated protein CAP/septum formation inhibitor MinC, C-terminal',
#  'IPR027684': 'Tubulin-specific chaperone C',
#  'IPR038397': 'TBCC, N-terminal domain superfamily',
#  'IPR017901': 'C-CAP/cofactor C-like domain',
#  'IPR027524': 'Eukaryotic translation initiation factor 3 subunit H',
#  'IPR050242': 'JAMM/MPN+ metalloenzymes, peptidase M67A',
#  'IPR037518': 'MPN domain',
#  'IPR000555': 'JAB1/MPN/MOV34 metalloenzyme domain',
#  'IPR045810': 'eIF3h, C-terminal',
#  'IPR001300': 'Peptidase C2, calpain, catalytic domain',
#  'IPR050420': 'Calpain',
#  'IPR022684': 'Peptidase C2, calpain family',
#  'IPR052454': 'Thioredoxin-related transmembrane domain-containing protein',
#  'IPR003663': 'Sugar/inositol transporter',
#  'IPR050360': 'Major Facilitator Superfamily Sugar Transporters',
#  'IPR050346': 'Flavin-containing Monooxygenases',
#  'IPR020946': 'Flavin monooxygenase-like',
#  'IPR018866': 'Zinc-finger domain of monoamine-oxidase A repressor R1',
#  'IPR001736': 'Phospholipase D/Transphosphatidylase',
#  'IPR001683': 'Phox homology',
#  'IPR025202': 'Phospholipase D-like domain',
#  'IPR036871': 'PX domain superfamily',
#  'IPR016555': 'Phospholipase D, eukaryotic type',
#  'IPR015679': 'Phospholipase D family',
#  'IPR000182': 'GNAT domain',
#  'IPR045141': 'N-alpha-acetyltransferase 60-like',
#  'IPR016181': 'Acyl-CoA N-acyltransferase',
#  'IPR016439': 'Sphingosine N-acyltransferase Lag1/Lac1-like',
#  'IPR006634': 'TRAM/LAG1/CLN8 homology domain',
#  'IPR008030': 'NmrA-like domain',
#  'IPR051164': 'NmrA-like oxidoreductase',
#  'IPR041888': 'ZN598/Hel2, RING finger',
#  'IPR044288': 'E3 ubiquitin-protein ligase ZNF598/Hel2',
#  'IPR001593': 'Small ribosomal subunit protein eS1',
#  'IPR027500': 'Small ribosomal subunit protein eS1, eukaryotes',
#  'IPR018281': 'Small ribosomal subunit protein eS1, conserved site',
#  'IPR036691': 'Endonuclease/exonuclease/phosphatase superfamily',
#  'IPR011042': 'Six-bladed beta-propeller, TolB-like',
#  'IPR004000': 'Actin family',
#  ...}

# %%
interpro_desc_list = list(interpro_desc_dict.items())

interpro_desc_df = pd.DataFrame(interpro_desc_list, columns=['InterPro', 'InterPro_description'])

# %%
interpro_desc_df.head()
# Out:
#     InterPro                              InterPro_description
# 0          -                                                 -
# 1  IPR001594                 Palmitoyltransferase, DHHC domain
# 2  IPR001810                                      F-box domain
# 3  IPR006553  Leucine-rich repeat, cysteine-containing subtype
# 4  IPR036047                     F-box-like domain superfamily

# %%
interpro_desc_df.sort_values(by='InterPro').to_csv('../../active_files/interpro_annotations.csv', index=False)

# %%
interpro_dict = {
        'TTHERM_ID': [],
        'InterPro': [],
}

for id in annot_df_raw['Protein accession'].unique():

    curr_df = annot_df_raw.loc[annot_df_raw['Protein accession'] == id]

    ipaa = sorted(list(curr_df['InterPro annotations - accession'].unique()))

    interpro_dict['TTHERM_ID'].append(id)
    interpro_dict['InterPro'].append(
                                                            ','.join(ipaa[1: ])
                                                            if len(ipaa) > 1 and ipaa[0] == '-' else ipaa[0]
                                                            )
    
interpro_df = pd.DataFrame(interpro_dict)

# %%
interpro_df.sample(20)
# Out:
#              TTHERM_ID                                           InterPro
# 1493   TTHERM_00773750  IPR001680,IPR015943,IPR019775,IPR036322,IPR050687
# 5022   TTHERM_01002840  IPR001789,IPR003594,IPR003661,IPR004358,IPR005...
# 6540   TTHERM_00131160                                                  -
# 14491  TTHERM_00313330                                                  -
# 12741  TTHERM_00187060                                                  -
# 3112   TTHERM_00502410            IPR000595,IPR014710,IPR018490,IPR043533
# 2425   TTHERM_00666970                                                  -
# 13244  TTHERM_00759520                                          IPR032675
# 6235   TTHERM_01262820  IPR006595,IPR013083,IPR024964,IPR027370,IPR037...
# 10847  TTHERM_00826850  IPR000595,IPR013099,IPR014710,IPR018490,IPR050818
# 11380  TTHERM_00081120                      IPR001841,IPR013083,IPR050731
# 9717   TTHERM_00689965            IPR001841,IPR011016,IPR013083,IPR052788
# 228    TTHERM_00895610                                          IPR003388
# 3391   TTHERM_00956400                      IPR001611,IPR027038,IPR032675
# 1374   TTHERM_00455510  IPR001611,IPR002110,IPR003591,IPR032675,IPR036...
# 18067  TTHERM_00526260                                          IPR000315
# 17916  TTHERM_01489720                      IPR001611,IPR027038,IPR032675
# 11143  TTHERM_01092415                                                  -
# 2324   TTHERM_01108710                                IPR002110,IPR036770
# 7653   TTHERM_00492840  IPR002048,IPR011992,IPR018247,IPR025663,IPR053084

# %%
interpro_df.shape
# Out:
# (21654, 2)

# %%
interpro_df = interpro_df.loc[
    (interpro_df['InterPro'] != '-')
    # &
    # (interpro_df['InterPro annotations - description'] != '-')
    # |
    # (interpro_df['InterPro annotations - description'] != '-')
]

# %%
interpro_df
# Out:
#              TTHERM_ID                                           InterPro
# 1      TTHERM_00581830                                          IPR001594
# 3      TTHERM_00522350            IPR001810,IPR006553,IPR032675,IPR036047
# 4      TTHERM_00624190                                          IPR004344
# 5      TTHERM_01370770  IPR000719,IPR001611,IPR011009,IPR027038,IPR032675
# 6      TTHERM_00522360                                          IPR011701
# ...                ...                                                ...
# 21645  TTHERM_00263110                      IPR007421,IPR029684,IPR038461
# 21646  TTHERM_00408770                                IPR006212,IPR009030
# 21649  TTHERM_00939130                                          IPR032675
# 21650  TTHERM_00698680                                IPR013087,IPR036236
# 21651  TTHERM_00294840  IPR001045,IPR029063,IPR030374,IPR035246,IPR037163
#
# [15624 rows x 2 columns]

# %%
dataframe_utils.sql_query_df({'interpro_df': interpro_df}, 'select * from interpro_df where InterPro not like "%IPR%"')
# Out:
# Empty DataFrame
# Columns: [TTHERM_ID, InterPro]
# Index: []

# %%
interpro_df.sort_values(by='TTHERM_ID').to_csv('../../active_files/interpro_annot.csv', index=False)
