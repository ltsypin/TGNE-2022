# %%
import pandas as pd
from glob import glob
import sys

sys.path.append('../../')
from utils import dataframe_utils

# %%
annot_files_raw = glob('./**/*.tsv')
annot_files_raw
# Out:
# ['./jul01/pep_frag_173.fasta.tsv',
#  './jul01/pep_frag_035.fasta.tsv',
#  './jul01/pep_frag_086.fasta.tsv',
#  './jul01/pep_frag_109.fasta.tsv',
#  './jul01/pep_frag_092.fasta.tsv',
#  './jul01/pep_frag_021.fasta.tsv',
#  './jul01/pep_frag_167.fasta.tsv',
#  './jul01/pep_frag_000.fasta.tsv',
#  './jul01/pep_frag_146.fasta.tsv',
#  './jul01/pep_frag_152.fasta.tsv',
#  './jul01/pep_frag_014.fasta.tsv',
#  './jul01/pep_frag_128.fasta.tsv',
#  './jul01/pep_frag_038.fasta.tsv',
#  './jul01/pep_frag_104.fasta.tsv',
#  './jul01/pep_frag_042.fasta.tsv',
#  './jul01/pep_frag_056.fasta.tsv',
#  './jul01/pep_frag_110.fasta.tsv',
#  './jul01/pep_frag_077.fasta.tsv',
#  './jul01/pep_frag_131.fasta.tsv',
#  './jul01/pep_frag_182.fasta.tsv',
#  './jul01/pep_frag_019.fasta.tsv',
#  './jul01/pep_frag_196.fasta.tsv',
#  './jul01/pep_frag_125.fasta.tsv',
#  './jul01/pep_frag_063.fasta.tsv',
#  './jul01/pep_frag_189.fasta.tsv',
#  './jul01/pep_frag_140.fasta.tsv',
#  './jul01/pep_frag_006.fasta.tsv',
#  './jul01/pep_frag_068.fasta.tsv',
#  './jul01/pep_frag_012.fasta.tsv',
#  './jul01/pep_frag_154.fasta.tsv',
#  './jul01/pep_frag_049.fasta.tsv',
#  './jul01/pep_frag_080.fasta.tsv',
#  './jul01/pep_frag_033.fasta.tsv',
#  './jul01/pep_frag_175.fasta.tsv',
#  './jul01/pep_frag_161.fasta.tsv',
#  './jul01/pep_frag_027.fasta.tsv',
#  './jul01/pep_frag_094.fasta.tsv',
#  './jul01/pep_frag_184.fasta.tsv',
#  './jul01/pep_frag_137.fasta.tsv',
#  './jul01/pep_frag_071.fasta.tsv',
#  './jul01/pep_frag_065.fasta.tsv',
#  './jul01/pep_frag_123.fasta.tsv',
#  './jul01/pep_frag_159.fasta.tsv',
#  './jul01/pep_frag_190.fasta.tsv',
#  './jul01/pep_frag_044.fasta.tsv',
#  './jul01/pep_frag_102.fasta.tsv',
#  './jul01/pep_frag_178.fasta.tsv',
#  './jul01/pep_frag_116.fasta.tsv',
#  './jul01/pep_frag_099.fasta.tsv',
#  './jul01/pep_frag_050.fasta.tsv',
#  './jul01/pep_frag_093.fasta.tsv',
#  './jul01/pep_frag_166.fasta.tsv',
#  './jul01/pep_frag_020.fasta.tsv',
#  './jul01/pep_frag_034.fasta.tsv',
#  './jul01/pep_frag_172.fasta.tsv',
#  './jul01/pep_frag_108.fasta.tsv',
#  './jul01/pep_frag_087.fasta.tsv',
#  './jul01/pep_frag_015.fasta.tsv',
#  './jul01/pep_frag_153.fasta.tsv',
#  './jul01/pep_frag_129.fasta.tsv',
#  './jul01/pep_frag_147.fasta.tsv',
#  './jul01/pep_frag_001.fasta.tsv',
#  './jul01/pep_frag_111.fasta.tsv',
#  './jul01/pep_frag_057.fasta.tsv',
#  './jul01/pep_frag_039.fasta.tsv',
#  './jul01/pep_frag_043.fasta.tsv',
#  './jul01/pep_frag_105.fasta.tsv',
#  './jul01/pep_frag_197.fasta.tsv',
#  './jul01/pep_frag_018.fasta.tsv',
#  './jul01/pep_frag_062.fasta.tsv',
#  './jul01/pep_frag_124.fasta.tsv',
#  './jul01/pep_frag_130.fasta.tsv',
#  './jul01/pep_frag_076.fasta.tsv',
#  './jul01/pep_frag_183.fasta.tsv',
#  './jul01/pep_frag_069.fasta.tsv',
#  './jul01/pep_frag_155.fasta.tsv',
#  './jul01/pep_frag_013.fasta.tsv',
#  './jul01/pep_frag_007.fasta.tsv',
#  './jul01/pep_frag_188.fasta.tsv',
#  './jul01/pep_frag_141.fasta.tsv',
#  './jul01/pep_frag_026.fasta.tsv',
#  './jul01/pep_frag_160.fasta.tsv',
#  './jul01/pep_frag_095.fasta.tsv',
#  './jul01/pep_frag_048.fasta.tsv',
#  './jul01/pep_frag_081.fasta.tsv',
#  './jul01/pep_frag_174.fasta.tsv',
#  './jul01/pep_frag_032.fasta.tsv',
#  './jul01/pep_frag_122.fasta.tsv',
#  './jul01/pep_frag_064.fasta.tsv',
#  './jul01/pep_frag_158.fasta.tsv',
#  './jul01/pep_frag_191.fasta.tsv',
#  './jul01/pep_frag_185.fasta.tsv',
#  './jul01/pep_frag_070.fasta.tsv',
#  './jul01/pep_frag_136.fasta.tsv',
#  './jul01/pep_frag_098.fasta.tsv',
#  './jul01/pep_frag_051.fasta.tsv',
#  './jul01/pep_frag_117.fasta.tsv',
#  './jul01/pep_frag_103.fasta.tsv',
#  './jul01/pep_frag_045.fasta.tsv',
#  './jul01/pep_frag_179.fasta.tsv',
#  './jul01/pep_frag_078.fasta.tsv',
#  './jul01/pep_frag_002.fasta.tsv',
#  './jul01/pep_frag_144.fasta.tsv',
#  './jul01/pep_frag_199.fasta.tsv',
#  './jul01/pep_frag_150.fasta.tsv',
#  './jul01/pep_frag_016.fasta.tsv',
#  './jul01/pep_frag_171.fasta.tsv',
#  './jul01/pep_frag_037.fasta.tsv',
#  './jul01/pep_frag_084.fasta.tsv',
#  './jul01/pep_frag_059.fasta.tsv',
#  './jul01/pep_frag_090.fasta.tsv',
#  './jul01/pep_frag_023.fasta.tsv',
#  './jul01/pep_frag_165.fasta.tsv',
#  './jul01/pep_frag_075.fasta.tsv',
#  './jul01/pep_frag_133.fasta.tsv',
#  './jul01/pep_frag_149.fasta.tsv',
#  './jul01/pep_frag_180.fasta.tsv',
#  './jul01/pep_frag_194.fasta.tsv',
#  './jul01/pep_frag_127.fasta.tsv',
#  './jul01/pep_frag_061.fasta.tsv',
#  './jul01/pep_frag_106.fasta.tsv',
#  './jul01/pep_frag_089.fasta.tsv',
#  './jul01/pep_frag_040.fasta.tsv',
#  './jul01/pep_frag_054.fasta.tsv',
#  './jul01/pep_frag_112.fasta.tsv',
#  './jul01/pep_frag_168.fasta.tsv',
#  './jul01/pep_frag_082.fasta.tsv',
#  './jul01/pep_frag_031.fasta.tsv',
#  './jul01/pep_frag_177.fasta.tsv',
#  './jul01/pep_frag_163.fasta.tsv',
#  './jul01/pep_frag_025.fasta.tsv',
#  './jul01/pep_frag_096.fasta.tsv',
#  './jul01/pep_frag_119.fasta.tsv',
#  './jul01/pep_frag_142.fasta.tsv',
#  './jul01/pep_frag_004.fasta.tsv',
#  './jul01/pep_frag_138.fasta.tsv',
#  './jul01/pep_frag_010.fasta.tsv',
#  './jul01/pep_frag_156.fasta.tsv',
#  './jul01/pep_frag_046.fasta.tsv',
#  './jul01/pep_frag_100.fasta.tsv',
#  './jul01/pep_frag_028.fasta.tsv',
#  './jul01/pep_frag_114.fasta.tsv',
#  './jul01/pep_frag_052.fasta.tsv',
#  './jul01/pep_frag_009.fasta.tsv',
#  './jul01/pep_frag_186.fasta.tsv',
#  './jul01/pep_frag_135.fasta.tsv',
#  './jul01/pep_frag_073.fasta.tsv',
#  './jul01/pep_frag_067.fasta.tsv',
#  './jul01/pep_frag_121.fasta.tsv',
#  './jul01/pep_frag_192.fasta.tsv',
#  './jul01/pep_frag_017.fasta.tsv',
#  './jul01/pep_frag_198.fasta.tsv',
#  './jul01/pep_frag_151.fasta.tsv',
#  './jul01/pep_frag_079.fasta.tsv',
#  './jul01/pep_frag_145.fasta.tsv',
#  './jul01/pep_frag_003.fasta.tsv',
#  './jul01/pep_frag_058.fasta.tsv',
#  './jul01/pep_frag_091.fasta.tsv',
#  './jul01/pep_frag_164.fasta.tsv',
#  './jul01/pep_frag_022.fasta.tsv',
#  './jul01/pep_frag_036.fasta.tsv',
#  './jul01/pep_frag_170.fasta.tsv',
#  './jul01/pep_frag_085.fasta.tsv',
#  './jul01/pep_frag_195.fasta.tsv',
#  './jul01/pep_frag_060.fasta.tsv',
#  './jul01/pep_frag_126.fasta.tsv',
#  './jul01/pep_frag_132.fasta.tsv',
#  './jul01/pep_frag_074.fasta.tsv',
#  './jul01/pep_frag_148.fasta.tsv',
#  './jul01/pep_frag_181.fasta.tsv',
#  './jul01/pep_frag_113.fasta.tsv',
#  './jul01/pep_frag_055.fasta.tsv',
#  './jul01/pep_frag_169.fasta.tsv',
#  './jul01/pep_frag_088.fasta.tsv',
#  './jul01/pep_frag_041.fasta.tsv',
#  './jul01/pep_frag_107.fasta.tsv',
#  './jul01/pep_frag_024.fasta.tsv',
#  './jul01/pep_frag_162.fasta.tsv',
#  './jul01/pep_frag_118.fasta.tsv',
#  './jul01/pep_frag_097.fasta.tsv',
#  './jul01/pep_frag_083.fasta.tsv',
#  './jul01/pep_frag_176.fasta.tsv',
#  './jul01/pep_frag_030.fasta.tsv',
#  './jul01/pep_frag_157.fasta.tsv',
#  './jul01/pep_frag_011.fasta.tsv',
#  './jul01/pep_frag_005.fasta.tsv',
#  './jul01/pep_frag_143.fasta.tsv',
#  './jul01/pep_frag_139.fasta.tsv',
#  './jul01/pep_frag_029.fasta.tsv',
#  './jul01/pep_frag_053.fasta.tsv',
#  './jul01/pep_frag_115.fasta.tsv',
#  './jul01/pep_frag_101.fasta.tsv',
#  './jul01/pep_frag_047.fasta.tsv',
#  './jul01/pep_frag_120.fasta.tsv',
#  './jul01/pep_frag_066.fasta.tsv',
#  './jul01/pep_frag_193.fasta.tsv',
#  './jul01/pep_frag_187.fasta.tsv',
#  './jul01/pep_frag_008.fasta.tsv',
#  './jul01/pep_frag_072.fasta.tsv',
#  './jul01/pep_frag_134.fasta.tsv',
#  './odd_jul01/odd_pep_frag_0.fasta.tsv']

# %%
columns = [
    "Protein accession",
    "Sequence MD5 digest",
    "Sequence length",
    "Analysis",
    "Signature accession",
    "Signature description",
    "Start location",
    "Stop location",
    "Score",
    "Status",
    "Date",
    "InterPro annotations - accession",
    "InterPro annotations - description",
    "GO annotations with their source(s)",
    "Pathways annotations"
]
len(columns)
# Out:
# 15

# %%
annot_df_raw = dataframe_utils.csv_files_to_df(annot_files_raw, sep='\t', cols=columns)
annot_df_raw
annot_df_raw['Protein accession'].values
# Out:
# array(['TTHERM_00541547', 'TTHERM_00541547', 'TTHERM_00541547', ...,
#        'TTHERM_00245160', 'TTHERM_00245160', 'TTHERM_00245160'],
#       dtype=object)

# %%
annot_df_raw
# Out:
#        Protein accession               Sequence MD5 digest  Sequence length  \
# 0        TTHERM_00541547  f07d6740e0003ef6fe12e459f21e761f             1221
# 1        TTHERM_00541547  f07d6740e0003ef6fe12e459f21e761f             1221
# 2        TTHERM_00541547  f07d6740e0003ef6fe12e459f21e761f             1221
# 3        TTHERM_00541547  f07d6740e0003ef6fe12e459f21e761f             1221
# 4        TTHERM_00541547  f07d6740e0003ef6fe12e459f21e761f             1221
# ...                  ...                               ...              ...
# 233202   TTHERM_00927401  65eeb2a7e98e049b64af46123ef13b7d              581
# 233203   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233204   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233205   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
# 233206   TTHERM_00245160  29c0c10a31c971f67381355224400f07              969
#
#            Analysis          Signature accession  \
# 0       SUPERFAMILY                     SSF57184
# 1            Gene3D            G3DSA:2.10.220.10
# 2            Gene3D            G3DSA:2.10.220.10
# 3       SUPERFAMILY                     SSF55486
# 4            FunFam  G3DSA:3.90.132.10:FF:000001
# ...             ...                          ...
# 233202        Coils                         Coil
# 233203   MobiDBLite                  mobidb-lite
# 233204   MobiDBLite                  mobidb-lite
# 233205   MobiDBLite                  mobidb-lite
# 233206   MobiDBLite                  mobidb-lite
#
#                                  Signature description  Start location  \
# 0                        Growth factor receptor domain             815
# 1                                                    -             661
# 2                                                    -            1082
# 3       Metalloproteases ("zincins"), catalytic domain              58
# 4             leishmanolysin-like peptidase isoform X2             120
# ...                                                ...             ...
# 233202                                            Coil             542
# 233203                   consensus disorder prediction             307
# 233204                   consensus disorder prediction             307
# 233205                   consensus disorder prediction             577
# 233206                   consensus disorder prediction              18
#
#         Stop location     Score Status        Date  \
# 0                 965  7.86E-21      T  02-07-2024
# 1                 753    3.2E-7      T  02-07-2024
# 2                1176    3.9E-8      T  02-07-2024
# 3                 380  3.56E-43      T  02-07-2024
# 4                 240   1.5E-29      T  02-07-2024
# ...               ...       ...    ...         ...
# 233202            562         -      T  08-07-2024
# 233203            326         -      T  08-07-2024
# 233204            323         -      T  08-07-2024
# 233205            612         -      T  08-07-2024
# 233206             80         -      T  08-07-2024
#
#        InterPro annotations - accession  \
# 0                             IPR009030
# 1                                     -
# 2                                     -
# 3                                     -
# 4                                     -
# ...                                 ...
# 233202                                -
# 233203                                -
# 233204                                -
# 233205                                -
# 233206                                -
#
#                        InterPro annotations - description  \
# 0       Growth factor receptor cysteine-rich domain su...
# 1                                                       -
# 2                                                       -
# 3                                                       -
# 4                                                       -
# ...                                                   ...
# 233202                                                  -
# 233203                                                  -
# 233204                                                  -
# 233205                                                  -
# 233206                                                  -
#
#        GO annotations with their source(s) Pathways annotations
# 0                                        -                    -
# 1                                        -                    -
# 2                                        -                    -
# 3                                        -                    -
# 4                                        -                    -
# ...                                    ...                  ...
# 233202                                   -                    -
# 233203                                   -                    -
# 233204                                   -                    -
# 233205                                   -                    -
# 233206                                   -                    -
#
# [233207 rows x 15 columns]

# %%
annot_df_raw.isna().any()
# Out:
# Protein accession                      False
# Sequence MD5 digest                    False
# Sequence length                        False
# Analysis                               False
# Signature accession                    False
# Signature description                  False
# Start location                         False
# Stop location                          False
# Score                                  False
# Status                                 False
# Date                                   False
# InterPro annotations - accession       False
# InterPro annotations - description     False
# GO annotations with their source(s)    False
# Pathways annotations                   False
# dtype: bool

# %%
interpro_desc_dict = {}

interpro_descs = annot_df_raw['InterPro annotations - description'].values

for idx, acc in enumerate(annot_df_raw['InterPro annotations - accession'].values):
    if acc in interpro_desc_dict and interpro_desc_dict[acc] != interpro_descs[idx]:
        raise(ValueError(f'InterPro annotation with accession={acc} has multiple descriptions:\n1. {interpro_desc_dict[acc]}\n2. {interpro_descs[idx]}\n...'))
    interpro_desc_dict[acc] = interpro_descs[idx]

# %%
interpro_desc_dict
# Out:
# {'IPR009030': 'Growth factor receptor cysteine-rich domain superfamily',
#  '-': '-',
#  'IPR006212': 'Furin-like repeat',
#  'IPR000742': 'EGF-like domain',
#  'IPR001577': 'Peptidase M8, leishmanolysin',
#  'IPR009851': 'Modifier of rudimentary, Modr',
#  'IPR014710': 'RmlC-like jelly roll fold',
#  'IPR000595': 'Cyclic nucleotide-binding domain',
#  'IPR051413': 'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel',
#  'IPR013099': 'Potassium channel domain',
#  'IPR018490': 'Cyclic nucleotide-binding domain superfamily',
#  'IPR041677': 'DNA2/NAM7 helicase, helicase domain',
#  'IPR027417': 'P-loop containing nucleoside triphosphate hydrolase',
#  'IPR045055': 'DNA2/NAM7-like helicase',
#  'IPR014001': 'Helicase superfamily 1/2, ATP-binding domain',
#  'IPR041679': 'DNA2/NAM7 helicase-like, C-terminal',
#  'IPR047187': 'Upf1-like, C-terminal helicase domain',
#  'IPR001752': 'Kinesin motor domain',
#  'IPR019821': 'Kinesin motor domain, conserved site',
#  'IPR036961': 'Kinesin motor domain superfamily',
#  'IPR027640': 'Kinesin-like protein',
#  'IPR016024': 'Armadillo-type fold',
#  'IPR000308': '14-3-3 protein',
#  'IPR036815': '14-3-3 domain superfamily',
#  'IPR023410': '14-3-3 domain',
#  'IPR044039': 'Domain of unknown function DUF5745',
#  'IPR043533': 'Cyclic nucleotide-binding domain-containing protein 1/2',
#  'IPR003938': 'Potassium channel, voltage-dependent, EAG/ELK/ERG',
#  'IPR005821': 'Ion transport domain',
#  'IPR018793': 'Cytochrome c oxidase assembly protein PET191',
#  'IPR011948': 'Dullard phosphatase domain, eukaryotic',
#  'IPR050365': 'Mitochondrial import inner membrane translocase subunit TIM50',
#  'IPR036412': 'HAD-like superfamily',
#  'IPR004274': 'FCP1 homology domain',
#  'IPR023214': 'HAD superfamily',
#  'IPR036259': 'MFS transporter superfamily',
#  'IPR052983': 'Major Facilitator Superfamily Riboflavin Transporter',
#  'IPR003000': 'Sirtuin family',
#  'IPR029035': 'DHS-like NAD/FAD-binding domain superfamily',
#  'IPR026590': 'Sirtuin family, catalytic core domain',
#  'IPR026591': 'Sirtuin, catalytic core small domain superfamily',
#  'IPR050134': 'NAD-dependent sirtuin protein deacylases',
#  'IPR032675': 'Leucine-rich repeat domain superfamily',
#  'IPR027038': 'Ran GTPase-activating protein',
#  'IPR001611': 'Leucine-rich repeat',
#  'IPR015655': 'Protein phosphatase 2C',
#  'IPR001932': 'PPM-type phosphatase-like domain',
#  'IPR036457': 'PPM-type phosphatase-like domain superfamily',
#  'IPR000222': 'PPM-type phosphatase, divalent cation binding',
#  'IPR000014': 'PAS domain',
#  'IPR052994': 'Tiny macrocysts signaling regulators',
#  'IPR035965': 'PAS domain superfamily',
#  'IPR001806': 'Small GTPase',
#  'IPR005225': 'Small GTP-binding protein domain',
#  'IPR004835': 'Chitin synthase',
#  'IPR004834': 'Fungal chitin synthase',
#  'IPR000719': 'Protein kinase domain',
#  'IPR011009': 'Protein kinase-like domain superfamily',
#  'IPR022953': 'ATP-dependent 6-phosphofructokinase',
#  'IPR035966': 'Phosphofructokinase superfamily',
#  'IPR000023': 'Phosphofructokinase domain',
#  'IPR050929': 'Phosphofructokinase type A',
#  'IPR036249': 'Thioredoxin-like superfamily',
#  'IPR036282': 'Glutathione S-transferase, C-terminal domain superfamily',
#  'IPR004045': 'Glutathione S-transferase, N-terminal',
#  'IPR040079': 'Glutathione transferase family',
#  'IPR004046': 'Glutathione S-transferase, C-terminal',
#  'IPR050213': 'Glutathione S-transferase superfamily',
#  'IPR010987': 'Glutathione S-transferase, C-terminal-like',
#  'IPR005946': 'Ribose-phosphate pyrophosphokinase',
#  'IPR029057': 'Phosphoribosyltransferase-like',
#  'IPR000836': 'Phosphoribosyltransferase domain',
#  'IPR029099': 'Ribose-phosphate pyrophosphokinase, N-terminal domain',
#  'IPR045160': 'Autophagy-related protein 16',
#  'IPR005874': 'Eukaryotic translation initiation factor SUI1',
#  'IPR001950': 'SUI1 domain',
#  'IPR036877': 'SUI1 domain superfamily',
#  'IPR019734': 'Tetratricopeptide repeat',
#  'IPR011990': 'Tetratricopeptide-like helical domain superfamily',
#  'IPR010989': 'SNARE',
#  'IPR000727': 'Target SNARE coiled-coil homology domain',
#  'IPR045242': 'Syntaxin',
#  'IPR006703': 'AIG1-type guanine nucleotide-binding (G) domain',
#  'IPR045058': 'GTPase GIMA/IAN/Toc',
#  'IPR001650': 'Helicase, C-terminal domain-like',
#  'IPR007502': 'Helicase-associated domain',
#  'IPR002464': 'DNA/RNA helicase, ATP-dependent, DEAH-box type, conserved site',
#  'IPR048333': 'Helicase associated domain (HA2), winged-helix domain',
#  'IPR011709': 'DEAD-box helicase, OB fold',
#  'IPR011545': 'DEAD/DEAH box helicase domain',
#  'IPR001841': 'Zinc finger, RING-type',
#  'IPR013083': 'Zinc finger, RING/FYVE/PHD-type',
#  'IPR038765': 'Papain-like cysteine peptidase superfamily',
#  'IPR035927': 'DUSP-like superfamily',
#  'IPR006615': 'Peptidase C19, ubiquitin-specific peptidase, DUSP domain',
#  'IPR002893': 'Zinc finger, MYND-type',
#  'IPR028889': 'Ubiquitin specific protease domain',
#  'IPR050185': 'Ubiquitin carboxyl-terminal hydrolase',
#  'IPR018200': 'Ubiquitin specific protease, conserved site',
#  'IPR001394': 'Peptidase C19, ubiquitin carboxyl-terminal hydrolase',
#  'IPR015943': 'WD40/YVTN repeat-like-containing domain superfamily',
#  'IPR001680': 'WD40 repeat',
#  'IPR036322': 'WD40-repeat-containing domain superfamily',
#  'IPR050305': 'Small GTPase superfamily, Rab',
#  'IPR043926': 'ABC transporter family G domain',
#  'IPR003439': 'ABC transporter-like, ATP-binding domain',
#  'IPR017871': 'ABC transporter-like, conserved site',
#  'IPR013525': 'ABC-2 type transporter, transmembrane domain',
#  'IPR003593': 'AAA+ ATPase domain',
#  'IPR050352': 'ATP-binding cassette subfamily G transporters',
#  'IPR016181': 'Acyl-CoA N-acyltransferase',
#  'IPR013087': 'Zinc finger C2H2-type',
#  'IPR040193': 'EF-hand domain-containing protein EFHC1/EFHC2/EFHB',
#  'IPR013057': 'Amino acid transporter, transmembrane domain',
#  'IPR011042': 'Six-bladed beta-propeller, TolB-like',
#  'IPR051262': 'SMP-30/CGR1 Lactonase',
#  'IPR013658': 'SMP-30/Gluconolactonase/LRE-like region',
#  'IPR051261': 'NOD-like receptor (NLR)',
#  'IPR017441': 'Protein kinase, ATP binding site',
#  'IPR045270': 'Serine/Threonine Kinase AGC, catalytic domain',
#  'IPR008271': 'Serine/threonine-protein kinase, active site',
#  'IPR000571': 'Zinc finger, CCCH-type',
#  'IPR036855': 'Zinc finger, CCCH-type superfamily',
#  'IPR052330': 'Oxidant-induced cell-cycle arrest/Chorion assembly',
#  'IPR001368': 'TNFR/NGFR cysteine-rich region',
#  'IPR035445': 'GYF-like domain superfamily',
#  'IPR003169': 'GYF domain',
#  'IPR011021': 'Arrestin-like, N-terminal',
#  'IPR014752': 'Arrestin-like, C-terminal',
#  'IPR011022': 'Arrestin C-terminal-like domain',
#  'IPR014756': 'Immunoglobulin E-set',
#  'IPR050357': 'Arrestin domain-containing protein',
#  'IPR007497': 'Interleukin-1 receptor-associated kinase 1-binding protein 1/DUF541',
#  'IPR052022': '26 kDa periplasmic antigen-related',
#  'IPR017920': 'COMM domain',
#  'IPR004331': 'SPX domain',
#  'IPR004344': 'Tubulin-tyrosine ligase/Tubulin polyglutamylase',
#  'IPR021258': 'Epiplasmin protein',
#  'IPR015894': 'Guanylate-binding protein, N-terminal',
#  'IPR001951': 'Histone H4',
#  'IPR009072': 'Histone-fold',
#  'IPR035425': 'CENP-T/Histone H4, histone fold',
#  'IPR019809': 'Histone H4, conserved site',
#  'IPR042530': 'EME1/EME2, C-terminal domain',
#  'IPR033310': 'Mms4/EME1/EME2',
#  'IPR001279': 'Metallo-beta-lactamase',
#  'IPR022712': 'Beta-Casp domain',
#  'IPR011108': 'Zn-dependent metallo-hydrolase, RNA specificity domain',
#  'IPR036866': 'Ribonuclease Z/Hydroxyacylglutathione hydrolase-like',
#  'IPR050698': 'RNA Processing Metallo-Beta-Lactamase Domain-Containing Protein',
#  'IPR039790': 'Cysteine and histidine-rich domain-containing protein 1',
#  'IPR049452': 'Anoctamin, transmembrane domain',
#  'IPR007632': 'Anoctamin',
#  'IPR022340': 'G protein-coupled receptor GCR1 putative',
#  'IPR017452': 'GPCR, rhodopsin-like, 7TM',
#  'IPR017981': 'GPCR, family 2-like, 7TM',
#  'IPR022343': 'GCR1-cAMP receptor',
#  'IPR029063': 'S-adenosyl-L-methionine-dependent methyltransferase superfamily',
#  'IPR000692': "rRNA 2'-O-methyltransferase fibrillarin-like",
#  'IPR020813': 'Fibrillarin, conserved site',
#  'IPR000953': 'Chromo/chromo shadow domain',
#  'IPR023780': 'Chromo domain',
#  'IPR016197': 'Chromo-like domain superfamily',
#  'IPR023779': 'Chromo domain, conserved site',
#  'IPR044251': 'Chromo domain-containing protein LHP1',
#  'IPR045266': 'Copper-dependent monooxygenases, DOMON domain',
#  'IPR005018': 'DOMON domain',
#  'IPR045128': 'Proteasome inhibitor PI31-like',
#  'IPR021625': 'PI31 proteasome regulator, N-terminal',
#  'IPR051787': 'Effector and Ciliary Development-Associated Protein',
#  'IPR021131': 'Large ribosomal subunit protein uL15/eL18',
#  'IPR036227': 'Large ribosomal subunit protein uL15/eL18 superfamily',
#  'IPR000039': 'Large ribosomal subunit protein eL18',
#  'IPR014808': 'DNA replication factor Dna2, N-terminal',
#  'IPR011047': 'Quinoprotein alcohol dehydrogenase-like superfamily',
#  'IPR025533': 'Protein of unknown function DUF4419',
#  'IPR004130': 'GPN-loop GTPase',
#  'IPR030228': 'GPN-loop GTPase 3',
#  'IPR036291': 'NAD(P)-binding domain superfamily',
#  'IPR020843': 'Polyketide synthase, enoylreductase domain',
#  'IPR011032': 'GroES-like superfamily',
#  'IPR013154': 'Alcohol dehydrogenase-like, N-terminal',
#  'IPR047122': 'Trans-enoyl reductase-like',
#  'IPR000237': 'GRIP domain',
#  'IPR019459': 'GRIP-related Arf-binding domain',
#  'IPR000626': 'Ubiquitin-like domain',
#  'IPR029071': 'Ubiquitin-like domain superfamily',
#  'IPR044635': 'Ubiquitin carboxyl-terminal hydrolase 14-like',
#  'IPR045203': 'RAN GTPase-activating protein 1/2',
#  'IPR050173': 'ATP-binding cassette transporter C',
#  'IPR011527': 'ABC transporter type 1, transmembrane domain',
#  'IPR044746': 'ABC transporter C family, six-transmembrane helical domain 1',
#  'IPR036640': 'ABC transporter type 1, transmembrane domain superfamily',
#  'IPR044726': 'ABC transporter C family, six-transmembrane helical domain 2',
#  'IPR050505': 'WD repeat-containing protein WDR55/POC1',
#  'IPR019775': 'WD40 repeat, conserved site',
#  'IPR009056': 'Cytochrome c-like domain',
#  'IPR002327': 'Cytochrome c, class IA/ IB',
#  'IPR036909': 'Cytochrome c-like domain superfamily',
#  'IPR051369': 'Glutathione S-transferase Theta',
#  'IPR050304': 'Microtubule-severing AAA ATPase',
#  'IPR041569': 'AAA ATPase, AAA+ lid domain',
#  'IPR003960': 'ATPase, AAA-type, conserved site',
#  'IPR036181': 'MIT domain superfamily',
#  'IPR003959': 'ATPase, AAA-type, core',
#  'IPR013105': 'Tetratricopeptide repeat 2',
#  'IPR011044': 'Quinoprotein amine dehydrogenase, beta chain-like',
#  'IPR008758': 'Peptidase S28',
#  'IPR042269': 'Serine carboxypeptidase S28, SKS domain',
#  'IPR029058': 'Alpha/Beta hydrolase fold',
#  'IPR036691': 'Endonuclease/exonuclease/phosphatase superfamily',
#  'IPR005135': 'Endonuclease/exonuclease/phosphatase',
#  'IPR050410': 'CCR4/nocturin mRNA turnover and transcription',
#  'IPR012340': 'Nucleic acid-binding, OB-fold',
#  'IPR013970': 'Replication factor A protein 3',
#  'IPR035892': 'C2 domain superfamily',
#  'IPR000008': 'C2 domain',
#  'IPR002859': 'PKD/REJ-like domain',
#  'IPR051065': 'Ras-related small GTPase',
#  'IPR013201': 'Cathepsin propeptide inhibitor domain (I29)',
#  'IPR000169': 'Cysteine peptidase, cysteine active site',
#  'IPR000668': 'Peptidase C1A, papain C-terminal',
#  'IPR039417': 'Papain-like cysteine endopeptidase',
#  'IPR013128': 'Peptidase C1A',
#  'IPR007233': 'Trafficking protein particle complex subunit',
#  'IPR011012': 'Longin-like domain superfamily',
#  'IPR032778': 'Growth factor receptor domain 4',
#  'IPR050668': 'Cytochrome b5',
#  'IPR018506': 'Cytochrome b5, heme-binding site',
#  'IPR036400': 'Cytochrome b5-like heme/steroid binding domain superfamily',
#  'IPR001199': 'Cytochrome b5-like heme/steroid binding domain',
#  'IPR011008': 'Dimeric alpha-beta barrel',
#  'IPR007138': 'Antibiotic biosynthesis monooxygenase domain',
#  'IPR050744': 'AI-2 Signaling Cycle Isomerase LsrG',
#  'IPR011024': 'Gamma-crystallin-like',
#  'IPR011050': 'Pectin lyase fold/virulence factor',
#  'IPR008266': 'Tyrosine-protein kinase, active site',
#  'IPR005127': 'Giardia variant-specific surface protein',
#  'IPR053215': 'TKL Ser/Thr protein kinase',
#  'IPR017860': 'Peptidase M22, conserved site',
#  'IPR000905': 'Gcp-like domain',
#  'IPR043129': 'ATPase, nucleotide binding domain',
#  'IPR034680': 'tRNA N6-adenosine threonylcarbamoyltransferase Kae1, archaeal/eukaryotic',
#  'IPR017861': 'Kae1/TsaD family',
#  'IPR045122': 'Calcium permeable stress-gated cation channel 1-like',
#  'IPR052201': 'Leucine-rich repeat-containing regulator of pluripotency',
#  'IPR008152': 'Clathrin adaptor, alpha/beta/gamma-adaptin, appendage, Ig-like subdomain',
#  'IPR017107': 'Adaptor protein complex AP-1, gamma subunit',
#  'IPR011989': 'Armadillo-like helical',
#  'IPR008153': 'Gamma-adaptin ear (GAE) domain',
#  'IPR050840': 'Adaptor Complexes Large Subunit',
#  'IPR013041': 'Clathrin adaptor, appendage, Ig-like subdomain superfamily',
#  'IPR002553': 'Clathrin/coatomer adaptor, adaptin-like, N-terminal',
#  'IPR010742': 'Respirasome Complex Assembly Factor 1',
#  'IPR029008': 'ER membrane protein complex subunit 6-like',
#  'IPR019333': 'Integrator complex subunit 3, N-terminal',
#  'IPR045334': 'Integrator complex subunit 3',
#  'IPR004037': 'Large ribosomal subunit protein eL8-like, conserved site',
#  'IPR018492': 'Ribosomal protein eL8/Nhp2 family',
#  'IPR001921': 'Large ribosomal subunit protein eL8',
#  'IPR029064': 'Ribosomal protein eL30-like superfamily',
#  'IPR050257': 'Eukaryotic ribosomal RNA-processing and assembly protein',
#  'IPR004038': 'Ribosomal protein eL8/eL30/eS12/Gadd45',
#  'IPR050711': 'Electron transfer and nitrogen metabolism enzyme',
#  'IPR036188': 'FAD/NAD(P)-binding domain superfamily',
#  'IPR023753': 'FAD/NAD(P)-binding domain',
#  'IPR021163': 'Ferredoxin-NADP+ reductase, adrenodoxin-type',
#  'IPR052798': 'Giardia Variant Surface Antigen',
#  'IPR007130': 'Diacylglycerol acyltransferase',
#  'IPR011701': 'Major facilitator superfamily',
#  'IPR020846': 'Major facilitator superfamily domain',
#  'IPR049680': 'Solute carrier family 49-like',
#  'IPR040025': 'Zinc finger protein 622/Rei1/Reh1',
#  'IPR036236': 'Zinc finger C2H2 superfamily',
#  'IPR003604': 'Matrin/U1-C-like, C2H2-type zinc finger',
#  'IPR041661': 'ZN622/Rei1/Reh1, zinc finger C2H2-type',
#  'IPR022755': 'Zinc finger, double-stranded RNA binding',
#  'IPR050956': 'Two-component system histidine kinase',
#  'IPR001789': 'Signal transduction response regulator, receiver domain',
#  'IPR011006': 'CheY-like superfamily',
#  'IPR042523': 'Ubiquitin-like modifier-activating enzyme Atg7, N-terminal, subdomain 2',
#  'IPR045886': 'ThiF/MoeB/HesA family',
#  'IPR000594': 'THIF-type NAD/FAD binding fold',
#  'IPR035985': 'Ubiquitin-activating enzyme',
#  'IPR032197': 'Ubiquitin-like modifier-activating enzyme Atg7, N-terminal',
#  'IPR042522': 'Ubiquitin-like modifier-activating enzyme Atg7, N-terminal, subdomain 1',
#  'IPR052187': 'Major facilitator superfamily domain-containing protein 1',
#  'IPR002720': 'Retinoblastoma-associated protein, A-box',
#  'IPR002719': 'Retinoblastoma-associated protein, B-box',
#  'IPR028309': 'Retinoblastoma protein family',
#  'IPR036915': 'Cyclin-like superfamily',
#  'IPR024599': 'Retinoblastoma-associated protein, N-terminal',
#  'IPR011992': 'EF-hand domain pair',
#  'IPR002048': 'EF-hand domain',
#  'IPR018247': 'EF-Hand 1, calcium-binding site',
#  'IPR050205': 'Calcium-dependent Serine/Threonine Protein Kinases',
#  'IPR033192': 'Outer dynein arm-docking complex subunit 3',
#  'IPR050259': 'Short-chain dehydrogenases/reductases',
#  'IPR002347': 'Short-chain dehydrogenase/reductase SDR',
#  'IPR011294': '3-hydroxybutyrate dehydrogenase',
#  'IPR020904': 'Short-chain dehydrogenase/reductase, conserved site',
#  'IPR025661': 'Cysteine peptidase, asparagine active site',
#  'IPR045081': 'Acidic leucine-rich nuclear phosphoprotein 32',
#  'IPR002674': 'Large ribosomal subunit protein eL43',
#  'IPR011331': 'Large ribosomal subunit protein eL37/eL43',
#  'IPR050522': 'Eukaryotic ribosomal protein eL43',
#  'IPR011332': 'Zinc-binding ribosomal protein',
#  'IPR050342': 'High Mobility Group Box (HMGB)',
#  'IPR009071': 'High mobility group box domain',
#  'IPR036910': 'High mobility group box domain superfamily',
#  'IPR027113': 'Transcription factor NFYB/HAP3',
#  'IPR003958': 'Transcription factor CBF/NF-Y/archaeal histone domain',
#  'IPR003956': 'Transcription factor, NFYB/HAP3, conserved site',
#  'IPR010652': 'Domain of unknown function DUF1232',
#  'IPR038896': 'E3 ubiquitin-protein ligase RNF170',
#  'IPR017907': 'Zinc finger, RING-type, conserved site',
#  'IPR018957': 'Zinc finger, C3HC4 RING-type',
#  'IPR025660': 'Cysteine peptidase, histidine active site',
#  'IPR052603': 'EF-hand calcium-binding domain-containing protein 6',
#  'IPR040673': 'CCDC81, HU domain 2',
#  'IPR028034': 'CCDC81, HU domain 1',
#  'IPR009395': 'Biogenesis of lysosome-related organelles complex 1 subunit 1',
#  'IPR036465': 'von Willebrand factor A-like domain superfamily',
#  'IPR046347': 'Basic-leucine zipper domain superfamily',
#  'IPR004827': 'Basic-leucine zipper domain',
#  'IPR018303': 'P-type ATPase, phosphorylation site',
#  'IPR023299': 'P-type ATPase, cytoplasmic domain N',
#  'IPR004014': 'Cation-transporting P-type ATPase, N-terminal',
#  'IPR008250': 'P-type ATPase, A domain superfamily',
#  'IPR050510': 'Cation transport ATPase (P-type)',
#  'IPR023298': 'P-type ATPase, transmembrane domain superfamily',
#  'IPR044492': 'P-type ATPase, haloacid dehalogenase domain',
#  'IPR001757': 'P-type ATPase',
#  'IPR013766': 'Thioredoxin domain',
#  'IPR005788': 'Protein disulfide-isomerase, thioredoxin-like domain',
#  'IPR017937': 'Thioredoxin, conserved site',
#  'IPR005792': 'Protein disulphide isomerase',
#  'IPR000620': 'EamA domain',
#  'IPR009038': 'GOLD domain',
#  'IPR036598': 'GOLD domain superfamily',
#  'IPR009091': 'Regulator of chromosome condensation 1/beta-lactamase-inhibitor protein II',
#  'IPR000408': 'Regulator of chromosome condensation, RCC1',
#  'IPR031645': 'Vacuolar protein sorting-associated protein 13, DH-like domain',
#  'IPR031646': 'Vacuolar protein sorting-associated protein 13, extended chorein',
#  'IPR026847': 'Vacuolar protein sorting-associated protein 13',
#  'IPR015412': 'Atg2/VPS13, C-terminal',
#  'IPR026854': 'Vacuolar protein sorting-associated protein 13-like, N-terminal domain',
#  'IPR050164': 'Ubiquitin carboxyl-terminal hydrolases',
#  'IPR002903': 'Ribosomal RNA small subunit methyltransferase H',
#  'IPR023397': 'S-adenosyl-L-methionine-dependent methyltransferase, MraW, recognition domain superfamily',
#  'IPR035969': 'Rab-GAP-TBC domain superfamily',
#  'IPR039755': 'TBC1 domain family member 23',
#  'IPR000195': 'Rab-GAP-TBC domain',
#  'IPR035699': 'Dynein heavy chain, hydrolytic ATP-binding dynein motor region',
#  'IPR041466': 'Dynein heavy chain, AAA 5 extension domain',
#  'IPR026983': 'Dynein heavy chain',
#  'IPR001849': 'Pleckstrin homology domain',
#  'IPR011993': 'PH-like domain superfamily',
#  'IPR039421': 'Type 1 protein exporter',
#  'IPR027752': 'Protein polyglycylase TTLL10',
#  'IPR039411': 'Ribosomal biogenesis NSA2 family',
#  'IPR022309': 'Ribosomal protein eS8/ribosomal biogenesis NSA2',
#  'IPR000253': 'Forkhead-associated (FHA) domain',
#  'IPR008984': 'SMAD/FHA domain superfamily',
#  'IPR039468': 'WDR19, WD40 repeat',
#  'IPR040379': 'WD repeat-containing protein 19/dyf-2',
#  'IPR005336': 'Mitochondrial pyruvate carrier',
#  'IPR009290': 'Radial spoke 3',
#  'IPR006689': 'Small GTPase superfamily, ARF/SAR type',
#  'IPR018488': 'Cyclic nucleotide-binding, conserved site',
#  'IPR050503': 'cAMP-dependent kinase regulatory chain',
#  'IPR038800': 'Coiled-coil domain-containing protein 17',
#  'IPR019954': 'Ubiquitin conserved site',
#  'IPR019956': 'Ubiquitin domain',
#  'IPR050158': 'Ubiquitin and ubiquitin-like',
#  'IPR011687': 'Ribosome biogenesis protein Nop53/GLTSCR2',
#  'IPR029055': 'Nucleophile aminohydrolases, N-terminal',
#  'IPR016295': 'Proteasome subunit beta 4',
#  'IPR001353': 'Proteasome, subunit alpha/beta',
#  'IPR023333': 'Proteasome B-type subunit',
#  'IPR016050': 'Proteasome beta-type subunit, conserved site',
#  'IPR050221': '26S Proteasome Regulatory ATPase',
#  'IPR032501': 'Proteasomal ATPase, second OB domain',
#  'IPR027794': 'tRNase Z endonuclease',
#  'IPR047151': 'Zinc phosphodiesterase ELAC protein 2-like',
#  'IPR013149': 'Alcohol dehydrogenase-like, C-terminal',
#  'IPR000560': 'Histidine phosphatase superfamily, clade-2',
#  'IPR029033': 'Histidine phosphatase superfamily',
#  'IPR050645': 'Histidine Acid Phosphatase',
#  'IPR030395': 'Glycerophosphodiester phosphodiesterase domain',
#  'IPR017946': 'PLC-like phosphodiesterase, TIM beta/alpha-barrel domain superfamily',
#  'IPR010614': 'RAD3-like helicase, DEAD',
#  'IPR010643': 'Helical and beta-bridge domain',
#  'IPR006555': 'ATP-dependent helicase, C-terminal',
#  'IPR045028': 'Helicase superfamily 1/2, DinG/Rad3-like',
#  'IPR014013': 'Helicase superfamily 1/2, ATP-binding domain, DinG/Rad3-type',
#  'IPR001945': 'RAD3/XPD family',
#  'IPR013020': 'ATP-dependent helicase Rad3/Chl1-like',
#  'IPR006554': 'Helicase-like, DEXD box c2 type',
#  'IPR010754': 'Optic atrophy 3-like',
#  'IPR036527': 'SCP2 sterol-binding domain superfamily',
#  'IPR003033': 'SCP2 sterol-binding domain',
#  'IPR051687': 'Peroxisomal Beta-Oxidation Enzymes',
#  'IPR050108': 'Cyclin-dependent kinase',
#  'IPR040190': 'N-acetylmuramic acid 6-phosphate etherase/glucokinase regulatory protein',
#  'IPR046348': 'SIS domain superfamily',
#  'IPR001347': 'SIS domain',
#  'IPR004023': 'Mago nashi protein',
#  'IPR036605': 'Mago nashi superfamily',
#  'IPR038407': 'Vesicle transport v-SNARE, N-terminal domain superfamily',
#  'IPR007705': 'Vesicle transport v-SNARE, N-terminal',
#  'IPR008564': 'Golgi apparatus membrane protein TVP23-like',
#  'IPR036869': 'Chaperone J-domain superfamily',
#  'IPR000073': 'Alpha/beta hydrolase fold-1',
#  'IPR037363': 'Sec13/Seh1 family',
#  'IPR045036': 'Spartin-like',
#  'IPR009686': 'Senescence/spartin-associated, C-terminal',
#  'IPR052320': 'Cytochrome b5 domain-containing',
#  'IPR006671': 'Cyclin, N-terminal',
#  'IPR013763': 'Cyclin-like domain',
#  'IPR015915': 'Kelch-type beta propeller',
#  'IPR000315': 'B-box-type zinc finger',
#  'IPR006652': 'Kelch repeat type 1',
#  'IPR050143': 'Tripartite motif-containing',
#  'IPR002913': 'START domain',
#  'IPR043556': 'StAR-related lipid transfer protein 5/6',
#  'IPR023393': 'START-like domain superfamily',
#  'IPR007863': 'Peptidase M16, C-terminal',
#  'IPR050626': 'Peptidase M16',
#  'IPR001431': 'Peptidase M16, zinc-binding site',
#  'IPR032632': 'Peptidase M16, middle/third domain',
#  'IPR011249': 'Metalloenzyme, LuxS/M16 peptidase-like',
#  'IPR011765': 'Peptidase M16, N-terminal',
#  'IPR001965': 'Zinc finger, PHD-type',
#  'IPR019787': 'Zinc finger, PHD-finger',
#  'IPR011011': 'Zinc finger, FYVE/PHD-type',
#  'IPR050117': 'Mitogen-activated protein kinase',
#  'IPR003527': 'Mitogen-activated protein (MAP) kinase, conserved site',
#  'IPR019479': 'Peroxiredoxin, C-terminal',
#  'IPR050217': 'Thiol-specific antioxidant peroxiredoxin',
#  'IPR000866': 'Alkyl hydroperoxide reductase subunit C/ Thiol specific antioxidant',
#  'IPR024706': 'Peroxiredoxin, AhpC-type',
#  'IPR050236': 'Serine/threonine-protein kinases, AGC',
#  'IPR008374': 'SF-assemblin/beta-giardin',
#  'IPR013662': 'RyR/IP3R Homology associated domain',
#  'IPR035910': 'RyR/IP3 receptor binding core, RIH domain superfamily',
#  'IPR000493': 'Inositol 1,4,5-trisphosphate receptor',
#  'IPR015925': 'Ryanodine/Inositol 1,4,5-trisphosphate receptor',
#  'IPR014821': 'Inositol 1,4,5-trisphosphate/ryanodine receptor',
#  'IPR036300': 'Mir domain superfamily',
#  'IPR011893': 'Selenoprotein, Rdx-type',
#  'IPR051617': 'UNC-93-like transmembrane regulator',
#  'IPR003409': 'MORN repeat',
#  'IPR005828': 'Major facilitator, sugar transporter-like',
#  'IPR050360': 'Major Facilitator Superfamily Sugar Transporters',
#  'IPR018967': 'Iron-binding zinc finger, CDGSH type',
#  'IPR042216': 'MitoNEET, CDGSH iron-sulfur domain',
#  'IPR052950': 'CDGSH iron-sulfur domain-containing protein',
#  'IPR003368': 'Polymorphic outer membrane protein repeat',
#  'IPR007312': 'Phosphoesterase',
#  'IPR017850': 'Alkaline-phosphatase-like, core domain superfamily',
#  'IPR009060': 'UBA-like superfamily',
#  'IPR029069': 'HotDog domain superfamily',
#  'IPR002539': 'MaoC-like dehydratase domain',
#  'IPR054357': 'Peroxisomal multifunctional enzyme type 2-like, N-terminal domain',
#  'IPR001005': 'SANT/Myb domain',
#  'IPR009057': 'Homedomain-like superfamily',
#  'IPR017930': 'Myb domain',
#  'IPR050560': 'MYB Transcription Factors',
#  'IPR007014': 'FUN14',
#  'IPR018170': 'Aldo/keto reductase, conserved site',
#  'IPR036812': 'NADP-dependent oxidoreductase domain superfamily',
#  'IPR020471': 'Aldo-keto reductase',
#  'IPR023210': 'NADP-dependent oxidoreductase domain',
#  'IPR030616': 'Aurora kinase-like',
#  'IPR003323': 'OTU domain',
#  'IPR042467': 'Peptidase C65, otubain, subdomain 2',
#  'IPR019400': 'Peptidase C65, otubain',
#  'IPR042468': 'Peptidase C65, otubain, subdomain 1',
#  'IPR006595': 'CTLH, C-terminal LisH motif',
#  'IPR045184': 'WD40 repeat-containing protein SMU1',
#  'IPR006594': 'LIS1 homology motif',
#  'IPR037047': 'PITH domain superfamily',
#  'IPR008979': 'Galactose-binding-like domain superfamily',
#  'IPR010400': 'PITH domain',
#  'IPR045099': 'PITH domain-containing protein 1-like',
#  'IPR006560': 'AWS domain',
#  'IPR036612': 'K Homology domain, type 1 superfamily',
#  'IPR046341': 'SET domain superfamily',
#  'IPR001214': 'SET domain',
#  'IPR050777': 'SET2 Histone-Lysine N-Methyltransferase',
#  'IPR003616': 'Post-SET domain',
#  'IPR051970': 'Telomere Length Regulation TEL2',
#  'IPR038528': 'TEL2, C-terminal domain superfamily',
#  'IPR019337': 'Telomere length regulation protein, conserved domain',
#  'IPR027484': 'Phosphatidylinositol-4-phosphate 5-kinase, N-terminal',
#  'IPR027483': 'Phosphatidylinositol-4-phosphate 4/5-kinase, C-terminal domain superfamily',
#  'IPR023610': 'Phosphatidylinositol-4/5-phosphate 5/4-kinase',
#  'IPR002498': 'Phosphatidylinositol-4-phosphate 4/5-kinase, core',
#  'IPR006553': 'Leucine-rich repeat, cysteine-containing subtype',
#  'IPR013783': 'Immunoglobulin-like fold',
#  'IPR015919': 'Cadherin-like superfamily',
#  'IPR050227': 'Ras-related protein Rab',
#  'IPR035999': 'Sec7 domain superfamily',
#  'IPR000904': 'Sec7 domain',
#  'IPR023394': 'Sec7, C-terminal domain superfamily',
#  'IPR051877': 'Centriole and Basal Body Structural Protein',
#  'IPR018993': 'FGFR1 oncogene partner (FOP), N-terminal dimerisation domain',
#  'IPR052438': 'Chromatin-remodeling and transcription coactivator',
#  'IPR019339': 'CBF1-interacting co-repressor CIR, N-terminal domain',
#  'IPR022209': 'Pre-mRNA splicing factor',
#  'IPR051376': 'Pre-mRNA-splicing factor CWC25',
#  'IPR008991': 'Translation protein SH3-like domain superfamily',
#  'IPR038657': 'Large ribosomal subunit protein bL19 superfamily',
#  'IPR012901': 'Carnosine N-methyltransferase',
#  'IPR007599': 'Derlin',
#  'IPR035952': 'Rhomboid-like superfamily',
#  'IPR020616': 'Thiolase, N-terminal',
#  'IPR016039': 'Thiolase-like',
#  'IPR002155': 'Thiolase',
#  'IPR050215': 'Thiolase-like superfamily, Thiolase',
#  'IPR020617': 'Thiolase, C-terminal',
#  'IPR020613': 'Thiolase, conserved site',
#  'IPR020610': 'Thiolase, active site',
#  'IPR052920': 'Potential DNA-binding regulatory protein',
#  'IPR022742': 'Serine aminopeptidase, S33',
#  'IPR007881': 'UNC-50',
#  'IPR003325': 'TerD domain',
#  'IPR051324': 'Stress and Tellurium Resistance Protein',
#  'IPR019363': 'Lipid droplet-associated hydrolase',
#  'IPR032631': 'P-type ATPase, N-terminal',
#  'IPR006539': 'P-type ATPase, subfamily IV',
#  'IPR032630': 'P-type ATPase, C-terminal',
#  'IPR005045': 'CDC50/LEM3 family',
#  'IPR018316': 'Tubulin/FtsZ, 2-layer sandwich domain',
#  'IPR037103': 'Tubulin/FtsZ-like, C-terminal domain',
#  'IPR000217': 'Tubulin',
#  'IPR036525': 'Tubulin/FtsZ, GTPase domain superfamily',
#  'IPR013838': 'Beta tubulin, autoregulation binding site',
#  'IPR003008': 'Tubulin/FtsZ, GTPase domain',
#  'IPR008280': 'Tubulin/FtsZ, C-terminal',
#  'IPR017975': 'Tubulin, conserved site',
#  'IPR023123': 'Tubulin, C-terminal',
#  'IPR002453': 'Beta tubulin',
#  'IPR036770': 'Ankyrin repeat-containing domain superfamily',
#  'IPR002110': 'Ankyrin repeat',
#  'IPR013586': '26S proteasome regulatory subunit, C-terminal',
#  'IPR000717': 'Proteasome component (PCI) domain',
#  'IPR036390': 'Winged helix DNA-binding domain superfamily',
#  'IPR050756': 'COP9 signalosome complex subunit 3',
#  'IPR051334': 'Serine/Arginine-Rich Protein Kinases',
#  'IPR003661': 'Signal transduction histidine kinase, dimerisation/phosphoacceptor domain',
#  'IPR003594': 'Histidine kinase/HSP90-like ATPase',
#  'IPR036890': 'Histidine kinase/HSP90-like ATPase superfamily',
#  'IPR005467': 'Histidine kinase domain',
#  'IPR036097': 'Signal transduction histidine kinase, dimerisation/phosphoacceptor domain superfamily',
#  'IPR006330': 'Adenosine/adenine deaminase',
#  'IPR001365': 'Adenosine deaminase domain',
#  'IPR032466': 'Metal-dependent hydrolase',
#  'IPR032154': 'Coatomer subunit gamma, C-terminal',
#  'IPR013040': 'Coatomer, gamma subunit, appendage, Ig-like subdomain',
#  'IPR017106': 'Coatomer gamma subunit',
#  'IPR009028': 'Coatomer/calthrin adaptor appendage, C-terminal subdomain',
#  'IPR012295': 'TBP domain superfamily',
#  'IPR037067': 'Coatomer, gamma subunit, appendage domain superfamily',
#  'IPR042277': 'Vacuolar protein sorting-associated protein IST1-like',
#  'IPR005061': 'Vacuolar protein sorting-associated protein Ist1',
#  'IPR041694': 'Oxidoreductase, N-terminal domain',
#  'IPR045010': 'Medium-chain dehydrogenase/reductase',
#  'IPR026755': 'Protein FAM221A/B',
#  'IPR039093': 'Protein XRP2',
#  'IPR012945': 'Tubulin binding cofactor C-like domain',
#  'IPR017901': 'C-CAP/cofactor C-like domain',
#  'IPR016098': 'Cyclase-associated protein CAP/septum formation inhibitor MinC, C-terminal',
#  'IPR006599': 'CARP motif',
#  'IPR024079': 'Metallopeptidase, catalytic domain superfamily',
#  'IPR012962': 'Peptidase M54, archaemetzincin',
#  'IPR052009': 'Archaemetzincin',
#  'IPR003846': 'Protein adenylyltransferase SelO',
#  'IPR016439': 'Sphingosine N-acyltransferase Lag1/Lac1-like',
#  'IPR006634': 'TRAM/LAG1/CLN8 homology domain',
#  'IPR000535': 'Major sperm protein (MSP) domain',
#  'IPR016763': 'Vesicle-associated membrane-protein-associated protein',
#  'IPR008962': 'PapD-like superfamily',
#  'IPR036875': 'Zinc finger, CCHC-type superfamily',
#  'IPR001878': 'Zinc finger, CCHC-type',
#  'IPR051575': 'Myb-like DNA-binding',
#  'IPR017884': 'SANT domain',
#  'IPR021133': 'HEAT, type 2',
#  'IPR000357': 'HEAT repeat',
#  'IPR040122': 'Importin beta family',
#  'IPR013767': 'PAS fold',
#  'IPR007651': 'Lipin, N-terminal',
#  'IPR026058': 'LIPIN family',
#  'IPR013209': 'Lipin/Ned1/Smp2 (LNS2)',
#  'IPR031315': 'LNS2/PITP',
#  'IPR008504': 'ER membrane protein complex subunit 6',
#  'IPR032781': 'ABC-transporter extension domain',
#  'IPR050611': 'ATP-binding cassette sub-family F member, EF3 subfamily',
#  'IPR030667': 'NEDD8-activating enzyme E1 regulatory subunit APP-BP1',
#  'IPR053095': 'Actin-binding & GATA zinc finger domain-containing protein',
#  'IPR051834': 'RING finger E3 ubiquitin-protein ligase',
#  'IPR042101': 'Signal recognition particle SRP54, N-terminal domain superfamily',
#  'IPR013822': 'Signal recognition particle SRP54, helical bundle',
#  'IPR004125': 'Signal recognition particle, SRP54 subunit, M-domain',
#  'IPR036891': 'Signal recognition particle, SRP54 subunit, M-domain superfamily',
#  'IPR000897': 'Signal recognition particle, SRP54 subunit, GTPase domain',
#  'IPR022941': 'Signal recognition particle, SRP54 subunit',
#  'IPR036225': 'SRP/SRP receptor, N-terminal',
#  'IPR006325': 'Signal recognition particle, SRP54 subunit, eukaryotic',
#  'IPR050498': 'Photosystem I assembly protein Ycf3',
#  'IPR038375': 'Protein arginine methyltransferase NDUFAF7 superfamily',
#  'IPR003788': 'Protein arginine methyltransferase NDUFAF7',
#  'IPR001715': 'Calponin homology domain',
#  'IPR027328': 'Microtubule-associated protein RP/EB',
#  'IPR036872': 'CH domain superfamily',
#  'IPR011115': 'SecA DEAD-like, N-terminal',
#  'IPR000185': 'Protein translocase subunit SecA',
#  'IPR014018': 'SecA motor DEAD',
#  'IPR006073': 'GTP binding domain',
#  'IPR007238': 'DNA primase large subunit, eukaryotic/archaeal',
#  'IPR037221': 'H-type lectin domain superfamily',
#  'IPR019019': 'H-type lectin domain',
#  'IPR041991': 'Large ribosomal subunit protein eL27, KOW domain',
#  'IPR001141': 'Large ribosomal subunit protein eL27',
#  'IPR038655': 'Large ribosomal subunit protein eL27 superfamily',
#  'IPR000387': 'Tyrosine-specific protein phosphatases domain',
#  'IPR029021': 'Protein-tyrosine phosphatase-like',
#  'IPR050561': 'Protein Tyrosine Phosphatase',
#  'IPR016130': 'Protein-tyrosine phosphatase, active site',
#  'IPR003595': 'Protein-tyrosine phosphatase, catalytic',
#  'IPR001054': 'Adenylyl cyclase class-3/4/guanylyl cyclase',
#  'IPR029787': 'Nucleotide cyclase',
#  'IPR025483': 'Lipase, eukaryotic',
#  'IPR006693': 'Partial AB-hydrolase lipase domain',
#  'IPR024160': 'Bin3-type S-adenosyl-L-methionine binding domain',
#  'IPR039772': 'RNA methyltransferase Bin3-like',
#  'IPR010675': 'RNA methyltransferase bin3, C-terminal',
#  'IPR016035': 'Acyl transferase/acyl hydrolase/lysophospholipase',
#  'IPR002641': 'Patatin-like phospholipase domain',
#  'IPR033562': 'Patatin-like phospholipase domain-containing protein',
#  'IPR036690': 'Ferrodoxin-fold anticodon-binding domain superfamily',
#  'IPR002319': 'Phenylalanyl-tRNA synthetase',
#  'IPR005121': 'Ferrodoxin-fold anticodon-binding domain',
#  'IPR006195': 'Aminoacyl-tRNA synthetase, class II',
#  'IPR045864': 'Class II Aminoacyl-tRNA synthetase/Biotinyl protein ligase (BPL) and lipoyl protein ligase (LPL)',
#  'IPR012864': 'Cysteine oxygenase/2-aminoethanethiol dioxygenase',
#  'IPR011051': 'RmlC-like cupin domain superfamily',
#  'IPR006068': 'Cation-transporting P-type ATPase, C-terminal',
#  'IPR010721': 'Probable O-methyltransferase UstE-like',
#  'IPR051164': 'NmrA-like oxidoreductase',
#  'IPR008030': 'NmrA-like domain',
#  'IPR050660': 'NEK Serine/Threonine Protein Kinase',
#  'IPR002088': 'Protein prenyltransferase, alpha subunit',
#  'IPR013078': 'Histidine phosphatase superfamily, clade-1',
#  'IPR050275': 'Phosphoglycerate Mutase/Phosphatase',
#  'IPR020422': 'Dual specificity protein phosphatase domain',
#  'IPR000340': 'Dual specificity phosphatase, catalytic domain',
#  'IPR002781': 'Transmembrane protein TauE-like',
#  'IPR000682': 'Protein-L-isoaspartate(D-aspartate) O-methyltransferase',
#  'IPR028343': 'Fructose-1,6-bisphosphatase',
#  'IPR000146': 'Fructose-1,6-bisphosphatase class 1',
#  'IPR033391': 'Fructose-1-6-bisphosphatase class I, N-terminal',
#  'IPR044015': 'Fructose-1-6-bisphosphatase class 1, C-terminal',
#  'IPR009670': 'Cell surface immobilisation antigen SerH',
#  'IPR002350': 'Kazal domain',
#  'IPR021135': 'Phosphoenolpyruvate carboxylase',
#  'IPR015813': 'Pyruvate/Phosphoenolpyruvate kinase-like domain superfamily',
#  'IPR050568': 'Transcription and DNA Replication Regulators',
#  'IPR007125': 'Histone H2A/H2B/H3',
#  'IPR040065': 'Protein LZIC',
#  'IPR004859': 'Xrn1, N-terminal',
#  'IPR017151': "5'-3' exoribonuclease type 2",
#  'IPR041412': 'Xrn1, helical domain',
#  'IPR027073': "5'-3' exoribonuclease",
#  'IPR005475': 'Transketolase-like, pyrimidine-binding domain',
#  'IPR042179': 'Multifunctional 2-oxoglutarate metabolism enzyme, C-terminal domain superfamily',
#  'IPR011603': '2-oxoglutarate dehydrogenase E1 component',
#  'IPR001017': 'Dehydrogenase, E1 component',
#  'IPR031717': 'Multifunctional 2-oxoglutarate metabolism enzyme, C-terminal',
#  'IPR029061': 'Thiamin diphosphate-binding fold',
#  'IPR031327': 'Mini-chromosome maintenance protein',
#  'IPR041562': 'MCM, AAA-lid domain',
#  'IPR001208': 'MCM domain',
#  'IPR041024': 'Mcm6, C-terminal winged-helix domain',
#  'IPR027925': 'MCM, N-terminal domain',
#  'IPR008049': 'DNA replication licensing factor Mcm6',
#  'IPR033762': 'MCM OB domain',
#  'IPR018525': 'Mini-chromosome maintenance, conserved site',
#  'IPR016093': 'MIR motif',
#  'IPR036871': 'PX domain superfamily',
#  'IPR001683': 'Phox homology',
#  'IPR001751': 'S100/Calcium binding protein 7/8-like, conserved site',
#  'IPR018499': 'Tetraspanin/Peripherin',
#  'IPR010760': 'DNA repair protein, Swi5',
#  'IPR016025': 'Clathrin heavy chain, N-terminal',
#  'IPR000547': 'Clathrin, heavy chain/VPS, 7-fold repeat',
#  'IPR016341': 'Clathrin, heavy chain',
#  'IPR002909': 'IPT domain',
#  'IPR051210': 'Ubiquitin ligases and GEF domain-containing protein',
#  'IPR001163': 'Sm domain, eukaryotic/archaea-type',
#  'IPR016654': 'U6 snRNA-associated Sm-like protein LSm2',
#  'IPR010920': 'LSM domain superfamily',
#  'IPR007702': 'Janus',
#  'IPR038596': 'Janus superfamily',
#  'IPR021109': 'Aspartic peptidase domain superfamily',
#  'IPR037299': 'TRIM37, MATH domain',
#  'IPR002083': 'MATH/TRAF domain',
#  'IPR053003': 'TRIM/RBCC E3 ubiquitin-protein ligases',
#  'IPR008974': 'TRAF-like',
#  'IPR006206': 'Mevalonate/galactokinase',
#  'IPR019741': 'Galactokinase, conserved site',
#  'IPR014721': 'Small ribosomal subunit protein uS5 domain 2-type fold, subgroup',
#  'IPR036554': 'GHMP kinase, C-terminal domain superfamily',
#  'IPR000705': 'Galactokinase',
#  'IPR013750': 'GHMP kinase, C-terminal domain',
#  'IPR019539': 'Galactokinase, N-terminal domain',
#  'IPR020568': 'Ribosomal protein uS5 domain 2-type superfamily',
#  'IPR001194': 'cDENN domain',
#  'IPR051942': 'DENN domain-containing protein 2',
#  'IPR043153': 'DENN domain, C-terminal lobe',
#  'IPR037516': 'Tripartite DENN domain',
#  'IPR000433': 'Zinc finger, ZZ-type',
#  'IPR007527': 'Zinc finger, SWIM-type',
#  'IPR043145': 'Zinc finger, ZZ-type superfamily',
#  'IPR039903': 'E3 ubiquitin-protein ligase Zswim2',
#  'IPR031712': 'Domain of unknown function DUF5077',
#  'IPR021862': 'Protein of unknown function DUF3472',
#  'IPR001461': 'Aspartic peptidase A1 family',
#  'IPR001969': 'Aspartic peptidase, active site',
#  'IPR034164': 'Pepsin-like domain',
#  'IPR033121': 'Peptidase family A1 domain',
#  'IPR051547': 'Tyrosyl-DNA phosphodiesterase 2-like',
#  'IPR001509': 'NAD-dependent epimerase/dehydratase',
#  'IPR050425': 'NAD(P)-dependent epimerase/dehydratase-related protein',
#  'IPR001130': "3'-5' ssDNA/RNA exonuclease TatD-like",
#  'IPR050891': 'TatD-type Metallo-dependent Hydrolase',
#  'IPR006687': 'Small GTPase superfamily, SAR1-type',
#  'IPR000058': 'Zinc finger, AN1-type',
#  'IPR002653': 'Zinc finger, A20-type',
#  'IPR035896': 'AN1-like Zinc finger',
#  'IPR050652': 'AN1/A20 Zinc Finger',
#  'IPR026906': 'BspA-type LRR region',
#  'IPR014730': 'Electron transfer flavoprotein, alpha/beta-subunit, N-terminal',
#  'IPR014729': 'Rossmann-like alpha/beta/alpha sandwich fold',
#  'IPR033948': 'Electron transfer flavoprotein, beta subunit, N-terminal',
#  'IPR012255': 'Electron transfer flavoprotein, beta subunit',
#  'IPR024084': 'Isopropylmalate dehydrogenase-like domain',
#  'IPR019818': 'Isocitrate/isopropylmalate dehydrogenase, conserved site',
#  'IPR052410': 'Dynein regulatory complex subunit 5',
#  'IPR045103': 'E3 ubiquitin-protein ligase RNF5/RNF185-like',
#  'IPR019371': 'KxDL domain',
#  'IPR028008': 'Protein of unknown function DUF4441',
#  'IPR023346': 'Lysozyme-like domain superfamily',
#  'IPR000726': 'Glycoside hydrolase, family 19, catalytic',
#  'IPR013211': 'LVIVD',
#  'IPR051640': 'GRB10-interacting GYF',
#  'IPR007858': 'Dpy-30 motif',
#  'IPR010516': 'Sin3 associated polypeptide p18',
#  'IPR042534': 'Sin3 associated polypeptide p18 superfamily',
#  'IPR051063': 'Protein Disulfide Isomerase',
#  'IPR046346': 'Aminoacid dehydrogenase-like, N-terminal domain superfamily',
#  'IPR012301': 'Malic enzyme, N-terminal domain',
#  'IPR051674': 'Malate Decarboxylating Enzymes',
#  'IPR015884': 'Malic enzyme, conserved site',
#  'IPR037062': 'Malic enzyme, N-terminal domain superfamily',
#  'IPR012302': 'Malic enzyme, NAD-binding',
#  'IPR045213': 'Malic enzyme, NAD-binding domain, bacterial type',
#  'IPR001891': 'Malic oxidoreductase',
#  'IPR003613': 'U-box domain',
#  'IPR050818': 'Voltage-gated potassium channel family H',
#  'IPR015425': 'Formin, FH2 domain',
#  'IPR014768': 'Rho GTPase-binding/formin homology 3 (GBD/FH3) domain',
#  'IPR042201': 'Formin, FH2 domain superfamily',
#  'IPR051425': 'Formin Homology',
#  'IPR004102': 'Poly(ADP-ribose) polymerase, regulatory domain',
#  'IPR011704': 'ATPase, dynein-related, AAA domain',
#  'IPR031248': 'E3 ubiquitin-protein ligase RNF213',
#  'IPR050930': 'Major Facilitator Superfamily Vesicular Transporter',
#  'IPR051350': 'WD repeat-containing signal transduction regulator',
#  'IPR045234': 'RING finger protein Unkempt-like',
#  'IPR015433': 'Phosphatidylinositol kinase',
#  'IPR000403': 'Phosphatidylinositol 3-/4-kinase, catalytic domain',
#  'IPR036940': 'Phosphatidylinositol 3-/4-kinase, catalytic domain superfamily',
#  'IPR039031': 'Mucolipin',
#  'IPR000086': 'NUDIX hydrolase domain',
#  'IPR003293': 'Nudix hydrolase 6-like',
#  'IPR040618': 'Pre-nudix hydrolase domain',
#  'IPR015797': 'NUDIX hydrolase-like domain superfamily',
#  'IPR020476': 'NUDIX hydrolase',
#  'IPR051213': 'START domain-containing lipid transfer',
#  'IPR050814': 'Myo-inositol Transporter',
#  'IPR004241': 'Autophagy protein Atg8 ubiquitin-like',
#  'IPR042856': 'Radial spoke protein 14',
#  'IPR001510': 'Zinc finger, PARP-type',
#  'IPR012982': 'PARP1-like, PADR1 domain, zinc ribbon fold',
#  'IPR036957': 'Zinc finger, PARP-type superfamily',
#  'IPR003034': 'SAP domain',
#  'IPR004001': 'Actin, conserved site',
#  'IPR004000': 'Actin family',
#  'IPR020902': 'Actin/actin-like conserved site',
#  'IPR027831': 'Domain of unknown function DUF4485',
#  'IPR002303': 'Valine-tRNA ligase',
#  'IPR037118': 'Valyl-tRNA synthetase, tRNA-binding arm superfamily',
#  'IPR013155': 'Methionyl/Valyl/Leucyl/Isoleucyl-tRNA synthetase, anticodon-binding',
#  'IPR001412': 'Aminoacyl-tRNA synthetase, class I, conserved site',
#  'IPR009008': 'Valyl/Leucyl/Isoleucyl-tRNA synthetase, editing domain',
#  'IPR009080': 'Aminoacyl-tRNA synthetase, class Ia, anticodon-binding',
#  'IPR002300': 'Aminoacyl-tRNA synthetase, class Ia',
#  'IPR019499': 'Valyl-tRNA synthetase, tRNA-binding arm',
#  'IPR033705': 'Valyl tRNA synthetase, anticodon-binding domain',
#  'IPR043519': 'Nucleotidyltransferase superfamily',
#  'IPR039529': 'GPI inositol-deacylase',
#  'IPR012908': 'GPI inositol-deacylase PGAP1-like',
#  'IPR000407': 'Nucleoside phosphatase GDA1/CD39',
#  'IPR008978': 'HSP20-like chaperone',
#  'IPR006994': 'TCF25/Rqc1',
#  'IPR007052': 'CS domain',
#  'IPR051762': 'Upstream Binding Factor 1',
#  'IPR012171': 'Fatty acid desaturase',
#  'IPR005804': 'Fatty acid desaturase domain',
#  'IPR045145': 'Chromatin assembly factor 1 subunit Cac2/CHAF1B/FAS2',
#  'IPR005024': 'Snf7 family',
#  'IPR027246': 'Eukaryotic porin/Tom40',
#  'IPR023614': 'Porin domain superfamily',
#  'IPR040102': 'WD repeat-containing protein 41',
#  'IPR013320': 'Concanavalin A-like lectin/glucanase domain superfamily',
#  'IPR051131': 'NEK Ser/Thr protein kinase family, NIMA subfamily',
#  'IPR013870': 'Large ribosomal subunit protein mL54',
#  'IPR004882': 'Luc7-related',
#  'IPR045223': 'Small ribosomal subunit protein RACK1-like',
#  'IPR020472': 'G-protein beta WD-40 repeat',
#  'IPR036397': 'Ribonuclease H superfamily',
#  'IPR002562': "3'-5' exonuclease domain",
#  'IPR045092': 'Exosome complex exonuclease Rrp6-like',
#  'IPR012337': 'Ribonuclease H-like superfamily',
#  'IPR017868': 'Filamin/ABP280 repeat-like',
#  'IPR046985': 'Inositol 5-phosphatase',
#  'IPR000300': 'Inositol polyphosphate-related phosphatase',
#  'IPR051023': 'Protein Phosphatase 2A Regulatory Subunit A',
#  'IPR050630': 'WD repeat Echinoderm Microtubule-associated Protein-like',
#  'IPR002041': 'Ran GTPase',
#  'IPR008907': 'Tubulin polymerization-promoting protein',
#  'IPR051419': 'Lysine/N-terminal Methyltransferase Superfamily',
#  'IPR013216': 'Methyltransferase type 11',
#  'IPR006164': 'Ku70/Ku80 beta-barrel domain',
#  'IPR016194': 'SPOC-like, C-terminal domain superfamily',
#  'IPR036361': 'SAP domain superfamily',
#  'IPR027388': 'Ku70, bridge and pillars domain superfamily',
#  'IPR047087': 'Ku70, core domain',
#  'IPR006165': 'Ku70',
#  'IPR005160': 'Ku70/Ku80 C-terminal arm',
#  'IPR005161': 'Ku70/Ku80, N-terminal alpha/beta',
#  'IPR038718': 'SNF2-like, N-terminal domain superfamily',
#  'IPR013785': 'Aldolase-type TIM barrel',
#  'IPR043594': 'HMG-CoA lyase',
#  'IPR000891': 'Pyruvate carboxyltransferase',
#  'IPR004709': 'Na+/H+ exchanger',
#  'IPR018422': 'Cation/H+ exchanger, CPA1 family',
#  'IPR006153': 'Cation/H+ exchanger',
#  'IPR050576': 'Ciliary and flagellar integrity-associated protein',
#  'IPR025875': 'Leucine rich repeat 4',
#  'IPR016135': 'Ubiquitin-conjugating enzyme/RWD-like',
#  'IPR000608': 'Ubiquitin-conjugating enzyme E2',
#  'IPR050113': 'Ubiquitin-conjugating enzyme',
#  'IPR033122': 'LETM1-like, ribosome-binding domain',
#  'IPR044202': 'LETM1/MDM38-like',
#  'IPR036388': 'Winged helix-like DNA-binding domain superfamily',
#  'IPR016827': 'Transcriptional adaptor 2',
#  'IPR008656': 'Inositol-tetrakisphosphate 1-kinase',
#  'IPR040464': 'Inositol 1,3,4-trisphosphate 5/6-kinase, ATP-grasp domain',
#  'IPR024811': 'Polycomb protein ASX/ASX-like',
#  'IPR009210': 'Activating signal cointegrator 1 complex subunit 1',
#  'IPR019510': 'A-kinase anchor protein 7-like, phosphoesterase domain',
#  'IPR029048': 'Heat shock protein 70kD, C-terminal domain superfamily',
#  'IPR018181': 'Heat shock protein 70, conserved site',
#  'IPR029047': 'Heat shock protein 70kD, peptide-binding domain superfamily',
#  'IPR013126': 'Heat shock protein 70 family',
#  'IPR045269': 'Serine/threonine-protein kinase Atg1-like',
#  'IPR002013': 'SAC domain',
#  'IPR043573': 'Polyphosphoinositide phosphatase Fig4-like',
#  'IPR019341': 'Alpha/gamma-adaptin-binding protein p34',
#  'IPR005552': 'Scramblase',
#  'IPR027370': 'Zinc finger, RING-type, eukaryotic',
#  'IPR026739': 'AP complex subunit beta',
#  'IPR005334': 'Dynein light chain Tctex-1 like',
#  'IPR038586': 'Tctex-1-like superfamily',
#  'IPR044034': 'Nascent polypeptide-associated complex subunit alpha-like, UBA domain',
#  'IPR038922': 'Huntingtin-interacting protein K, UBA-like domain',
#  'IPR050378': 'Metallo-dependent Hydrolases Superfamily',
#  'IPR003010': 'Carbon-nitrogen hydrolase',
#  'IPR011778': 'Hydantoinase/dihydropyrimidinase',
#  'IPR011059': 'Metal-dependent hydrolase, composite domain superfamily',
#  'IPR006680': 'Amidohydrolase-related',
#  'IPR036526': 'Carbon-nitrogen hydrolase superfamily',
#  'IPR024743': 'Dynein heavy chain, coiled coil stalk',
#  'IPR024317': 'Dynein heavy chain, AAA module D4',
#  'IPR041658': 'Dynein heavy chain AAA lid domain',
#  'IPR013602': 'Dynein heavy chain, linker',
#  'IPR041589': 'Dynein heavy chain 3, AAA+ lid domain',
#  'IPR035706': 'Dynein heavy chain, ATP-binding dynein motor region',
#  'IPR042228': 'Dynein heavy chain, linker, subdomain 3',
#  'IPR013594': 'Dynein heavy chain, tail',
#  'IPR043160': 'Dynein heavy chain, C-terminal domain, barrel region',
#  'IPR042219': 'Dynein heavy chain AAA lid domain superfamily',
#  'IPR004273': 'Dynein heavy chain region D6 P-loop domain',
#  'IPR042222': 'Dynein heavy chain, domain 2, N-terminal',
#  'IPR043157': 'Dynein heavy chain, AAA1 domain, small subdomain',
#  'IPR041228': 'Dynein heavy chain, C-terminal domain',
#  'IPR017938': 'Riboflavin synthase-like beta-barrel',
#  'IPR029039': 'Flavoprotein-like superfamily',
#  'IPR003097': 'Sulfite reductase [NADPH] flavoprotein alpha-component-like, FAD-binding',
#  'IPR008254': 'Flavodoxin/nitric oxide synthase',
#  'IPR039261': 'Ferredoxin-NADP reductase (FNR), nucleotide-binding domain',
#  'IPR023173': 'NADPH-cytochrome p450 reductase, FAD-binding, alpha-helical domain superfamily',
#  'IPR003018': 'GAF domain',
#  'IPR029016': 'GAF-like domain superfamily',
#  'IPR014436': 'Extradiol aromatic ring-opening dioxygenase, DODA-type',
#  'IPR004183': 'Extradiol ring-cleavage dioxygenase, class III enzyme, subunit B',
#  'IPR009316': 'COG complex component, COG2',
#  'IPR024603': 'COG complex component, COG2, C-terminal',
#  'IPR038252': 'Ubiquitin-activating enzyme E1, C-terminal domain superfamily',
#  'IPR042063': 'Ubiquitin-activating enzyme E1, SCCH domain',
#  'IPR032418': 'Ubiquitin-activating enzyme E1, FCCH domain',
#  'IPR042449': 'Ubiquitin-activating enzyme E1, inactive adenylation domain, subdomain 1',
#  'IPR042302': 'Ubiquitin-activating enzyme E1, FCCH domain superfamily',
#  'IPR018075': 'Ubiquitin-activating enzyme E1',
#  'IPR000011': 'Ubiquitin/SUMO-activating enzyme E1-like',
#  'IPR018965': 'Ubiquitin-activating enzyme E1, C-terminal',
#  'IPR019572': 'Ubiquitin-activating enzyme, SCCH domain',
#  'IPR039304': 'Dynein assembly factor 3, axonemal',
#  'IPR027974': 'Domain of unknown function DUF4470',
#  'IPR028235': 'Dynein assembly factor 3, C-terminal domain',
#  'IPR000629': 'ATP-dependent RNA helicase DEAD-box, conserved site',
#  'IPR014014': 'RNA helicase, DEAD-box type, Q motif',
#  'IPR000504': 'RNA recognition motif domain',
#  'IPR051945': 'RRM MRD1 RNA Processing and Ribosome Biogenesis',
#  'IPR012677': 'Nucleotide-binding alpha-beta plait domain superfamily',
#  'IPR035979': 'RNA-binding domain superfamily',
#  'IPR023626': 'Large ribosomal subunit protein eL39 domain superfamily',
#  'IPR000077': 'Large ribosomal subunit protein eL39',
#  'IPR020083': 'Large ribosomal subunit protein eL39, conserved site',
#  'IPR003656': 'Zinc finger, BED-type',
#  'IPR032714': 'Cilium assembly protein DZIP1, N-terminal',
#  'IPR034393': 'TatSF1-like',
#  'IPR034392': 'TatSF1-like, RNA recognition motif 1',
#  'IPR025640': 'GYF domain 2',
#  'IPR050079': 'DEAD box RNA helicase',
#  'IPR025313': 'ATP-dependent rRNA helicase SPB4-like, C-terminal extension',
#  'IPR028596': 'Katanin p60 subunit A1',
#  'IPR015415': 'Spastin/Vps4, C-terminal',
#  'IPR029062': 'Class I glutamine amidotransferase-like',
#  'IPR044992': 'Glutamine amidotransferase domain containing protein ChyE-like',
#  'IPR017926': 'Glutamine amidotransferase',
#  'IPR051514': 'R-spondin domain-containing protein',
#  'IPR051223': 'Polycystin',
#  'IPR036534': 'GAR domain superfamily',
#  'IPR003108': 'GAR domain',
#  'IPR008733': 'Peroxisomal biogenesis factor 11',
#  'IPR051181': 'CAF1 family poly(A)-specific ribonucleases',
#  'IPR006941': 'Ribonuclease CAF1',
#  'IPR001563': 'Peptidase S10, serine carboxypeptidase',
#  'IPR018202': 'Serine carboxypeptidase, serine active site',
#  'IPR033124': 'Serine carboxypeptidases, histidine active site',
#  'IPR039467': "Transcription factor TFIIIB component B'', Myb domain",
#  'IPR007305': 'Vesicle transport protein, Got1/SFT2-like',
#  'IPR045176': 'Protein transport protein Got1',
#  'IPR035940': 'CAP superfamily',
#  'IPR014044': 'CAP domain',
#  'IPR017984': 'Chromo domain subgroup',
#  'IPR000850': 'Adenylate kinase/UMP-CMP kinase',
#  'IPR018392': 'LysM domain',
#  'IPR036779': 'LysM domain superfamily',
#  'IPR045030': 'LysM and putative peptidoglycan-binding domain-containing protein 1-4',
#  'IPR004839': 'Aminotransferase, class I/classII',
#  'IPR015424': 'Pyridoxal phosphate-dependent transferase',
#  'IPR015422': 'Pyridoxal phosphate-dependent transferase, small domain',
#  'IPR005958': 'Tyrosine/nicotianamine aminotransferase',
#  'IPR015421': 'Pyridoxal phosphate-dependent transferase, major domain',
#  'IPR007523': 'NDUFAF3/Mth938 domain-containing protein',
#  'IPR036748': 'MTH938-like superfamily',
#  'IPR002528': 'Multi antimicrobial extrusion protein',
#  'IPR019474': 'Ubiquitin conjugation factor E4, core',
#  'IPR045132': 'Ubiquitin conjugation factor E4',
#  'IPR001296': 'Glycosyl transferase, family 1',
#  'IPR028098': 'Glycosyltransferase subfamily 4-like, N-terminal domain',
#  'IPR026051': 'Chitobiosyldiphosphodolichol beta-mannosyltransferase ALG1-like',
#  'IPR009001': 'Translation elongation factor EF1A/initiation factor IF2gamma, C-terminal',
#  'IPR000795': 'Translational (tr)-type GTP-binding domain',
#  'IPR009000': 'Translation protein, beta-barrel domain superfamily',
#  'IPR050100': 'Translation factor GTPase superfamily members',
#  'IPR040364': 'Tetratricopeptide repeat protein 21A/21B',
#  'IPR000306': 'FYVE zinc finger',
#  'IPR036440': 'Peptidase C15, pyroglutamyl peptidase I-like superfamily',
#  'IPR016125': 'Peptidase C15, pyroglutamyl peptidase I-like',
#  'IPR026205': 'Progesterone-induced-blocking factor 1',
#  'IPR001245': 'Serine-threonine/tyrosine-protein kinase, catalytic domain',
#  'IPR014825': 'DNA alkylation repair enzyme',
#  'IPR030125': 'SPIN90/Ldb17',
#  'IPR018556': 'SPIN90/Ldb17, leucine-rich domain',
#  ...}

# %%
interpro_desc_list = list(interpro_desc_dict.items())

interpro_desc_df = pd.DataFrame(interpro_desc_list, columns=['InterPro', 'InterPro_description'])

# %%
interpro_desc_df.head()
# Out:
#     InterPro                               InterPro_description
# 0  IPR009030  Growth factor receptor cysteine-rich domain su...
# 1          -                                                  -
# 2  IPR006212                                  Furin-like repeat
# 3  IPR000742                                    EGF-like domain
# 4  IPR001577                       Peptidase M8, leishmanolysin

# %%
interpro_desc_df.sort_values(by='InterPro').to_csv('./interpro_annotations.csv', index=False)

# %%
interpro_dict = {
        'TTHERM_ID': [],
        'InterPro': [],
}

for id in annot_df_raw['Protein accession'].unique():

    curr_df = annot_df_raw.loc[annot_df_raw['Protein accession'] == id]

    ipaa = sorted(list(curr_df['InterPro annotations - accession'].unique()))

    interpro_dict['TTHERM_ID'].append(id)
    interpro_dict['InterPro'].append(
                                                            ','.join(ipaa[1: ])
                                                            if len(ipaa) > 1 and ipaa[0] == '-' else ipaa[0]
                                                            )
    
interpro_df = pd.DataFrame(interpro_dict)

# %%
interpro_df.sample(20)
# Out:
#              TTHERM_ID                                           InterPro
# 2175   TTHERM_00522480            IPR000595,IPR014710,IPR018490,IPR043533
# 12695  TTHERM_00160980                                IPR006876,IPR051584
# 6891   TTHERM_00028680                                          IPR004947
# 15037  TTHERM_01260060                      IPR001611,IPR027038,IPR032675
# 15386  TTHERM_01279550                                IPR006553,IPR032675
# 3113   TTHERM_00584690                                          IPR011992
# 8096   TTHERM_00455230                                          IPR040040
# 12059  TTHERM_00420980            IPR001680,IPR015943,IPR020472,IPR036322
# 21469  TTHERM_01197000                                          IPR006212
# 16543  TTHERM_00077380                                                  -
# 420    TTHERM_00194360                                IPR007599,IPR035952
# 606    TTHERM_00849330                                                  -
# 18538  TTHERM_00086825                                          IPR032675
# 17910  TTHERM_00632910                      IPR001611,IPR027038,IPR032675
# 21546  TTHERM_00727745                                          IPR022214
# 17212  TTHERM_00075590  IPR001680,IPR002130,IPR015943,IPR020892,IPR029...
# 10417  TTHERM_00940250                      IPR017452,IPR017981,IPR022343
# 7817   TTHERM_00322910                      IPR005304,IPR029026,IPR029028
# 14166  TTHERM_00298420  IPR000642,IPR003593,IPR003959,IPR003960,IPR005...
# 13571  TTHERM_01260750                                IPR035965,IPR052994

# %%
interpro_df.shape
# Out:
# (21654, 2)

# %%
interpro_df = interpro_df.loc[
    (interpro_df['InterPro'] != '-')
    # &
    # (interpro_df['InterPro annotations - description'] != '-')
    # |
    # (interpro_df['InterPro annotations - description'] != '-')
]

# %%
interpro_df
# Out:
#              TTHERM_ID                                           InterPro
# 0      TTHERM_00541547            IPR000742,IPR001577,IPR006212,IPR009030
# 1      TTHERM_01124020                                          IPR009851
# 2      TTHERM_01184230  IPR000595,IPR013099,IPR014710,IPR018490,IPR051413
# 3      TTHERM_00095380  IPR014001,IPR027417,IPR041677,IPR041679,IPR045...
# 4      TTHERM_00238980  IPR001752,IPR019821,IPR027417,IPR027640,IPR036961
# ...                ...                                                ...
# 21646  TTHERM_00829340                                          IPR001611
# 21647  TTHERM_00426250  IPR000447,IPR006076,IPR031656,IPR036188,IPR038299
# 21649  TTHERM_01073470  IPR001005,IPR009057,IPR017930,IPR021786,IPR047...
# 21650  TTHERM_00630640                      IPR001611,IPR027038,IPR032675
# 21651  TTHERM_00760540                                          IPR015019
#
# [15624 rows x 2 columns]

# %%
dataframe_utils.sql_query_df({'interpro_df': interpro_df}, 'select * from interpro_df where InterPro not like "%IPR%"')
# Out:
# Empty DataFrame
# Columns: [TTHERM_ID, InterPro]
# Index: []

# %%
interpro_df.sort_values(by='TTHERM_ID').to_csv('./interpro_annot.csv', index=False)

# %%
# annot_df_raw['Analysis'].unique()

# %%
# analysis_dfs = []

# for analysis in annot_df_raw['Analysis'].unique():
#     curr_analysis_dict = {
#         'TTHERM_ID': [],
#         analysis: [],
#         f'{analysis}_desc': [],
#     }

#     curr_analysis_df = annot_df_raw.loc[annot_df_raw['Analysis'] == analysis]

#     curr_analysis_dict['TTHERM_ID'] += list(curr_analysis_df['Protein accession'].values)
#     curr_analysis_dict[analysis] += list(curr_analysis_df['Signature accession'].values)
#     curr_analysis_dict[f'{analysis}_desc'] += list(curr_analysis_df['Signature description'].values)

#     analysis_dfs.append(pd.DataFrame(curr_analysis_dict))

# %%
# combined_df = pd.DataFrame({'TTHERM_ID': annot_df_raw['Protein accession'].values})

# for idx, df in enumerate(analysis_dfs):
#     # combined_df = combined_df.merge(df, on='TTHERM_ID', how='outer')
#     combined_df = dataframe_utils.sql_query_df({'combined_df': combined_df, 'df': df},
# '''SELECT *
# FROM combined_df
# FULL OUTER JOIN df
# ON combined_df.TTHERM_ID = df.TTHERM_ID;''')
