# %%
import pandas as pd
from json import load

# %%
qc_rma_signal_data_df = pd.read_csv('../microarray_QC/QC_probe_rma_values.csv')
qc_rma_signal_data_df.head()
# Out:
#          Unnamed: 0  C0_GSM285570.xys  C0_GSM656230.xys  C10_GSM285578.xys  \
# 0  TTHERM_000000042          6.161783          5.057687           6.621031
# 1  TTHERM_000000045         11.386933         11.193811          11.229506
# 2   TTHERM_00000010         10.830266          9.836930           5.805547
# 3   TTHERM_00000020          8.623682          5.570322           4.974599
# 4   TTHERM_00000030          6.035942          4.757383           4.829810
#
#    C10_GSM285591.xys  C12_GSM285579.xys  C12_GSM285592.xys  C12_GSM656237.xys  \
# 0           6.656588           7.559767           7.763309           6.450318
# 1          10.873188          10.801168          10.834801          11.130466
# 2           6.005496           6.202794           6.237380           6.314438
# 3           5.436244           5.051285           5.577026           5.250233
# 4           4.835038           5.185818           4.862489           4.651688
#
#    C14_GSM285580.xys  C14_GSM285593.xys  ...  S3_GSM285542.xys  \
# 0           8.049750           7.788162  ...          6.058490
# 1          11.207738          11.009172  ...         10.859625
# 2           7.423571           7.507645  ...          9.125377
# 3           4.974993           5.747498  ...          7.443906
# 4           4.920573           4.636333  ...          7.582175
#
#    S3_GSM285555.xys  S3_GSM285562.xys  S6_GSM285543.xys  S6_GSM285556.xys  \
# 0          6.404280          6.950018          6.006570          5.792800
# 1         11.047529         10.865832         10.806576         10.705724
# 2          8.647941          8.126324         10.720722          9.868662
# 3          8.055853          5.551413          8.174586          6.869377
# 4          6.712158          5.595456          9.599540          8.572935
#
#    S6_GSM285563.xys  S9_GSM285544.xys  S9_GSM285564.xys  S9_GSM647653.xys  \
# 0          6.897388          6.496772          7.006359          5.547167
# 1         10.943747         11.259886         11.069086         11.345458
# 2          7.614758          9.664811          8.535958         10.010385
# 3          5.811808          6.470432          5.692521          7.722280
# 4          5.345320          8.511582          5.509824          8.745682
#
#    S9_GSM647654.xys
# 0          5.733327
# 1         11.425561
# 2         10.104864
# 3          6.830825
# 4          8.708604
#
# [5 rows x 52 columns]

# %%
qc_rma_signal_data_df.rename(columns={'Unnamed: 0': 'TTHERM_ID'}, inplace=True)
qc_rma_signal_data_df.rename(columns={c: c.split('.')[0] for c in qc_rma_signal_data_df.columns}, inplace=True)
qc_rma_signal_data_df.head()
# Out:
#           TTHERM_ID  C0_GSM285570  C0_GSM656230  C10_GSM285578  C10_GSM285591  \
# 0  TTHERM_000000042      6.161783      5.057687       6.621031       6.656588
# 1  TTHERM_000000045     11.386933     11.193811      11.229506      10.873188
# 2   TTHERM_00000010     10.830266      9.836930       5.805547       6.005496
# 3   TTHERM_00000020      8.623682      5.570322       4.974599       5.436244
# 4   TTHERM_00000030      6.035942      4.757383       4.829810       4.835038
#
#    C12_GSM285579  C12_GSM285592  C12_GSM656237  C14_GSM285580  C14_GSM285593  \
# 0       7.559767       7.763309       6.450318       8.049750       7.788162
# 1      10.801168      10.834801      11.130466      11.207738      11.009172
# 2       6.202794       6.237380       6.314438       7.423571       7.507645
# 3       5.051285       5.577026       5.250233       4.974993       5.747498
# 4       5.185818       4.862489       4.651688       4.920573       4.636333
#
#    ...  S3_GSM285542  S3_GSM285555  S3_GSM285562  S6_GSM285543  S6_GSM285556  \
# 0  ...      6.058490      6.404280      6.950018      6.006570      5.792800
# 1  ...     10.859625     11.047529     10.865832     10.806576     10.705724
# 2  ...      9.125377      8.647941      8.126324     10.720722      9.868662
# 3  ...      7.443906      8.055853      5.551413      8.174586      6.869377
# 4  ...      7.582175      6.712158      5.595456      9.599540      8.572935
#
#    S6_GSM285563  S9_GSM285544  S9_GSM285564  S9_GSM647653  S9_GSM647654
# 0      6.897388      6.496772      7.006359      5.547167      5.733327
# 1     10.943747     11.259886     11.069086     11.345458     11.425561
# 2      7.614758      9.664811      8.535958     10.010385     10.104864
# 3      5.811808      6.470432      5.692521      7.722280      6.830825
# 4      5.345320      8.511582      5.509824      8.745682      8.708604
#
# [5 rows x 52 columns]

# %%
len(qc_rma_signal_data_df['TTHERM_ID'].values)
# Out:
# 23614

# %%
with open('../../new_raw_data/microarray_accessions_all.json', 'r') as f:
    # Including single REP measurement for C-15m (GSM656231) even though there are no replicates for it
    # in order to replicate the 2011 analysis
    # Format: keys are the physiological phase; values are the geo accessions for each microarray
    all_geo = load(f)
all_geo
# Out:
# {'Ll': ['GSM283687', 'GSM284355', 'GSM284362'],
#  'Lm': ['GSM283690', 'GSM284357', 'GSM284363'],
#  'Lh': ['GSM283691', 'GSM284360', 'GSM284364'],
#  'S0': ['GSM285363',
#   'GSM285554',
#   'GSM285561',
#   'GSM647244',
#   'GSM647651',
#   'GSM647652'],
#  'S3': ['GSM285542', 'GSM285555', 'GSM285562'],
#  'S6': ['GSM285543', 'GSM285556', 'GSM285563'],
#  'S9': ['GSM285544', 'GSM285557', 'GSM285564', 'GSM647653', 'GSM647654'],
#  'S12': ['GSM285545', 'GSM285558', 'GSM285565'],
#  'S15': ['GSM285546', 'GSM285559', 'GSM285566'],
#  'S24': ['GSM285547', 'GSM285560', 'GSM285567', 'GSM647245'],
#  'C0': ['GSM285570', 'GSM285586', 'GSM656230'],
#  'C15m': ['GSM656231'],
#  'C2': ['GSM285572', 'GSM285587', 'GSM656233'],
#  'C4': ['GSM285574', 'GSM285588', 'GSM656234'],
#  'C6': ['GSM285575', 'GSM285589', 'GSM656232'],
#  'C8': ['GSM285576', 'GSM285590', 'GSM656236'],
#  'C10': ['GSM285578', 'GSM285591', 'GSM656235'],
#  'C12': ['GSM285579', 'GSM285592', 'GSM656237'],
#  'C14': ['GSM285580', 'GSM285593', 'GSM656238'],
#  'C16': ['GSM285582', 'GSM285595', 'GSM656239'],
#  'C18': ['GSM285583', 'GSM285596', 'GSM656240']}

# %%
col_names = []

for key in all_geo:
    for val in all_geo[key]:
        col_names.append(f'{key}_{val}')

# %%
ordered_columns = [c for c in col_names if c in qc_rma_signal_data_df.columns[1:]]
ordered_columns
# Out:
# ['Ll_GSM283687',
#  'Ll_GSM284355',
#  'Ll_GSM284362',
#  'Lm_GSM283690',
#  'Lm_GSM284357',
#  'Lm_GSM284363',
#  'Lh_GSM283691',
#  'Lh_GSM284360',
#  'Lh_GSM284364',
#  'S0_GSM285363',
#  'S0_GSM285554',
#  'S0_GSM285561',
#  'S0_GSM647651',
#  'S0_GSM647652',
#  'S3_GSM285542',
#  'S3_GSM285555',
#  'S3_GSM285562',
#  'S6_GSM285543',
#  'S6_GSM285556',
#  'S6_GSM285563',
#  'S9_GSM285544',
#  'S9_GSM285564',
#  'S9_GSM647653',
#  'S9_GSM647654',
#  'S15_GSM285559',
#  'S15_GSM285566',
#  'S24_GSM285547',
#  'S24_GSM285560',
#  'C0_GSM285570',
#  'C0_GSM656230',
#  'C4_GSM285574',
#  'C4_GSM285588',
#  'C4_GSM656234',
#  'C6_GSM285575',
#  'C6_GSM656232',
#  'C8_GSM285576',
#  'C8_GSM285590',
#  'C10_GSM285578',
#  'C10_GSM285591',
#  'C12_GSM285579',
#  'C12_GSM285592',
#  'C12_GSM656237',
#  'C14_GSM285580',
#  'C14_GSM285593',
#  'C14_GSM656238',
#  'C16_GSM285582',
#  'C16_GSM285595',
#  'C16_GSM656239',
#  'C18_GSM285583',
#  'C18_GSM285596',
#  'C18_GSM656240']

# %%
tidy_column_order_list = ['TTHERM_ID'] + ordered_columns
tidy_column_order_list
# Out:
# ['TTHERM_ID',
#  'Ll_GSM283687',
#  'Ll_GSM284355',
#  'Ll_GSM284362',
#  'Lm_GSM283690',
#  'Lm_GSM284357',
#  'Lm_GSM284363',
#  'Lh_GSM283691',
#  'Lh_GSM284360',
#  'Lh_GSM284364',
#  'S0_GSM285363',
#  'S0_GSM285554',
#  'S0_GSM285561',
#  'S0_GSM647651',
#  'S0_GSM647652',
#  'S3_GSM285542',
#  'S3_GSM285555',
#  'S3_GSM285562',
#  'S6_GSM285543',
#  'S6_GSM285556',
#  'S6_GSM285563',
#  'S9_GSM285544',
#  'S9_GSM285564',
#  'S9_GSM647653',
#  'S9_GSM647654',
#  'S15_GSM285559',
#  'S15_GSM285566',
#  'S24_GSM285547',
#  'S24_GSM285560',
#  'C0_GSM285570',
#  'C0_GSM656230',
#  'C4_GSM285574',
#  'C4_GSM285588',
#  'C4_GSM656234',
#  'C6_GSM285575',
#  'C6_GSM656232',
#  'C8_GSM285576',
#  'C8_GSM285590',
#  'C10_GSM285578',
#  'C10_GSM285591',
#  'C12_GSM285579',
#  'C12_GSM285592',
#  'C12_GSM656237',
#  'C14_GSM285580',
#  'C14_GSM285593',
#  'C14_GSM656238',
#  'C16_GSM285582',
#  'C16_GSM285595',
#  'C16_GSM656239',
#  'C18_GSM285583',
#  'C18_GSM285596',
#  'C18_GSM656240']

# %%
len(tidy_column_order_list)
# Out:
# 52

# %%
len(list(qc_rma_signal_data_df.columns))
# Out:
# 52

# %%
tidy_qc_rma_signal_data_df = qc_rma_signal_data_df.loc[:,tidy_column_order_list]
tidy_qc_rma_signal_data_df.head()
# Out:
#           TTHERM_ID  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      6.928782      7.264201      6.934214      6.732989
# 1  TTHERM_000000045      9.633489      9.977124     10.027529      9.720665
# 2   TTHERM_00000010      5.066343      4.767264      5.010981      6.139047
# 3   TTHERM_00000020      4.696881      4.638401      4.956299      6.942556
# 4   TTHERM_00000030      4.654278      4.537105      4.928739      5.063991
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      6.970612      7.150978      6.126826      6.868968      6.641119  ...
# 1      9.605762     10.225542     10.279608     10.459966     10.693337  ...
# 2      4.619361      4.751761      5.818550      5.342529      5.483750  ...
# 3      5.101252      4.730307      8.457690      4.526411      4.908300  ...
# 4      4.584168      4.911880      5.935311      4.519470      4.757861  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       6.450318       8.049750       7.788162       7.052154       6.517742
# 1      11.130466      11.207738      11.009172      10.615417      11.038938
# 2       6.314438       7.423571       7.507645       7.417087       7.147801
# 3       5.250233       4.974993       5.747498       5.252167       5.210531
# 4       4.651688       4.920573       4.636333       4.883712       4.779395
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       6.918501       6.048861       7.041619       6.757932       5.817246
# 1      11.009222      10.216348      11.099187      11.172276      10.561021
# 2       7.747930       7.093641       7.672685       7.511290       6.890117
# 3       7.083187       5.252222       5.037613       5.495281       5.013987
# 4       4.744335       4.513140       4.838428       4.961475       4.653340
#
# [5 rows x 52 columns]

# %%
tidy_qc_rma_signal_data_df.shape
# Out:
# (23614, 52)

# %%
duplicates = tidy_qc_rma_signal_data_df['TTHERM_ID'].duplicated()
tidy_qc_rma_signal_data_df[duplicates]
# Out:
# Empty DataFrame
# Columns: [TTHERM_ID, Ll_GSM283687, Ll_GSM284355, Ll_GSM284362, Lm_GSM283690, Lm_GSM284357, Lm_GSM284363, Lh_GSM283691, Lh_GSM284360, Lh_GSM284364, S0_GSM285363, S0_GSM285554, S0_GSM285561, S0_GSM647651, S0_GSM647652, S3_GSM285542, S3_GSM285555, S3_GSM285562, S6_GSM285543, S6_GSM285556, S6_GSM285563, S9_GSM285544, S9_GSM285564, S9_GSM647653, S9_GSM647654, S15_GSM285559, S15_GSM285566, S24_GSM285547, S24_GSM285560, C0_GSM285570, C0_GSM656230, C4_GSM285574, C4_GSM285588, C4_GSM656234, C6_GSM285575, C6_GSM656232, C8_GSM285576, C8_GSM285590, C10_GSM285578, C10_GSM285591, C12_GSM285579, C12_GSM285592, C12_GSM656237, C14_GSM285580, C14_GSM285593, C14_GSM656238, C16_GSM285582, C16_GSM285595, C16_GSM656239, C18_GSM285583, C18_GSM285596, C18_GSM656240]
# Index: []
#
# [0 rows x 52 columns]

# %%
growth = ['Ll', 'Lm', 'Lh']
starvation = ['S0', 'S3', 'S6', 'S9', 'S12', 'S15', 'S24']
conjugation = ['C0', 'C15m', 'C2', 'C4', 'C6', 'C8', 'C10', 'C12', 'C14', 'C16', 'C18']
vegetative = growth + starvation

grow_cols = [c for c in tidy_qc_rma_signal_data_df.columns if c.split('_')[0] in growth]
starve_cols = [c for c in tidy_qc_rma_signal_data_df.columns if c.split('_')[0] in starvation]
sex_cols = [c for c in tidy_qc_rma_signal_data_df.columns if c.split('_')[0] in conjugation]
veg_cols = [c for c in tidy_qc_rma_signal_data_df.columns if c.split('_')[0] in vegetative]

# %%
tidy_qc_rma_signal_data_df_grow = tidy_qc_rma_signal_data_df[['TTHERM_ID'] + grow_cols]
tidy_qc_rma_signal_data_df_starve = tidy_qc_rma_signal_data_df[['TTHERM_ID'] + starve_cols]
tidy_qc_rma_signal_data_df_sex = tidy_qc_rma_signal_data_df[['TTHERM_ID'] + sex_cols]
tidy_qc_rma_signal_data_df_veg = tidy_qc_rma_signal_data_df[['TTHERM_ID'] + veg_cols]

# %%
tidy_qc_rma_signal_data_df.to_csv('./agg_tidy_2021aligned_qc_rma_expression_full.csv', index=False)
tidy_qc_rma_signal_data_df_grow.to_csv('./agg_tidy_2021aligned_qc_rma_expression_grow.csv', index=False)
tidy_qc_rma_signal_data_df_starve.to_csv('./agg_tidy_2021aligned_qc_rma_expression_starve.csv', index=False)
tidy_qc_rma_signal_data_df_veg.to_csv('./agg_tidy_2021aligned_qc_rma_expression_veg.csv', index=False)
tidy_qc_rma_signal_data_df_sex.to_csv('./agg_tidy_2021aligned_qc_rma_expression_sex.csv', index=False)
