# %%
import pandas as pd
import numpy as np

# %%
all_good_filtered_df = pd.read_csv('../microarray_probe_alignment_and_filtering/allgood_filt_agg_tidy_2021aligned_qc_rma_expression_full.csv')
all_good_filtered_df.head()
# Out:
#          Unnamed: 0  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      6.048861      7.919037      8.049750      6.517742
# 1  TTHERM_000000045     10.279608     10.615417     10.387395      9.633489
# 2   TTHERM_00000010      7.093641      6.416601      7.614758      6.230779
# 3   TTHERM_00000020      8.563845      4.974599      8.174586      5.210531
# 4   TTHERM_00000030      4.925506      4.757861      5.459656      4.513140
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      7.788162      6.404280      6.412490      7.133459      6.928782  ...
# 1     10.474965     11.009222     10.365769     10.943747     11.386933  ...
# 2      7.423571      7.795560      7.672685      8.126324      6.005496  ...
# 3      8.457690      4.908300      5.570322      4.471576      5.252167  ...
# 4      5.595456      5.935311      6.712158      4.829810      4.839549  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       7.559767       7.551087       6.918501       5.837645       7.052154
# 1      10.565662      11.172276      11.099187      10.756614      10.216348
# 2       9.664811       6.314438       5.483750       8.514044       4.619361
# 3       7.443906       5.252222       6.942556       5.692521       5.436244
# 4       4.779395       5.185818       4.862489       4.757031       4.537105
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       6.732989       5.817246       6.757932       6.450318       7.150978
# 1      11.229506       9.977124      10.801168      11.147059      11.437405
# 2       6.569601       7.747930       6.806230       7.703284      10.720722
# 3       5.250233       7.850878       5.037613       4.526411       8.055853
# 4       4.650699       4.584168       5.778574       4.744335       4.636333
#
# [5 rows x 48 columns]

# %%
row_before = all_good_filtered_df[all_good_filtered_df['Unnamed: 0'] == 'TTHERM_000000045'].iloc[0].to_list()
row_before
# Out:
# ['TTHERM_000000045',
#  10.2796076736323,
#  10.6154174122116,
#  10.387395294209,
#  9.63348945750135,
#  10.4749649578478,
#  11.0092223634905,
#  10.3657693135432,
#  10.943747297682,
#  11.3869328088529,
#  9.72066499457012,
#  11.4078014907261,
#  11.1585749625366,
#  11.1304661898713,
#  10.7057238299974,
#  10.027529224492,
#  10.8065762994081,
#  11.0475287438773,
#  10.8658315709889,
#  10.6933367137174,
#  11.1938106308639,
#  10.6067884020829,
#  11.0091716588798,
#  10.8348010054154,
#  10.8596252921786,
#  10.918467456148,
#  9.60576165439986,
#  10.561020841315,
#  11.0389384309738,
#  10.5592089855906,
#  10.4599658135965,
#  11.2077383927052,
#  10.8695154893307,
#  10.2255418537393,
#  11.0690862030554,
#  10.8731876335348,
#  11.2598857309259,
#  11.2196993786901,
#  10.5656618947703,
#  11.172275859071,
#  11.0991873445735,
#  10.7566137458041,
#  10.2163481019082,
#  11.2295058710607,
#  9.97712401794542,
#  10.8011681261152,
#  11.1470585557108,
#  11.437404836036]

# %%
columns_to_shuffle = all_good_filtered_df.columns[1:]
print(len(columns_to_shuffle))
columns_to_shuffle
# Out:
# 47
# Index(['Ll_GSM283687', 'Ll_GSM284355', 'Ll_GSM284362', 'Lm_GSM283690',
#        'Lm_GSM284357', 'Lm_GSM284363', 'Lh_GSM283691', 'Lh_GSM284360',
#        'Lh_GSM284364', 'S0_GSM285363', 'S0_GSM285554', 'S0_GSM285561',
#        'S3_GSM285542', 'S3_GSM285555', 'S3_GSM285562', 'S6_GSM285543',
#        'S6_GSM285556', 'S6_GSM285563', 'S9_GSM285544', 'S9_GSM285564',
#        'S15_GSM285559', 'S15_GSM285566', 'S24_GSM285547', 'S24_GSM285560',
#        'C0_GSM285570', 'C0_GSM656230', 'C4_GSM285574', 'C4_GSM285588',
#        'C4_GSM656234', 'C6_GSM285575', 'C6_GSM656232', 'C8_GSM285576',
#        'C8_GSM285590', 'C10_GSM285578', 'C10_GSM285591', 'C12_GSM285579',
#        'C12_GSM285592', 'C12_GSM656237', 'C14_GSM285580', 'C14_GSM285593',
#        'C14_GSM656238', 'C16_GSM285582', 'C16_GSM285595', 'C16_GSM656239',
#        'C18_GSM285583', 'C18_GSM285596', 'C18_GSM656240'],
#       dtype='object')

# %%
def shuffle_row(row):
    shuffled_row = row.values.copy()
    np.random.shuffle(shuffled_row)
    return pd.Series(shuffled_row, index=row.index)

# %%
all_good_filtered_df[columns_to_shuffle] = all_good_filtered_df[columns_to_shuffle].apply(shuffle_row, axis=1)

# %%
all_good_filtered_df.head()
# Out:
#          Unnamed: 0  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      7.559767      5.792800      6.950018      6.540692
# 1  TTHERM_000000045     10.365769      9.633489     11.407801     10.459966
# 2   TTHERM_00000010      7.795560      5.464501      6.237380      5.805547
# 3   TTHERM_00000020      4.471576      4.956299      4.638401      6.470432
# 4   TTHERM_00000030      4.651688      5.595456      5.185818      5.579639
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      7.898334      6.656588      6.753910      6.348526      8.049750  ...
# 1     10.279608     10.834801     10.615417     10.859625     10.806576  ...
# 2      6.397369      7.614758      4.992709     10.720722      6.890117  ...
# 3      5.436244      5.051285      5.037613      5.811808      5.213117  ...
# 4      4.584168      4.756852      4.636333      4.537105      4.829810  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       7.006359       6.302364       6.897388       5.817246       6.126826
# 1      11.038938      10.801168      11.130466      10.943747      10.559209
# 2       9.125377       5.342529       8.126324       7.423571       7.511290
# 3       5.250233       7.443906       5.252222       4.730307       7.083187
# 4       4.862489       6.712158       4.650699       4.839549       4.653340
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       6.641119       7.264201       7.763309       6.732989       6.006570
# 1      10.705724      11.207738      10.225542      10.561021      10.027529
# 2       7.147801       6.569601       6.139047       5.066343       8.535958
# 3       5.715788       5.747498       8.563845       9.045493       8.174586
# 4       5.401231       4.747674       5.063991       5.935311       8.417411
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Sanity check to ensure only values in the rows were shuffled:

# %%
row_after = all_good_filtered_df[all_good_filtered_df['Unnamed: 0'] == 'TTHERM_000000045'].iloc[0].to_list()
row_after
# Out:
# ['TTHERM_000000045',
#  10.3657693135432,
#  9.63348945750135,
#  11.4078014907261,
#  10.4599658135965,
#  10.2796076736323,
#  10.8348010054154,
#  10.6154174122116,
#  10.8596252921786,
#  10.8065762994081,
#  10.8658315709889,
#  11.2295058710607,
#  11.0690862030554,
#  10.6067884020829,
#  10.7566137458041,
#  11.2196993786901,
#  9.72066499457012,
#  11.437404836036,
#  11.1470585557108,
#  11.0092223634905,
#  11.0991873445735,
#  11.3869328088529,
#  11.1585749625366,
#  9.97712401794542,
#  10.6933367137174,
#  11.1938106308639,
#  11.172275859071,
#  11.0091716588798,
#  10.2163481019082,
#  11.2598857309259,
#  11.0475287438773,
#  10.4749649578478,
#  10.5656618947703,
#  10.8695154893307,
#  10.387395294209,
#  10.8731876335348,
#  9.60576165439986,
#  10.918467456148,
#  11.0389384309738,
#  10.8011681261152,
#  11.1304661898713,
#  10.943747297682,
#  10.5592089855906,
#  10.7057238299974,
#  11.2077383927052,
#  10.2255418537393,
#  10.561020841315,
#  10.027529224492]

# %%
len(row_before) == len(row_after)
# Out:
# True

# %%
for value in row_before:
    if value not in row_after:
        print(value)

# %%
for idx in range(len(row_before)):
    if row_before[idx] != row_after[idx]:
        print('DIFFERENT:', row_before[idx], 'IS NOT', row_after[idx])
# Out:
# DIFFERENT: 10.2796076736323 IS NOT 10.3657693135432
# DIFFERENT: 10.6154174122116 IS NOT 9.63348945750135
# DIFFERENT: 10.387395294209 IS NOT 11.4078014907261
# DIFFERENT: 9.63348945750135 IS NOT 10.4599658135965
# DIFFERENT: 10.4749649578478 IS NOT 10.2796076736323
# DIFFERENT: 11.0092223634905 IS NOT 10.8348010054154
# DIFFERENT: 10.3657693135432 IS NOT 10.6154174122116
# DIFFERENT: 10.943747297682 IS NOT 10.8596252921786
# DIFFERENT: 11.3869328088529 IS NOT 10.8065762994081
# DIFFERENT: 9.72066499457012 IS NOT 10.8658315709889
# DIFFERENT: 11.4078014907261 IS NOT 11.2295058710607
# DIFFERENT: 11.1585749625366 IS NOT 11.0690862030554
# DIFFERENT: 11.1304661898713 IS NOT 10.6067884020829
# DIFFERENT: 10.7057238299974 IS NOT 10.7566137458041
# DIFFERENT: 10.027529224492 IS NOT 11.2196993786901
# DIFFERENT: 10.8065762994081 IS NOT 9.72066499457012
# DIFFERENT: 11.0475287438773 IS NOT 11.437404836036
# DIFFERENT: 10.8658315709889 IS NOT 11.1470585557108
# DIFFERENT: 10.6933367137174 IS NOT 11.0092223634905
# DIFFERENT: 11.1938106308639 IS NOT 11.0991873445735
# DIFFERENT: 10.6067884020829 IS NOT 11.3869328088529
# DIFFERENT: 11.0091716588798 IS NOT 11.1585749625366
# DIFFERENT: 10.8348010054154 IS NOT 9.97712401794542
# DIFFERENT: 10.8596252921786 IS NOT 10.6933367137174
# DIFFERENT: 10.918467456148 IS NOT 11.1938106308639
# DIFFERENT: 9.60576165439986 IS NOT 11.172275859071
# DIFFERENT: 10.561020841315 IS NOT 11.0091716588798
# DIFFERENT: 11.0389384309738 IS NOT 10.2163481019082
# DIFFERENT: 10.5592089855906 IS NOT 11.2598857309259
# DIFFERENT: 10.4599658135965 IS NOT 11.0475287438773
# DIFFERENT: 11.2077383927052 IS NOT 10.4749649578478
# DIFFERENT: 10.8695154893307 IS NOT 10.5656618947703
# DIFFERENT: 10.2255418537393 IS NOT 10.8695154893307
# DIFFERENT: 11.0690862030554 IS NOT 10.387395294209
# DIFFERENT: 11.2598857309259 IS NOT 9.60576165439986
# DIFFERENT: 11.2196993786901 IS NOT 10.918467456148
# DIFFERENT: 10.5656618947703 IS NOT 11.0389384309738
# DIFFERENT: 11.172275859071 IS NOT 10.8011681261152
# DIFFERENT: 11.0991873445735 IS NOT 11.1304661898713
# DIFFERENT: 10.7566137458041 IS NOT 10.943747297682
# DIFFERENT: 10.2163481019082 IS NOT 10.5592089855906
# DIFFERENT: 11.2295058710607 IS NOT 10.7057238299974
# DIFFERENT: 9.97712401794542 IS NOT 11.2077383927052
# DIFFERENT: 10.8011681261152 IS NOT 10.2255418537393
# DIFFERENT: 11.1470585557108 IS NOT 10.561020841315
# DIFFERENT: 11.437404836036 IS NOT 10.027529224492

# %%
all_good_filtered_df.to_csv('../microarray_probe_alignment_and_filtering/allgood_filt_agg_tidy_2021aligned_qc_rma_expression_full.csv', index=False)
