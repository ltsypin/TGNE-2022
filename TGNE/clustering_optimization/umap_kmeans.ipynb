# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, pairwise_distances
import numpy as np
import scipy.stats as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyclustering.cluster.kmeans import kmeans, kmeans_visualizer
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer
from pyclustering.utils.metric import distance_metric, type_metric
import umap

# %%
def shuffle_row(row):
    shuffled_row = row.values.copy()
    np.random.shuffle(shuffled_row)
    return pd.Series(shuffled_row, index=row.index)

def shuffle_rows(df):
    columns_to_shuffle = df.columns[1:]
    df[columns_to_shuffle] = df[columns_to_shuffle].apply(shuffle_row, axis=1)
    return df

# %%
def get_geom_mean_expression(expression_df):
    """
    
    Function to take an expression dataframe from the microarrays and collapse it into the means of
    all replicate chips.
    """
    # C2 and S12 got removed during quality control
    x = [
        'Ll', 
        'Lm', 
        'Lh', 
        'S0', 
        'S3', 
        'S6', 
        'S9', 
        # 'S12', 
        'S15', 
        'S24', 
        'C0', 
        # 'C2', 
        'C4', 
        'C6', 
        'C8', 
        'C10', 
        'C12', 
        'C14', 
        'C16', 
        'C18']
    
    # cols = expression_df.columns[1:]
    # x = [c for c in x if c in cols]
    
    condition_expr_dict = {c.split("_")[0]: [] for c in expression_df.columns[1:]}
    
    for c in list(expression_df.columns)[1:]:
        
        cond = c.split('_')[0]
        if cond in condition_expr_dict.keys():
            expr_list = condition_expr_dict.get(cond, [])

            # Need to avoid true zeros
            expr_list.append(expression_df[c].values)
            condition_expr_dict[cond] = expr_list
        
    condition_mean_dict = {c: (st.mstats.gmean(np.array(condition_expr_dict[c]) + 1, 0) - 1) for c in condition_expr_dict.keys() if c in x}
    
    mean_expr_df = pd.DataFrame(condition_mean_dict)
    mean_expr_df['TTHERM_ID'] = expression_df['TTHERM_ID'].values
    cols = list(mean_expr_df.columns)
    reorder = cols[-1:] + cols[:-1]
    mean_expr_df = mean_expr_df[reorder]
    
    return mean_expr_df

def normalizer(array):
    """
    Normalizes the values of an array to range from zero to one
    """
    
    a = np.array(array)
    
    normalized = (array - np.min(array)) / (np.max(array) - np.min(array))
    
    return normalized

def normalize_expression_per_gene(expression_df):
    """
    Function to normalize all gene expression to range from zero to one.
    """
    if 'TTHERM_ID' in expression_df.columns:
        ttids = expression_df['TTHERM_ID'].values
        data = expression_df[list(expression_df.columns)[1:]]
        
        norm_expression_df = data.apply(lambda row: normalizer(row), axis=1)
        norm_expression_df['TTHERM_ID'] = ttids
        
        columns = norm_expression_df.columns.tolist()
        
        rearrangment = columns[-1:] + columns[:-1]
        
        norm_expression_df = norm_expression_df[rearrangment]
        
    else:
        norm_expression_df = expression_df.apply(lambda row: normalizer(row), axis=1)
    
    return norm_expression_df

# %%
# Load your gene expression data
gene_data = pd.read_csv('../microarray_probe_alignment_and_filtering/allgood_filt_agg_tidy_2021aligned_qc_rma_expression_full.csv')  # Assuming the first column is the index
gene_data = gene_data.rename(columns={'Unnamed: 0': 'TTHERM_ID'})

# %%
gene_data.head()
# Out:
#           TTHERM_ID  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      6.928782      7.264201      6.934214      6.732989
# 1  TTHERM_000000045      9.633489      9.977124     10.027529      9.720665
# 2   TTHERM_00000010      5.066343      4.767264      5.010981      6.139047
# 3   TTHERM_00000020      4.696881      4.638401      4.956299      6.942556
# 4   TTHERM_00000030      4.654278      4.537105      4.928739      5.063991
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      6.970612      7.150978      6.126826      6.868968      6.641119  ...
# 1      9.605762     10.225542     10.279608     10.459966     10.693337  ...
# 2      4.619361      4.751761      5.818550      5.342529      5.483750  ...
# 3      5.101252      4.730307      8.457690      4.526411      4.908300  ...
# 4      4.584168      4.911880      5.935311      4.519470      4.757861  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       6.450318       8.049750       7.788162       7.052154       6.517742
# 1      11.130466      11.207738      11.009172      10.615417      11.038938
# 2       6.314438       7.423571       7.507645       7.417087       7.147801
# 3       5.250233       4.974993       5.747498       5.252167       5.210531
# 4       4.651688       4.920573       4.636333       4.883712       4.779395
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       6.918501       6.048861       7.041619       6.757932       5.817246
# 1      11.009222      10.216348      11.099187      11.172276      10.561021
# 2       7.747930       7.093641       7.672685       7.511290       6.890117
# 3       7.083187       5.252222       5.037613       5.495281       5.013987
# 4       4.744335       4.513140       4.838428       4.961475       4.653340
#
# [5 rows x 48 columns]

# %%
# gene_data = shuffle_rows(gene_data)

# %%
gene_data.head()
# Out:
#           TTHERM_ID  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      6.928782      7.264201      6.934214      6.732989
# 1  TTHERM_000000045      9.633489      9.977124     10.027529      9.720665
# 2   TTHERM_00000010      5.066343      4.767264      5.010981      6.139047
# 3   TTHERM_00000020      4.696881      4.638401      4.956299      6.942556
# 4   TTHERM_00000030      4.654278      4.537105      4.928739      5.063991
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      6.970612      7.150978      6.126826      6.868968      6.641119  ...
# 1      9.605762     10.225542     10.279608     10.459966     10.693337  ...
# 2      4.619361      4.751761      5.818550      5.342529      5.483750  ...
# 3      5.101252      4.730307      8.457690      4.526411      4.908300  ...
# 4      4.584168      4.911880      5.935311      4.519470      4.757861  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       6.450318       8.049750       7.788162       7.052154       6.517742
# 1      11.130466      11.207738      11.009172      10.615417      11.038938
# 2       6.314438       7.423571       7.507645       7.417087       7.147801
# 3       5.250233       4.974993       5.747498       5.252167       5.210531
# 4       4.651688       4.920573       4.636333       4.883712       4.779395
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       6.918501       6.048861       7.041619       6.757932       5.817246
# 1      11.009222      10.216348      11.099187      11.172276      10.561021
# 2       7.747930       7.093641       7.672685       7.511290       6.890117
# 3       7.083187       5.252222       5.037613       5.495281       5.013987
# 4       4.744335       4.513140       4.838428       4.961475       4.653340
#
# [5 rows x 48 columns]

# %%
gene_data = normalize_expression_per_gene(gene_data)

# %%
gene_data.head()
# Out:
#           TTHERM_ID  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  Lm_GSM283690  \
# 0  TTHERM_000000042      0.604560      0.712935      0.606315      0.541298
# 1  TTHERM_000000045      0.015138      0.202748      0.230267      0.062732
# 2   TTHERM_00000010      0.071967      0.023813      0.063054      0.244680
# 3   TTHERM_00000020      0.049259      0.036473      0.105976      0.540233
# 4   TTHERM_00000030      0.027748      0.004712      0.081708      0.108299
#
#    Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  Lh_GSM284364  ...  \
# 0      0.618075      0.676352      0.345444      0.585234      0.511614  ...
# 1      0.000000      0.338374      0.367892      0.466359      0.593770  ...
# 2      0.000000      0.021317      0.193078      0.116435      0.139173  ...
# 3      0.137667      0.056567      0.871488      0.011989      0.095481  ...
# 4      0.013964      0.078393      0.279603      0.001245      0.048113  ...
#
#    C12_GSM656237  C14_GSM285580  C14_GSM285593  C14_GSM656238  C16_GSM285582  \
# 0       0.449966       0.966750       0.882229       0.644422       0.471751
# 1       0.832424       0.874612       0.766203       0.551230       0.782454
# 2       0.272919       0.451498       0.465034       0.450454       0.407097
# 3       0.170239       0.110063       0.278956       0.170661       0.161559
# 4       0.027239       0.080103       0.024220       0.072855       0.052347
#
#    C16_GSM285595  C16_GSM656239  C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0       0.601238       0.320253       0.641018       0.549357       0.245417
# 1       0.766230       0.333354       0.815348       0.855251       0.521531
# 2       0.503722       0.398377       0.491607       0.465621       0.365608
# 3       0.570979       0.170673       0.123753       0.223814       0.118588
# 4       0.045454       0.000000       0.063952       0.088144       0.027564
#
# [5 rows x 48 columns]

# %%
gene_data
# Out:
#               TTHERM_ID  Ll_GSM283687  Ll_GSM284355  Ll_GSM284362  \
# 0      TTHERM_000000042      0.604560      0.712935      0.606315
# 1      TTHERM_000000045      0.015138      0.202748      0.230267
# 2       TTHERM_00000010      0.071967      0.023813      0.063054
# 3       TTHERM_00000020      0.049259      0.036473      0.105976
# 4       TTHERM_00000030      0.027748      0.004712      0.081708
# ...                 ...           ...           ...           ...
# 20321   TTHERM_02293890      0.178656      0.109809      0.048422
# 20322   TTHERM_02385080      0.793598      0.342475      0.834350
# 20323   TTHERM_02555200      0.461078      0.000000      0.520474
# 20324   TTHERM_02607240      0.646061      0.498276      0.055730
# 20325   TTHERM_02653470      0.362125      0.409122      0.346317
#
#        Lm_GSM283690  Lm_GSM284357  Lm_GSM284363  Lh_GSM283691  Lh_GSM284360  \
# 0          0.541298      0.618075      0.676352      0.345444      0.585234
# 1          0.062732      0.000000      0.338374      0.367892      0.466359
# 2          0.244680      0.000000      0.021317      0.193078      0.116435
# 3          0.540233      0.137667      0.056567      0.871488      0.011989
# 4          0.108299      0.013964      0.078393      0.279603      0.001245
# ...             ...           ...           ...           ...           ...
# 20321      0.071034      0.385238      0.000000      0.716332      0.255116
# 20322      0.593193      0.610267      0.721421      0.821797      0.379938
# 20323      0.188476      0.200151      0.459836      0.627646      0.520845
# 20324      0.281406      0.521778      0.212822      0.924278      0.235940
# 20325      0.446020      0.535675      0.406166      0.853065      0.929290
#
#        Lh_GSM284364  ...  C12_GSM656237  C14_GSM285580  C14_GSM285593  \
# 0          0.511614  ...       0.449966       0.966750       0.882229
# 1          0.593770  ...       0.832424       0.874612       0.766203
# 2          0.139173  ...       0.272919       0.451498       0.465034
# 3          0.095481  ...       0.170239       0.110063       0.278956
# 4          0.048113  ...       0.027239       0.080103       0.024220
# ...             ...  ...            ...            ...            ...
# 20321      0.208480  ...       0.602522       0.669650       0.629458
# 20322      0.763581  ...       0.000000       0.894450       0.807465
# 20323      0.418029  ...       0.317590       0.424080       0.749697
# 20324      0.000000  ...       0.439230       0.824600       0.847735
# 20325      0.717500  ...       0.449989       0.985894       0.878433
#
#        C14_GSM656238  C16_GSM285582  C16_GSM285595  C16_GSM656239  \
# 0           0.644422       0.471751       0.601238       0.320253
# 1           0.551230       0.782454       0.766230       0.333354
# 2           0.450454       0.407097       0.503722       0.398377
# 3           0.170661       0.161559       0.570979       0.170673
# 4           0.072855       0.052347       0.045454       0.000000
# ...              ...            ...            ...            ...
# 20321       0.522463       0.618023       0.542049       0.589131
# 20322       0.259562       0.786715       0.928782       0.510341
# 20323       0.418365       0.818543       0.940057       0.642974
# 20324       0.743985       0.704899       0.777690       0.923941
# 20325       0.533408       1.000000       0.980593       0.599541
#
#        C18_GSM285583  C18_GSM285596  C18_GSM656240
# 0           0.641018       0.549357       0.245417
# 1           0.815348       0.855251       0.521531
# 2           0.491607       0.465621       0.365608
# 3           0.123753       0.223814       0.118588
# 4           0.063952       0.088144       0.027564
# ...              ...            ...            ...
# 20321       0.517068       0.699527       0.850138
# 20322       0.977735       0.868325       0.618105
# 20323       0.723721       1.000000       0.831430
# 20324       0.474318       0.394939       1.000000
# 20325       0.835638       0.913960       0.630991
#
# [20326 rows x 48 columns]

# %%
# Extract labels column
labels = gene_data['TTHERM_ID']  # Replace 'labels' with the actual column name

# Drop labels column before PCA
gene_data = gene_data.drop('TTHERM_ID', axis=1)

manhattan_distance_matrix = pairwise_distances(gene_data, metric='manhattan', n_jobs=-1)

# %%
dict_opt = {'nns': -1, 'components': -1, 'nclusters': -1, 'sscore': -1}

# %%
nums_nns = np.arange(5,100,10)

# nums_components = np.arange(2,20,1)
nums_components = np.arange(9,31,3)

nums_clusters = np.arange(50,300,25)

for num_nns in nums_nns:

    for num_components in nums_components:

        umap_result = umap.UMAP(
            # random_state=42, 
            n_components=num_components, 
            n_neighbors=num_nns, 
            metric='manhattan', 
            n_jobs=-1
            ).fit_transform(gene_data)

        umap_df = pd.DataFrame(data=umap_result, columns=[f'UMAP{num}' for num in range(1, num_components + 1)])

        for num_clusters in nums_clusters:

            initial_centers = kmeans_plusplus_initializer(np.array(umap_df), num_clusters).initialize()
            # create metric that will be used for clustering
            manhattan_metric = distance_metric(type_metric.MANHATTAN)
            # create instance of K-Means using specific distance metric:
            kmeans_instance = kmeans(np.array(umap_df), initial_centers, metric=manhattan_metric)
            # run cluster analysis and obtain results
            kmeans_instance.process()
            clusters = kmeans_instance.get_clusters()

            cluster_assignments = np.zeros(umap_df.shape[0])

            for idx, cluster in enumerate(clusters):
                for gene_idx in cluster:
                    cluster_assignments[gene_idx] = idx

            # Compute silhouette score
            silhouette_avg = silhouette_score(manhattan_distance_matrix, cluster_assignments, metric='precomputed')
            print(f"Silhouette Score for {num_nns} nearest neighbors, {num_components} UMAP components, and {num_clusters} clusters: {silhouette_avg}")

            if dict_opt['sscore'] < silhouette_avg:
                dict_opt['sscore'] = silhouette_avg
                dict_opt['nclusters'] = num_clusters
                dict_opt['components'] = num_components
                dict_opt['nns'] = num_nns
# Out:
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 50 clusters: 0.03946595018369172
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 75 clusters: 0.03245616276602175
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 100 clusters: 0.027705456030051832
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 125 clusters: 0.028961702936982598
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 150 clusters: 0.025508162683709135
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 175 clusters: 0.02133422430424809
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 200 clusters: 0.01931880326569481
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 225 clusters: 0.01838016243422178
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 250 clusters: 0.01775790690254623
# Silhouette Score for 5 nearest neighbors, 9 UMAP components, and 275 clusters: 0.016194166491405707
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 50 clusters: 0.03763555873738207
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 75 clusters: 0.031139803790775158
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 100 clusters: 0.029737099696558023
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 125 clusters: 0.027668710860293336
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 150 clusters: 0.026297666900869283
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 175 clusters: 0.02041909873500213
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 200 clusters: 0.020228221964942106
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 225 clusters: 0.018149316998353114
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 250 clusters: 0.017555248931835424
# Silhouette Score for 5 nearest neighbors, 12 UMAP components, and 275 clusters: 0.016809193595833175
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 50 clusters: 0.04171860274441345
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 75 clusters: 0.0315099739908623
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 100 clusters: 0.02690884381529486
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 125 clusters: 0.02502955929493277
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 150 clusters: 0.023354925613204593
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 175 clusters: 0.02304474805985795
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 200 clusters: 0.020153242195695108
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 225 clusters: 0.018211676969550013
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 250 clusters: 0.01996776039764822
# Silhouette Score for 5 nearest neighbors, 15 UMAP components, and 275 clusters: 0.015724463208227256
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 50 clusters: 0.03839588384675348
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 75 clusters: 0.030962948302143505
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 100 clusters: 0.028484818853792476
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 125 clusters: 0.024821367139342573
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 150 clusters: 0.023032849938119417
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 175 clusters: 0.02446867835273503
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 200 clusters: 0.01999487902527149
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 225 clusters: 0.019852698697431836
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 250 clusters: 0.01909373505405991
# Silhouette Score for 5 nearest neighbors, 18 UMAP components, and 275 clusters: 0.0188806575676156
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 50 clusters: 0.041117254604374064
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 75 clusters: 0.03106131302782126
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 100 clusters: 0.026558399144375678
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 125 clusters: 0.025327887762675576
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 150 clusters: 0.02393727714598802
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 175 clusters: 0.021301043508490453
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 200 clusters: 0.017438027774438387
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 225 clusters: 0.018600603531132638
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 250 clusters: 0.016487142371569723
# Silhouette Score for 5 nearest neighbors, 21 UMAP components, and 275 clusters: 0.015110996899573062
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 50 clusters: 0.03994012166954348
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 75 clusters: 0.02993577240678377
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 100 clusters: 0.026100758920275195
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 125 clusters: 0.024958171312896522
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 150 clusters: 0.024335791325523954
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 175 clusters: 0.021262334574189808
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 200 clusters: 0.018115657924103315
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 225 clusters: 0.018330850728730985
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 250 clusters: 0.014559427657810495
# Silhouette Score for 5 nearest neighbors, 24 UMAP components, and 275 clusters: 0.017374610915340424
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 50 clusters: 0.03259456210540911
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 75 clusters: 0.03110436941401649
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 100 clusters: 0.02711396609930305
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 125 clusters: 0.02619473288897019
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 150 clusters: 0.021794938077211896
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 175 clusters: 0.020859371374615233
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 200 clusters: 0.01996192439143263
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 225 clusters: 0.017840895062470927
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 250 clusters: 0.017295275314721133
# Silhouette Score for 5 nearest neighbors, 27 UMAP components, and 275 clusters: 0.012960586260457293
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 50 clusters: 0.03221034207732317
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 75 clusters: 0.031118803226420896
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 100 clusters: 0.028555176903075682
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 125 clusters: 0.027619321581488786
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 150 clusters: 0.02615041311790957
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 175 clusters: 0.024193598237075398
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 200 clusters: 0.020557839736398277
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 225 clusters: 0.020202445965046157
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 250 clusters: 0.019124676542536672
# Silhouette Score for 5 nearest neighbors, 30 UMAP components, and 275 clusters: 0.017867017258931764
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 50 clusters: 0.05258209447169373
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 75 clusters: 0.043447269137275236
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 100 clusters: 0.03806429669695607
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 125 clusters: 0.034115999232390254
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03080786067318604
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 175 clusters: 0.03170789786454683
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 200 clusters: 0.029302756754108768
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 225 clusters: 0.026604515519099096
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 250 clusters: 0.02390297084605703
# Silhouette Score for 15 nearest neighbors, 9 UMAP components, and 275 clusters: 0.023527980872831953
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 50 clusters: 0.05099689053957363
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 75 clusters: 0.0409813538374693
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 100 clusters: 0.040249814456865006
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03350696122568978
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 150 clusters: 0.033216273209568395
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 175 clusters: 0.031903470590300076
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 200 clusters: 0.02838128420663333
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 225 clusters: 0.029356270614780813
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 250 clusters: 0.026332269127654916
# Silhouette Score for 15 nearest neighbors, 12 UMAP components, and 275 clusters: 0.025321921539746144
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 50 clusters: 0.051785267558598254
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 75 clusters: 0.04117927689634436
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 100 clusters: 0.03775545038294717
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 125 clusters: 0.035467537301839915
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 150 clusters: 0.03177600006314256
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 175 clusters: 0.029245682362078963
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 200 clusters: 0.028542502293570242
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 225 clusters: 0.027159220992333574
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 250 clusters: 0.02677958191879801
# Silhouette Score for 15 nearest neighbors, 15 UMAP components, and 275 clusters: 0.02517336832275569
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 50 clusters: 0.05202339506241829
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 75 clusters: 0.04264588664156146
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 100 clusters: 0.03664996558515122
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 125 clusters: 0.035790250728986985
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 150 clusters: 0.03215481610686029
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 175 clusters: 0.02796561263322809
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 200 clusters: 0.029275009699192733
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 225 clusters: 0.026115318241674016
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 250 clusters: 0.02474914970641862
# Silhouette Score for 15 nearest neighbors, 18 UMAP components, and 275 clusters: 0.023816966799162235
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 50 clusters: 0.05103376402233476
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04463123580651321
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 100 clusters: 0.03982616683947779
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 125 clusters: 0.03533329445743164
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 150 clusters: 0.03275175592087507
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 175 clusters: 0.02920947508185349
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 200 clusters: 0.02753357565532888
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 225 clusters: 0.027992471660891187
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 250 clusters: 0.026306304287705723
# Silhouette Score for 15 nearest neighbors, 21 UMAP components, and 275 clusters: 0.024397581248976327
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 50 clusters: 0.05357586389551711
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 75 clusters: 0.043734924669159
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 100 clusters: 0.038427911735838344
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 125 clusters: 0.03425617438795532
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 150 clusters: 0.03343304536516057
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 175 clusters: 0.030580145511440858
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 200 clusters: 0.029494508622915583
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 225 clusters: 0.027235729857047915
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 250 clusters: 0.024909841170444903
# Silhouette Score for 15 nearest neighbors, 24 UMAP components, and 275 clusters: 0.022305740174714626
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 50 clusters: 0.05236889582557977
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 75 clusters: 0.0387768683302013
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 100 clusters: 0.03701762054451319
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 125 clusters: 0.0334478605539144
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 150 clusters: 0.033078891317272104
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 175 clusters: 0.032055791376662035
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 200 clusters: 0.02874168815179219
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 225 clusters: 0.027709249804302227
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 250 clusters: 0.025972994187334907
# Silhouette Score for 15 nearest neighbors, 27 UMAP components, and 275 clusters: 0.025271120340288073
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 50 clusters: 0.052481960800860046
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 75 clusters: 0.041627696348923944
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 100 clusters: 0.04178762544620489
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 125 clusters: 0.03486878484659589
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 150 clusters: 0.03175025064092999
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 175 clusters: 0.031759900374502964
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 200 clusters: 0.030046458179778406
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 225 clusters: 0.02530858816421897
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 250 clusters: 0.025049894174191487
# Silhouette Score for 15 nearest neighbors, 30 UMAP components, and 275 clusters: 0.023696636359055927
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 50 clusters: 0.05231200748245669
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 75 clusters: 0.04352423761650787
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 100 clusters: 0.04240973339248608
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 125 clusters: 0.03622383869179924
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03370741659264852
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 175 clusters: 0.03048201037477394
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 200 clusters: 0.027641260179217697
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 225 clusters: 0.028181660189873586
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 250 clusters: 0.024354260396373072
# Silhouette Score for 25 nearest neighbors, 9 UMAP components, and 275 clusters: 0.024285732189320182
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 50 clusters: 0.053930539953489356
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04568025806998259
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 100 clusters: 0.04104150881167528
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03603988310520743
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 150 clusters: 0.03467125710597802
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 175 clusters: 0.031208798810066062
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 200 clusters: 0.029432220060574135
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 225 clusters: 0.02723204157114884
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 250 clusters: 0.025938304352927273
# Silhouette Score for 25 nearest neighbors, 12 UMAP components, and 275 clusters: 0.023225628133851945
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 50 clusters: 0.05501884326622996
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 75 clusters: 0.04633223291612796
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 100 clusters: 0.03918548171104647
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 125 clusters: 0.035433866261780106
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 150 clusters: 0.03405320100565709
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 175 clusters: 0.03063042979981482
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 200 clusters: 0.02953862724359719
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 225 clusters: 0.02847305665572445
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 250 clusters: 0.02479636008179923
# Silhouette Score for 25 nearest neighbors, 15 UMAP components, and 275 clusters: 0.02431094140292359
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 50 clusters: 0.05262902121232579
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 75 clusters: 0.0463100596385422
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 100 clusters: 0.041147557274866825
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 125 clusters: 0.03587925496934108
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 150 clusters: 0.034124134402692276
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 175 clusters: 0.03218235394221341
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 200 clusters: 0.029083818398182953
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 225 clusters: 0.027809416592767047
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 250 clusters: 0.02659323173921178
# Silhouette Score for 25 nearest neighbors, 18 UMAP components, and 275 clusters: 0.026446021101225067
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 50 clusters: 0.05468275872230176
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04799827862936613
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 100 clusters: 0.04042683539001283
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 125 clusters: 0.0356374142702502
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 150 clusters: 0.03574555095106098
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 175 clusters: 0.03428933409426582
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 200 clusters: 0.02947424353232093
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 225 clusters: 0.02831805884813967
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 250 clusters: 0.026011013929719513
# Silhouette Score for 25 nearest neighbors, 21 UMAP components, and 275 clusters: 0.02310055303084052
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 50 clusters: 0.0539304235662527
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 75 clusters: 0.04002620697708248
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 100 clusters: 0.0425612259228957
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 125 clusters: 0.03418195525498329
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 150 clusters: 0.037237321661805996
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 175 clusters: 0.03249086885465232
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 200 clusters: 0.02898919266140801
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 225 clusters: 0.027750246322659718
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 250 clusters: 0.026393293418263113
# Silhouette Score for 25 nearest neighbors, 24 UMAP components, and 275 clusters: 0.023851753619794944
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 50 clusters: 0.05574295491824136
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 75 clusters: 0.044800769176722606
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 100 clusters: 0.038475724186923056
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 125 clusters: 0.03637039252035333
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 150 clusters: 0.03423044550886306
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 175 clusters: 0.030140878511766733
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 200 clusters: 0.030384406665797278
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 225 clusters: 0.028719125966730073
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 250 clusters: 0.027713603031395348
# Silhouette Score for 25 nearest neighbors, 27 UMAP components, and 275 clusters: 0.02597356272641966
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 50 clusters: 0.05256199721160549
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 75 clusters: 0.043630541334705425
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 100 clusters: 0.0413146825149392
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 125 clusters: 0.03696756649500663
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 150 clusters: 0.0340600531305664
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 175 clusters: 0.03049078179646553
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 200 clusters: 0.03048536328681039
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 225 clusters: 0.029849071795256157
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 250 clusters: 0.026035166017870544
# Silhouette Score for 25 nearest neighbors, 30 UMAP components, and 275 clusters: 0.022355759813987748
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 50 clusters: 0.055624153324805886
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 75 clusters: 0.04519573537155577
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 100 clusters: 0.03898703783777111
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 125 clusters: 0.03770260302543084
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03402829753338226
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 175 clusters: 0.03187289501040909
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 200 clusters: 0.028158647906786596
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 225 clusters: 0.027786913810814714
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 250 clusters: 0.023751064475251712
# Silhouette Score for 35 nearest neighbors, 9 UMAP components, and 275 clusters: 0.02278244125450321
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 50 clusters: 0.05063863220781609
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04457348971757918
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 100 clusters: 0.04474003740915168
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03647169420815366
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 150 clusters: 0.035521757723994934
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 175 clusters: 0.031239704948997582
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 200 clusters: 0.03051741085199712
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 225 clusters: 0.026786262748284953
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 250 clusters: 0.02529375470965465
# Silhouette Score for 35 nearest neighbors, 12 UMAP components, and 275 clusters: 0.02444884003714348
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 50 clusters: 0.05304662218421582
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 75 clusters: 0.046809465640314754
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 100 clusters: 0.040709097870675566
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 125 clusters: 0.036568743015931944
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 150 clusters: 0.034088051675058614
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 175 clusters: 0.03124265804629694
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 200 clusters: 0.030522598481755526
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 225 clusters: 0.02806951027922293
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 250 clusters: 0.025171343957442697
# Silhouette Score for 35 nearest neighbors, 15 UMAP components, and 275 clusters: 0.024158341872322547
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 50 clusters: 0.055541608891795206
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 75 clusters: 0.04101366478321659
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 100 clusters: 0.04256885802280604
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 125 clusters: 0.039070539100329184
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 150 clusters: 0.03524124406068885
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 175 clusters: 0.03344181282972427
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 200 clusters: 0.030337539427234245
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 225 clusters: 0.027904999147018075
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 250 clusters: 0.027784826394135716
# Silhouette Score for 35 nearest neighbors, 18 UMAP components, and 275 clusters: 0.025707326915438995
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 50 clusters: 0.052498003570869194
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04476759650099707
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 100 clusters: 0.042699242411574315
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 125 clusters: 0.03721459356177773
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 150 clusters: 0.03116204730151986
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 175 clusters: 0.03087113329945406
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 200 clusters: 0.029173404307779458
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 225 clusters: 0.027481008699401233
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 250 clusters: 0.02588831814343287
# Silhouette Score for 35 nearest neighbors, 21 UMAP components, and 275 clusters: 0.023767634862129322
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 50 clusters: 0.05384814513231009
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 75 clusters: 0.044891119319367276
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 100 clusters: 0.04383982965400549
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 125 clusters: 0.03840059063873438
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 150 clusters: 0.033492969208423824
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 175 clusters: 0.031485200348369984
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 200 clusters: 0.030271057654068963
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 225 clusters: 0.027308131245474595
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 250 clusters: 0.026873439590596192
# Silhouette Score for 35 nearest neighbors, 24 UMAP components, and 275 clusters: 0.024025913164924837
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 50 clusters: 0.05589907968079486
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 75 clusters: 0.04476862335393902
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 100 clusters: 0.03914663234238465
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 125 clusters: 0.0374537081197594
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 150 clusters: 0.03183909366212842
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 175 clusters: 0.029309778671384384
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 200 clusters: 0.0280799402383523
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 225 clusters: 0.030292744146213454
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 250 clusters: 0.026640555052324696
# Silhouette Score for 35 nearest neighbors, 27 UMAP components, and 275 clusters: 0.023367071798808366
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 50 clusters: 0.0544788295308355
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 75 clusters: 0.04561031978776046
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 100 clusters: 0.04270432686252095
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 125 clusters: 0.038163784123500355
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 150 clusters: 0.03380541267840317
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 175 clusters: 0.029769759934535664
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 200 clusters: 0.02978889503178893
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 225 clusters: 0.027863189015028184
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 250 clusters: 0.02573013960122212
# Silhouette Score for 35 nearest neighbors, 30 UMAP components, and 275 clusters: 0.025799013644520856
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 50 clusters: 0.0540796782780887
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 75 clusters: 0.044692238052894656
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 100 clusters: 0.04150925676732365
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 125 clusters: 0.036187162859905815
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03212929635632597
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 175 clusters: 0.03131007249588756
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 200 clusters: 0.03092475688529628
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 225 clusters: 0.027481993347367884
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 250 clusters: 0.02501080724683268
# Silhouette Score for 45 nearest neighbors, 9 UMAP components, and 275 clusters: 0.025752201901095163
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 50 clusters: 0.05459672040014304
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04669979721516098
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 100 clusters: 0.042024104493160866
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03591959891152886
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 150 clusters: 0.034890051410670864
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 175 clusters: 0.03026143001177631
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 200 clusters: 0.028340534626835473
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 225 clusters: 0.02657291023585445
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 250 clusters: 0.025992116606843533
# Silhouette Score for 45 nearest neighbors, 12 UMAP components, and 275 clusters: 0.023596249063071804
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 50 clusters: 0.05359789269203693
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 75 clusters: 0.04763837265531484
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 100 clusters: 0.04208034612418368
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 125 clusters: 0.037586254172973586
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 150 clusters: 0.0346284257571304
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 175 clusters: 0.033004155488990564
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 200 clusters: 0.028753256844958424
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 225 clusters: 0.027050039552883827
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 250 clusters: 0.025602726215408635
# Silhouette Score for 45 nearest neighbors, 15 UMAP components, and 275 clusters: 0.02427629366772571
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 50 clusters: 0.05365320341863826
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 75 clusters: 0.04521786646760386
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 100 clusters: 0.038435952073336006
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 125 clusters: 0.037456220558839425
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 150 clusters: 0.03363136743073742
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 175 clusters: 0.030407308128070895
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 200 clusters: 0.030012689332771406
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 225 clusters: 0.027466276068774612
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 250 clusters: 0.026380559137941673
# Silhouette Score for 45 nearest neighbors, 18 UMAP components, and 275 clusters: 0.02495274740772137
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 50 clusters: 0.055427920130700435
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04247615214907655
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 100 clusters: 0.04085601507688831
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 125 clusters: 0.037014643549245656
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 150 clusters: 0.03240450558279884
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 175 clusters: 0.03125785622821607
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 200 clusters: 0.030363984388280803
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 225 clusters: 0.028600611180425638
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 250 clusters: 0.027347478118200538
# Silhouette Score for 45 nearest neighbors, 21 UMAP components, and 275 clusters: 0.02364009551430134
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 50 clusters: 0.05481491771476536
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 75 clusters: 0.042682679955625115
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 100 clusters: 0.0412629367461964
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 125 clusters: 0.038411467646819866
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 150 clusters: 0.0329329443668695
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 175 clusters: 0.030348705232147305
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 200 clusters: 0.02965056044385277
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 225 clusters: 0.02810495843596777
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 250 clusters: 0.025550954397640487
# Silhouette Score for 45 nearest neighbors, 24 UMAP components, and 275 clusters: 0.024002662192905446
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 50 clusters: 0.05365860205784631
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 75 clusters: 0.04619678237594858
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 100 clusters: 0.04118443944167987
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 125 clusters: 0.037084718119105554
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 150 clusters: 0.034443811764886784
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 175 clusters: 0.030811381361634964
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 200 clusters: 0.03046635105974313
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 225 clusters: 0.027240505396223164
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 250 clusters: 0.024367380326106188
# Silhouette Score for 45 nearest neighbors, 27 UMAP components, and 275 clusters: 0.02600648334718195
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 50 clusters: 0.05385542423142922
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 75 clusters: 0.04472901746597572
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 100 clusters: 0.04124902994287787
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 125 clusters: 0.03819513029156008
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 150 clusters: 0.03500408859102959
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 175 clusters: 0.030267609016249156
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 200 clusters: 0.029680827274243305
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 225 clusters: 0.026881688912796187
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 250 clusters: 0.025476796476883244
# Silhouette Score for 45 nearest neighbors, 30 UMAP components, and 275 clusters: 0.024144925394636113
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 50 clusters: 0.05541062889157094
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 75 clusters: 0.047261944815251575
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 100 clusters: 0.04186334007148304
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 125 clusters: 0.036993589056566197
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03241195550549689
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 175 clusters: 0.03271197194278341
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 200 clusters: 0.028485266415391758
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 225 clusters: 0.025116483062137724
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 250 clusters: 0.024351896551627675
# Silhouette Score for 55 nearest neighbors, 9 UMAP components, and 275 clusters: 0.023938183053062792
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 50 clusters: 0.0521946137276059
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04476767391777983
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 100 clusters: 0.04025228875990208
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03704710414432472
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 150 clusters: 0.03532872720360486
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 175 clusters: 0.030507509444079286
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 200 clusters: 0.027694828400225448
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 225 clusters: 0.026324322658881235
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 250 clusters: 0.02448295733615136
# Silhouette Score for 55 nearest neighbors, 12 UMAP components, and 275 clusters: 0.0222115685543744
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 50 clusters: 0.054348511142907646
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 75 clusters: 0.04484750330311255
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 100 clusters: 0.04340458482530863
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 125 clusters: 0.03649398148592308
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 150 clusters: 0.03424368313492505
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 175 clusters: 0.03175398061919786
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 200 clusters: 0.029793947845950002
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 225 clusters: 0.026361644451786282
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 250 clusters: 0.025573479050947145
# Silhouette Score for 55 nearest neighbors, 15 UMAP components, and 275 clusters: 0.023664830328240502
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 50 clusters: 0.054013327862333135
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 75 clusters: 0.04363503371062971
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 100 clusters: 0.038764221991266376
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 125 clusters: 0.03728905043193659
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 150 clusters: 0.033780765203736914
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 175 clusters: 0.031141083130510748
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 200 clusters: 0.02901523292276501
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 225 clusters: 0.02603254641640467
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 250 clusters: 0.02535651831561859
# Silhouette Score for 55 nearest neighbors, 18 UMAP components, and 275 clusters: 0.02136935001855849
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 50 clusters: 0.054155025428436795
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04525083610860299
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 100 clusters: 0.040247225882903644
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 125 clusters: 0.039240242799439495
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 150 clusters: 0.034507972938012846
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 175 clusters: 0.028267789314518538
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 200 clusters: 0.026772466927818372
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 225 clusters: 0.025601400149087298
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 250 clusters: 0.02619189860529005
# Silhouette Score for 55 nearest neighbors, 21 UMAP components, and 275 clusters: 0.022731220391507864
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 50 clusters: 0.05409507765830342
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 75 clusters: 0.04505981826095961
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 100 clusters: 0.042914794197846266
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 125 clusters: 0.035545612041367074
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 150 clusters: 0.03608964507205778
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 175 clusters: 0.030479994409382906
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 200 clusters: 0.028731298531035787
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 225 clusters: 0.02502793053286232
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 250 clusters: 0.026600386026464327
# Silhouette Score for 55 nearest neighbors, 24 UMAP components, and 275 clusters: 0.025138622058640907
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 50 clusters: 0.053176232590580144
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 75 clusters: 0.04234774491093833
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 100 clusters: 0.04067420803898615
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 125 clusters: 0.037328065264529496
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 150 clusters: 0.03268588431826678
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 175 clusters: 0.02866373947952734
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 200 clusters: 0.02758579729235934
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 225 clusters: 0.025681079661984185
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 250 clusters: 0.024281227847700038
# Silhouette Score for 55 nearest neighbors, 27 UMAP components, and 275 clusters: 0.020375544520897668
# Silhouette Score for 55 nearest neighbors, 30 UMAP components, and 50 clusters: 0.05250153326158155
# Silhouette Score for 55 nearest neighbors, 30 UMAP components, and 75 clusters: 0.04645357580605181
# Silhouette Score for 55 nearest neighbors, 30 UMAP components, and 100 clusters: 0.040237147042313515
# Silhouette Score for 55 nearest neighbors, 30 UMAP components, and 125 clusters: 0.037655352566053756
# Silhouette Score for 55 nearest neighbors, 30 UMAP components, and 150 clusters: 0.034518803635842366
# ...
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 100 clusters: 0.038674195147574
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 125 clusters: 0.03540903245112454
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03014228729947995
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 175 clusters: 0.028003100217542657
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 200 clusters: 0.02490447461664682
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 225 clusters: 0.023391952095587323
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 250 clusters: 0.023554649075227467
# Silhouette Score for 85 nearest neighbors, 9 UMAP components, and 275 clusters: 0.020167281319702583
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 50 clusters: 0.05529125279504559
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04231337698789884
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 100 clusters: 0.03851154457576528
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03551634123209718
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 150 clusters: 0.0297660836846076
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 175 clusters: 0.02720361694117592
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 200 clusters: 0.027022590662950863
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 225 clusters: 0.022916682312938853
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 250 clusters: 0.02272952489254831
# Silhouette Score for 85 nearest neighbors, 12 UMAP components, and 275 clusters: 0.02043987675463316
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 50 clusters: 0.05390247215983824
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 75 clusters: 0.0462465458111759
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 100 clusters: 0.039929130217589225
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 125 clusters: 0.03415627721107503
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 150 clusters: 0.03295160783865423
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 175 clusters: 0.02803592068366998
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 200 clusters: 0.025797585004170086
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 225 clusters: 0.024251004065202936
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 250 clusters: 0.023777330587898843
# Silhouette Score for 85 nearest neighbors, 15 UMAP components, and 275 clusters: 0.019242283383139675
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 50 clusters: 0.05781382669899379
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 75 clusters: 0.04444670995775026
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 100 clusters: 0.039265101530317224
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 125 clusters: 0.03548974723483066
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 150 clusters: 0.032817406976031
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 175 clusters: 0.027356669044575538
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 200 clusters: 0.028759738248894558
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 225 clusters: 0.02558832804411643
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 250 clusters: 0.021729971464855675
# Silhouette Score for 85 nearest neighbors, 18 UMAP components, and 275 clusters: 0.021481001189991855
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 50 clusters: 0.05298280999163936
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04323141936554115
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 100 clusters: 0.0391559793925752
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 125 clusters: 0.03427777626092077
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 150 clusters: 0.03088687785333103
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 175 clusters: 0.029801094572014956
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 200 clusters: 0.02664658660274614
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 225 clusters: 0.023949267245722355
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 250 clusters: 0.02249942365703159
# Silhouette Score for 85 nearest neighbors, 21 UMAP components, and 275 clusters: 0.01970276515152653
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 50 clusters: 0.04790017113555827
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 75 clusters: 0.04262789646909194
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 100 clusters: 0.03901492893106002
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 125 clusters: 0.032684522507743334
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 150 clusters: 0.02933745020685965
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 175 clusters: 0.02919467241502267
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 200 clusters: 0.025265212312548652
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 225 clusters: 0.023353168404813458
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 250 clusters: 0.020512454727209823
# Silhouette Score for 85 nearest neighbors, 24 UMAP components, and 275 clusters: 0.020254788609953122
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 50 clusters: 0.05574675636173231
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 75 clusters: 0.042943197972625476
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 100 clusters: 0.03984349537716984
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 125 clusters: 0.036879503801723876
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 150 clusters: 0.032061490550191286
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 175 clusters: 0.029593191945132602
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 200 clusters: 0.02637624747588504
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 225 clusters: 0.022809156902099594
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 250 clusters: 0.02100513447060473
# Silhouette Score for 85 nearest neighbors, 27 UMAP components, and 275 clusters: 0.021003912243648126
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 50 clusters: 0.05245496427880685
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 75 clusters: 0.046177573270956646
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 100 clusters: 0.040079074539869496
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 125 clusters: 0.03643365144816729
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 150 clusters: 0.031700554060496766
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 175 clusters: 0.028518966028892867
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 200 clusters: 0.02582872382601117
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 225 clusters: 0.02177339687268116
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 250 clusters: 0.020591607748971556
# Silhouette Score for 85 nearest neighbors, 30 UMAP components, and 275 clusters: 0.02224524567347098
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 50 clusters: 0.051948072843036014
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 75 clusters: 0.044446170136606594
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 100 clusters: 0.03990116326176118
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 125 clusters: 0.035222907311707304
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 150 clusters: 0.03188021846938712
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 175 clusters: 0.02807462175335942
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 200 clusters: 0.026126502208355037
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 225 clusters: 0.02516398822146488
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 250 clusters: 0.02124464050053073
# Silhouette Score for 95 nearest neighbors, 9 UMAP components, and 275 clusters: 0.01968084196887753
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 50 clusters: 0.05388916586963322
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 75 clusters: 0.04200146237297381
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 100 clusters: 0.041142928401263386
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 125 clusters: 0.03468812637351199
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 150 clusters: 0.033632269296027965
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 175 clusters: 0.0258582742780045
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 200 clusters: 0.02668471311597809
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 225 clusters: 0.02299423270496153
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 250 clusters: 0.02161684094966563
# Silhouette Score for 95 nearest neighbors, 12 UMAP components, and 275 clusters: 0.018692917761923382
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 50 clusters: 0.054647921814442335
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 75 clusters: 0.0429591326399187
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 100 clusters: 0.04020741065128072
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 125 clusters: 0.03349526777789221
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 150 clusters: 0.029357946604518428
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 175 clusters: 0.029379423251117438
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 200 clusters: 0.027145112750426675
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 225 clusters: 0.02376615391647273
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 250 clusters: 0.0232943547754945
# Silhouette Score for 95 nearest neighbors, 15 UMAP components, and 275 clusters: 0.021255738784354255
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 50 clusters: 0.054349951926987945
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 75 clusters: 0.047236363944447225
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 100 clusters: 0.039088318405523015
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 125 clusters: 0.03444158211289574
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 150 clusters: 0.032424203562057774
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 175 clusters: 0.029139387082629118
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 200 clusters: 0.02595886428711274
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 225 clusters: 0.02286694863012153
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 250 clusters: 0.023278897109450074
# Silhouette Score for 95 nearest neighbors, 18 UMAP components, and 275 clusters: 0.021813678577743092
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 50 clusters: 0.055028848241317235
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 75 clusters: 0.04561314911245531
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 100 clusters: 0.03923907313915038
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 125 clusters: 0.03302854951344765
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 150 clusters: 0.033218336527608784
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 175 clusters: 0.02866647658894106
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 200 clusters: 0.024719330338807074
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 225 clusters: 0.024258171372307232
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 250 clusters: 0.021287348215433394
# Silhouette Score for 95 nearest neighbors, 21 UMAP components, and 275 clusters: 0.02003674915832063
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 50 clusters: 0.04930949491424778
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 75 clusters: 0.04371877547244243
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 100 clusters: 0.04160945565647429
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 125 clusters: 0.03456146013408103
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 150 clusters: 0.031524185286078
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 175 clusters: 0.02786772377260675
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 200 clusters: 0.027284986622883936
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 225 clusters: 0.024250438028124256
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 250 clusters: 0.024824443402270614
# Silhouette Score for 95 nearest neighbors, 24 UMAP components, and 275 clusters: 0.01970396330619934
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 50 clusters: 0.050731214121578445
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 75 clusters: 0.043884036600321245
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 100 clusters: 0.03635266943775993
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 125 clusters: 0.036067360153283726
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 150 clusters: 0.03043441253118052
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 175 clusters: 0.027641798577085614
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 200 clusters: 0.025694153277418485
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 225 clusters: 0.02385994485763932
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 250 clusters: 0.021549067263783687
# Silhouette Score for 95 nearest neighbors, 27 UMAP components, and 275 clusters: 0.020629278936342445
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 50 clusters: 0.05090669126926539
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 75 clusters: 0.042994960252261016
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 100 clusters: 0.03868000222782593
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 125 clusters: 0.035473716031444766
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 150 clusters: 0.03215039459593035
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 175 clusters: 0.02722996655049867
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 200 clusters: 0.026294404737829263
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 225 clusters: 0.02156096623798247
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 250 clusters: 0.02073923841850594
# Silhouette Score for 95 nearest neighbors, 30 UMAP components, and 275 clusters: 0.020672490211867577

# %%
dict_opt
# Out:
# {'nns': 65, 'components': 15, 'nclusters': 50, 'sscore': 0.0578705586751156}
