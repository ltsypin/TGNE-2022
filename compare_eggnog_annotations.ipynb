# %%
import pandas as pd

# %% [markdown]
# ### Check if two eggnog annotation files contain exactly the same contents

# %%
annotations_old_2021 = pd.read_csv('./TGNE/eggnog/Ttherm2021MAC_eggnog_hmmer_default_evalue.emapper.annotations', comment='#', delimiter='\t')
annotations_old_2021 = annotations_old_2021.sort_values(by='query')
annotations_old_2021.reset_index(drop=True, inplace=True)
annotations_old_2021.head()
# Out:
#               query  seed_ortholog         evalue   score  \
# 0  TTHERM_000000042  5911.EAR87740   0.000000e+00  1776.8
# 1   TTHERM_00000010  5911.EAR87737  1.700000e-272   898.9
# 2   TTHERM_00000020  5911.EAR87739   1.600000e-77   260.4
# 3   TTHERM_00000030  5888.CAK56476   5.900000e-52   172.6
# 4   TTHERM_00000040  5911.EAR87740   0.000000e+00  2139.6
#
#                                           eggNOG_OGs    max_annot_lvl  \
# 0  2CVX5@1|root,2RT23@2759|Eukaryota,3ZDPV@5878|C...  5878|Ciliophora
# 1              KOG0575@1|root,KOG0575@2759|Eukaryota   2759|Eukaryota
# 2              KOG0032@1|root,KOG0032@2759|Eukaryota   2759|Eukaryota
# 3              KOG0615@1|root,KOG0615@2759|Eukaryota   2759|Eukaryota
# 4  2CVX5@1|root,2RT23@2759|Eukaryota,3ZDPV@5878|C...  5878|Ciliophora
#
#   COG_category                               Description Preferred_name GOs  \
# 0            -                                         -              -   -
# ...

# %%
annotations_none_2021 = pd.read_csv('./TGNE/eggnog/2021_none_eggnog_compiled.annotations', comment='#', delimiter='\t')
annotations_none_2021 = annotations_none_2021.sort_values(by='query')
annotations_none_2021.reset_index(drop=True, inplace=True)
annotations_none_2021.head()
# Out:
#               query  seed_ortholog         evalue   score  \
# 0  TTHERM_000000042  5911.EAR87740   0.000000e+00  1776.8
# 1   TTHERM_00000010  5911.EAR87737  1.700000e-272   898.9
# 2   TTHERM_00000020  5911.EAR87739   1.600000e-77   260.4
# 3   TTHERM_00000030  5888.CAK56476   5.900000e-52   172.6
# 4   TTHERM_00000040  5911.EAR87740   0.000000e+00  2139.6
#
#                                           eggNOG_OGs    max_annot_lvl  \
# 0  2CVX5@1|root,2RT23@2759|Eukaryota,3ZDPV@5878|C...  5878|Ciliophora
# 1              KOG0575@1|root,KOG0575@2759|Eukaryota   2759|Eukaryota
# 2              KOG0032@1|root,KOG0032@2759|Eukaryota   2759|Eukaryota
# 3              KOG0615@1|root,KOG0615@2759|Eukaryota   2759|Eukaryota
# 4  2CVX5@1|root,2RT23@2759|Eukaryota,3ZDPV@5878|C...  5878|Ciliophora
#
#   COG_category                               Description Preferred_name GOs  \
# 0            -                                         -              -   -
# ...

# %%
annotations_none = pd.read_csv('./TGNE/eggnog/2024_none_eggnog_compiled.annotations', comment='#', delimiter='\t')
annotations_none = annotations_none.sort_values(by='query')
annotations_none.reset_index(drop=True, inplace=True)

annotations_realign = pd.read_csv('./TGNE/eggnog/2024_realign_eggnog_compiled.annotations', comment='#', delimiter='\t')
annotations_realign = annotations_realign.sort_values(by='query')
annotations_realign.reset_index(drop=True, inplace=True)

annotations_denovo = pd.read_csv('./TGNE/eggnog/2024_denovo_eggnog_compiled.annotations', comment='#', delimiter='\t')
annotations_denovo = annotations_denovo.sort_values(by='query')
annotations_denovo.reset_index(drop=True, inplace=True)

# %%
annotations_none.head()
# Out:
#            query  seed_ortholog         evalue   score  \
# 0  YF00000003.t1  5911.EAR89668   0.000000e+00  3238.2
# 1  YF00000004.t1  5911.EAR89667  8.500000e-271   892.2
# 2  YF00000005.t1  5911.EAR89666  6.800000e-113   369.6
# 3  YF00000006.t1  5911.EAR89665  1.800000e-238   784.9
# 4  YF00000008.t1  5911.EAR85802   1.200000e-91   302.5
#
#                                           eggNOG_OGs    max_annot_lvl  \
# 0  COG1132@1|root,KOG0054@2759|Eukaryota,3ZD02@58...  5878|Ciliophora
# 1  COG0697@1|root,KOG3912@2759|Eukaryota,3ZBQJ@58...   2759|Eukaryota
# 2  COG0633@1|root,KOG3309@2759|Eukaryota,3ZC6Z@58...  5878|Ciliophora
# 3  KOG3026@1|root,KOG3026@2759|Eukaryota,3ZBX8@58...  5878|Ciliophora
# 4  COG2202@1|root,KOG0500@1|root,KOG0500@2759|Euk...   2759|Eukaryota
#
#   COG_category                          Description Preferred_name  \
# 0            Q       ABC transporter family protein              -
# 1           EG         Nucleotide-sugar transporter        SLC35F6
# ...

# %%
annotations_realign.head()
# Out:
#            query  seed_ortholog         evalue   score  \
# 0  YF00000003.t1  5911.EAR89668   0.000000e+00  3238.2
# 1  YF00000004.t1  5911.EAR89667  8.500000e-271   892.2
# 2  YF00000005.t1  5911.EAR89666  6.800000e-113   369.6
# 3  YF00000006.t1  5911.EAR89665  1.800000e-238   784.9
# 4  YF00000008.t1  5911.EAR85802   1.200000e-91   302.5
#
#                                           eggNOG_OGs    max_annot_lvl  \
# 0  COG1132@1|root,KOG0054@2759|Eukaryota,3ZD02@58...  5878|Ciliophora
# 1  COG0697@1|root,KOG3912@2759|Eukaryota,3ZBQJ@58...   2759|Eukaryota
# 2  COG0633@1|root,KOG3309@2759|Eukaryota,3ZC6Z@58...  5878|Ciliophora
# 3  KOG3026@1|root,KOG3026@2759|Eukaryota,3ZBX8@58...  5878|Ciliophora
# 4  COG2202@1|root,KOG0500@1|root,KOG0500@2759|Euk...   2759|Eukaryota
#
#   COG_category                          Description Preferred_name  \
# 0            Q       ABC transporter family protein              -
# 1           EG         Nucleotide-sugar transporter        SLC35F6
# ...

# %%
annotations_denovo.head()
# Out:
#            query  seed_ortholog         evalue   score  \
# 0  YF00000003.t1  5911.EAR89668   0.000000e+00  3238.2
# 1  YF00000004.t1  5911.EAR89667  8.500000e-271   892.2
# 2  YF00000005.t1  5911.EAR89666  6.800000e-113   369.6
# 3  YF00000006.t1  5911.EAR89665  1.800000e-238   784.9
# 4  YF00000008.t1  5911.EAR85802   1.200000e-91   302.5
#
#                                           eggNOG_OGs    max_annot_lvl  \
# 0  COG1132@1|root,KOG0054@2759|Eukaryota,3ZD02@58...  5878|Ciliophora
# 1  COG0697@1|root,KOG3912@2759|Eukaryota,3ZBQJ@58...   2759|Eukaryota
# 2  COG0633@1|root,KOG3309@2759|Eukaryota,3ZC6Z@58...  5878|Ciliophora
# 3  KOG3026@1|root,KOG3026@2759|Eukaryota,3ZBX8@58...  5878|Ciliophora
# 4  COG2202@1|root,KOG0500@1|root,KOG0500@2759|Euk...   2759|Eukaryota
#
#   COG_category                          Description Preferred_name  \
# 0            Q       ABC transporter family protein              -
# 1           EG         Nucleotide-sugar transporter        SLC35F6
# ...

# %%
annotations_none_2024_lev = pd.read_csv('./TGNE/eggnog/TGD2024_NoRealign.emapper.annotations', comment='#', delimiter='\t')

# %%
annotations_none_2024_lev = annotations_none_2024_lev.sort_values(by='query')
annotations_none_2024_lev.reset_index(drop=True, inplace=True)

# %%
annotations_none_2024_lev.shape, annotations_none.shape, annotations_realign.shape, annotations_denovo.shape
# Out:
# ((15730, 21), (15730, 21), (15730, 21), (15730, 21))

# %%
(all(annotations_none_2024_lev == annotations_none) and 
 all(annotations_none_2024_lev == annotations_realign) and 
 all(annotations_none_2024_lev == annotations_denovo))
# Out:
# True

# %%
print('TOTAL # GENES ANNOTATED:')
print('     old_2021:', annotations_old_2021.shape[0])
print('    none_2021:', annotations_none_2021.shape[0])
print('none_2024_lev:', annotations_none_2024_lev.shape[0])
print('    none_2024:', annotations_none.shape[0])
print(' realign_2024:', annotations_realign.shape[0])
print('  denovo_2024:', annotations_denovo.shape[0])
# Out:
# TOTAL # GENES ANNOTATED:
#      old_2021: 17274
#     none_2021: 17274
# none_2024_lev: 15730
#     none_2024: 15730
#  realign_2024: 15730
#   denovo_2024: 15730

# %%
term_cols = ['COG_category',
 'GOs',
 'EC',
 'KEGG_ko',
 'PFAMs']

for t in term_cols:
    print(f'TOTAL # GENES {t} ANNOTATED:')
    print('     old_2021:', annotations_old_2021[annotations_old_2021[t] != '-'].shape[0])
    print('    none_2021:', annotations_none_2021[annotations_none_2021[t] != '-'].shape[0])
    print('none_2024_lev:', annotations_none_2024_lev[annotations_none_2024_lev[t] != '-'].shape[0])
    print('    none_2024:', annotations_none[annotations_none[t] != '-'].shape[0])
    print(' realign_2024:', annotations_realign[annotations_realign[t] != '-'].shape[0])
    print('  denovo_2024:', annotations_denovo[annotations_denovo[t] != '-'].shape[0])
    print()
# Out:
# TOTAL # GENES COG_category ANNOTATED:
#      old_2021: 12640
#     none_2021: 12640
# none_2024_lev: 11451
#     none_2024: 11451
#  realign_2024: 11451
#   denovo_2024: 11451
#
# TOTAL # GENES GOs ANNOTATED:
#      old_2021: 1658
#     none_2021: 1725
# none_2024_lev: 1494
#     none_2024: 1555
#  realign_2024: 1555
#   denovo_2024: 1555
#
# TOTAL # GENES EC ANNOTATED:
#      old_2021: 3049
#     none_2021: 3069
# none_2024_lev: 2787
#     none_2024: 2802
#  realign_2024: 2802
#   denovo_2024: 2802
#
# TOTAL # GENES KEGG_ko ANNOTATED:
#      old_2021: 6995
#     none_2021: 7016
# none_2024_lev: 6325
#     none_2024: 6343
#  realign_2024: 6343
#   denovo_2024: 6343
#
# TOTAL # GENES PFAMs ANNOTATED:
#      old_2021: 0
#     none_2021: 10660
# none_2024_lev: 9705
#     none_2024: 9708
#  realign_2024: 9708
#   denovo_2024: 9708

# %% [markdown]
# ### Eggnog emapper output probing and comparison

# %%
'''
PRINT SUMATION STRING FOR THE NUMBER OF SEQS SCANNED IN SEED ORTHOLOGS FILE
cat *.seed_orthologs | grep 'queries scanned' | sed -e 's/## //g' -e 's/ queries scanned/+/g' | tr -d '\n' | sed 's/+$//'; echo
'''
# Out:
# "\nPRINT SUMATION STRING FOR THE NUMBER OF SEQS SCANNED IN SEED ORTHOLOGS FILE\ncat *.seed_orthologs | grep 'queries scanned' | sed -e 's/## //g' -e 's/ queries scanned/+/g' | tr -d '\n' | sed 's/+$//'; echo\n"

# %%
# python3 s-generate_emapper_sbatch.py /project2/apturkew/michael/indexes/tgd2024/Manual_check-total-gene.gff3_Right_UTR.gff3_pep.fasta /project2/apturkew/michael/eggnog_none_parallel_2024 /project2/apturkew/michael/eggnog_data 10 64 60
0+0+0+0+256+0+260+0+288+280+0+280+266+0+0+242+237+260+0+0+0+0+0+0+0+232+271+306+0+258+293+266+0+0+283+299+231+0+272+268+289+0+0+0+285+250+0+303+295+0+0+0+277+0+0+0+0+0+283+0
# Out:
# 7330

# %%
# f100 python3 s-generate_emapper_sbatch.py /project2/apturkew/michael/indexes/tgd2024/Manual_check-total-gene.gff3_Right_UTR.gff3_pep.fasta /project2/apturkew/michael/eggnog_none_parallel_2024_f100/ /project2/apturkew/michael/eggnog_data 20 64 100

# Out:
# 13792

# %%
# f200 python3 s-generate_emapper_sbatch.py /project2/apturkew/michael/indexes/tgd2024/Manual_check-total-gene.gff3_Right_UTR.gff3_pep.fasta /project2/apturkew/michael/eggnog_none_parallel_2024_f200/ /project2/apturkew/michael/eggnog_data 20 64 200
...
# Out:
# 15220

# %%
'''
PRINT SUMATION STRING FOR THE NUMBER OF SEQS SCANNED IN ANNOTATIONS FILE
cat *.annotations | grep 'queries scanned' | sed -e 's/## //g' -e 's/ queries scanned/+/g' | tr -d '\n' | sed 's/+$//'; echo
'''
# Out:
# "\nPRINT SUMATION STRING FOR THE NUMBER OF SEQS SCANNED IN ANNOTATIONS FILE\ncat *.annotations | grep 'queries scanned' | sed -e 's/## //g' -e 's/ queries scanned/+/g' | tr -d '\n' | sed 's/+$//'; echo\n"

# %%
# f200 python3 s-generate_emapper_sbatch.py /project2/apturkew/michael/indexes/tgd2024/Manual_check-total-gene.gff3_Right_UTR.gff3_pep.fasta /project2/apturkew/michael/eggnog_none_parallel_2024_f200/ /project2/apturkew/michael/eggnog_data 20 64 200
...
# Out:
# 14570

# %% [markdown]
# grep -l '## 0 queries scanned' *_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_001_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_010_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_017_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_025_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_026_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_049_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_077_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_078_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_089_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_142_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_163_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_180_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_181_a.emapper.seed_orthologs
# Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_192_a.emapper.seed_orthologs
#
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_001_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_010_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_017_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_025_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_026_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_049_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_077_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_078_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_089_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_142_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_163_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_180_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_181_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_192_emapper_a.sbatch
#
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_001_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_010_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_017_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_025_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_026_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_049_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_077_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_078_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_089_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_142_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_163_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_180_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_181_emapper_b.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_192_emapper_b.sbatch

# %% [markdown]
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_010_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_017_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_025_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_026_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_077_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_078_emapper_a.sbatch

# %% [markdown]
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_017_emapper_a.sbatch
# submit Manual_check-total-gene.gff3_Right_UTR.gff3_pep_frag_078_emapper_a.sbatch

# %% [markdown]
# sed -i 's/pfam_realign none/pfam_realign realign/g' *emapper_a.sbatch
# sed -i 's/pfam_realign none/pfam_realign denovo/g' *emapper_a.sbatch

# %%
'''
FIND THE SEED ORTHOLOGS FILES WHERE THE NUMBER OF SEQS SCANNED IS ZERO AND PRINT THE COMMAND TO RUN STEP 'A' FOR EACH 
grep -l '## 0 queries scanned' *_a.emapper.seed_orthologs | awk '{print "submit " $0}' | sed 's/_a\.emapper\.seed_orthologs/_emapper_a.sbatch/'
'''
# Out:
# '\nFIND THE SEED ORTHOLOGS FILES WHERE THE NUMBER OF SEQS SCANNED IS ZERO AND PRINT THE COMMAND TO RUN STEP \'A\' FOR EACH \ngrep -l \'## 0 queries scanned\' *_a.emapper.seed_orthologs | awk \'{print "submit " $0}\' | sed \'s/_a\\.emapper\\.seed_orthologs/_emapper_a.sbatch/\'\n'

# %% [markdown]
# eggnog_none_parallel_2021_f300
# eggnog_none_parallel_2024_f200
# eggnog_none_parallel_2024_realign
# eggnog_none_parallel_2024_denovo

# %% [markdown]
# mkdir eggnog_none_parallel_2021_f300
# mkdir eggnog_none_parallel_2024_f200
# mkdir eggnog_none_parallel_2024_realign
# mkdir eggnog_none_parallel_2024_denovo

# %% [markdown]
# get /project2/apturkew/michael/eggnog_none_parallel_2021_f300/eggnog_compiled/eggnog_compiled.annotations ./2021_none_eggnog_compiled.annotations
# get /project2/apturkew/michael/eggnog_none_parallel_2024_f200/eggnog_compiled/eggnog_compiled.annotations ./2024_none_eggnog_compiled.annotations
# get /project2/apturkew/michael/eggnog_none_parallel_2024_realign/eggnog_compiled/eggnog_compiled.annotations ./2024_realign_eggnog_compiled.annotations
# get /project2/apturkew/michael/eggnog_none_parallel_2024_denovo/eggnog_compiled/eggnog_compiled.annotations ./2024_denovo_eggnog_compiled.annotations
